# %%
import requests
import urllib3

# 📍 ปิดการแจ้งเตือน InsecureRequestWarning เพื่อให้ Log ของระบบองค์กรสะอาด
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

def get_inquiry_profile():
    url = "https://clouds.online-allmember-staging.net/AllMemberInquiryProfile/InquiryProfile"
    payload = {"your": "data"}
    
    try:
        # 📍 จุดสำคัญ: ใส่ verify=False เพื่อข้ามการตรวจ SSL
        response = requests.post(url, json=payload, verify=False)
        response.raise_for_status()
        
        return response.json()
        
    except requests.exceptions.RequestException as e:
        raise Exception(f"API Error: {str(e)}")

# %%
.venv/Scripts/Activate.ps1
python -m app.backend.main
docker compose -f .\docker\docker-compose.yml down
docker ps -a
docker compose -f .\docker\docker-compose.yml  up -d --build
cd .\app\webpack
 npm run preview
npm run build
npm install

# %%
pip list
# Out:
# Package                 Version
# ----------------------- -----------
# annotated-doc           0.0.4
# annotated-types         0.7.0
# anyio                   4.13.0
# argon2-cffi             25.1.0
# argon2-cffi-bindings    25.1.0
# asttokens               3.0.1
# bcrypt                  5.0.0
# boto3                   1.43.6
# botocore                1.43.6
# certifi                 2026.4.22
# cffi                    2.0.0
# charset-normalizer      3.4.7
# click                   8.3.3
# colorama                0.4.6
# comm                    0.2.3
# cryptography            48.0.0
# debugpy                 1.8.20
# decorator               5.2.1
# dnspython               2.8.0
# ecdsa                   0.19.2
# email-validator         2.3.0
# et_xmlfile              2.0.0
# executing               2.2.1
# Faker                   40.15.0
# fastapi                 0.136.1
# fsspec                  2026.4.0
# greenlet                3.5.0
# h11                     0.16.0
# ...

# %%
import requests
import json
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
url = "http://clouds.online-allmember-staging.net/AllMemberInquiryProfile/InquiryProfile"

payload = json.dumps({
 "stationId": "1",
 "storeId": "09884",
 "channelId": "CN01",
 "identifyId": "3",
 "identifyValue": "0636509005",
 "requestTime": "2022/11/29 23:59:59"
})
headers = {
	'Content-Type': 'application/json'
}
try:
    response = requests.post(url, headers=headers, data=payload, verify=False)
    response.raise_for_status()
    
    print(response.json())
    
except requests.exceptions.RequestException as e:
    raise Exception(f"API Error: {str(e)}")
# Out:
# {'data': {'memberId': '010190592151', 'mobileNo': '0636509005', 'nameTH': 'ภัทรดา', 'surnameTH': 'เคนท้าว', 'nameEN': '', 'surnameEN': '', 'birthDay': '27/09/1992', 'memberStatusId': '1', 'idenNo': '1103700902520', 'walletStatus': '2', 'walletConsent': '2', 'responseTime': '21/04/2026 10:45:32', 'lst': [], 'memberGroups': [], 'eSlip': '3', 'flagMobileTrue': '0', 'term': {'version': '2', 'statusId': '1'}, 'consent': [{'actionId': '1', 'name': 'ความยินยอมในการเก็บรวบรวม ใช้ หรือเปิดเผยข้อมูลส่วนบุคคล', 'version': '2', 'statusId': '1', 'warningMsg': 'คุณจะไม่สามารถทำธุรกรรมทางการเงิน และใช้บริการต่างๆ บน 7App ได้ด้วยประสบการณ์ที่ดีที่สุด'}, {'actionId': '2', 'name': 'ความยินยอมในการเก็บรวบรวม ใช้ข้อมูลส่วนบุคคลเพื่อให้สิทธิประโยชน์เฉพาะตัวแก่สมาชิก', 'version': '2', 'statusId': '2', 'warningMsg': 'คุณจะพลาดโอกาสการได้รับประสบการณ์ที่ดีที่สุดที่เราต้องการมอบให้คุณ เมื่อใช้งาน 7App'}], 'flagRedeemReward': '1'}, 'returnCode': '00000', 'returnDesc': 'Success', 'returnDescTH': 'ทำรายการสำเร็
# ...

# %%
# ให้บันทึกเป็นไฟล์ models.py หรือวางแทนที่ใน Datainput.py
import pandas as pd
import xmltodict as xd
from datetime import datetime
from random import randint
from IPython.display import display
from typing import Dict, Any
import random
class TransactionContext:
    """
    คลาสจัดการข้อมูล (State Management) ของ Transaction
    ลดการใช้ Array Index ซับซ้อน และเก็บสถานะล่าสุดโดยอัตโนมัติ
    """
    def __init__(self, **kwargs):
        # 1. Core Identifiers
        self.store_id = kwargs.get("STORE_ID", "09884")
        self.vendor_id = kwargs.get("VENDOR_ID", "0993000134168")
        self.service_id = kwargs.get("SERVICE_ID", "02")
        self.item_name = kwargs.get("ITEM_NAME", "รับบริจาคเงิน")
        self.zone = kwargs.get("ZONE", "1")
        self.employee_id = kwargs.get("EMPLOYEE_ID", "0555505")
        self.pos_tax_id = kwargs.get("POS_TAX_ID", "1537264827382")
        self.payment_channel = kwargs.get("PAYMENT_CHANNEL", "C05")
        self.rept_type = kwargs.get("REPT_TYPE", "H")
        
        # 2. Reference Data
        self.data_1 = kwargs.get("DATA_1", "")
        self.data_2 = kwargs.get("DATA_2", "")
        self.data_3 = kwargs.get("DATA_3", "")
        self.data_4 = kwargs.get("DATA_4", "")
        self.data_5 = kwargs.get("DATA_5", "")
        self.data_6 = kwargs.get("DATA_6", "")
        self.data_7 = kwargs.get("DATA_7", "")
        self.data_9 = kwargs.get("DATA_9", "")
        
        # 3. Amount & Calculation
        self.bill_amt = str(kwargs.get("BILL_AMT", "100"))
        self.vat_amt = kwargs.get("VAT_AMT", "0")
        
        # 4. Customer Information
        self.cust_name = kwargs.get("CUST_NAME", "")
        self.cust_addr_1 = kwargs.get("CUST_ADDR_1", "")
        self.cust_addr_2 = kwargs.get("CUST_ADDR_2", "")
        self.cust_addr_3 = kwargs.get("CUST_ADDR_3", "")
        self.cust_phone_no = kwargs.get("CUST_PHONE_NO", "")
        
        # 5. System Data
        self._refresh_timestamp()
        self.common_trn_id = str(random.randint(1, 100))
        self.seq_no = ""
        self.client_serv_seq = ""
        
        # 6. Response States (อัปเดตอัตโนมัติเมื่อยิง API)
        self.response_data: Dict[str, Any] = {}
        self.resp_tx_id = ""
        self.resp_vendor_id = ""
        self.resp_serv_id = ""

    def _refresh_timestamp(self):
        now = datetime.now()
        self.sys_date = now.strftime("%Y/%m/%d")
        self.sys_time = now.strftime("%X")

    def process_response(self, xml_string: str) -> bool:
        """แปลง Response XML เป็น Dictionary และจัดเก็บ State ที่จำเป็น"""
        try:
            parsed = xd.parse(xml_string)
            hq_resp = parsed.get("HQ_RESPONSE", {})
            self.response_data = hq_resp
            
            # เก็บค่าสำคัญไว้ใช้ต่อยอด (เช่น ส่ง Cancel/Confirm)
            self.resp_tx_id = hq_resp.get("TX_ID", self.resp_tx_id)
            self.resp_vendor_id = hq_resp.get("VENDOR_ID", self.vendor_id)
            self.resp_serv_id = hq_resp.get("SERV_ID", self.service_id)
            self.seq_no = hq_resp.get("SEQ_NO", self.seq_no)
            self.client_serv_seq = hq_resp.get("CLIENT_SERV_SEQ", self.client_serv_seq)
            return True
        except Exception as e:
            print(f"[ERROR] XML Parsing Failed: {e}")
            return False

    def show_details(self):
        """แสดงข้อมูล Transaction และ Response ล่าสุดแบบตาราง"""
        print("\n" + "="*60)
        print("🟢 TRANSACTION CONTEXT DETAILS 🟢")
        print("="*60)
        req_df = pd.DataFrame([
            {"Field": "STORE_ID", "Value": self.store_id},
            {"Field": "VENDOR_ID", "Value": self.vendor_id},
            {"Field": "ITEM_NAME", "Value": self.item_name},
            {"Field": "BILL_AMT", "Value": self.bill_amt},
            {"Field": "DATA_1", "Value": self.data_1},
        ])
        print("\n▶ [CURRENT REQUEST CONFIG]:")
        display(req_df)
        
        if self.response_data:
            print("\n▶ [LATEST RESPONSE DATA]:")
            resp_df = pd.DataFrame([{"Field": k, "Value": v} for k, v in self.response_data.items() if v])
            display(resp_df)
        print("="*60 + "\n")

# %%
import base64
import requests
import pandas as pd
import xmltodict as xd
from datetime import datetime
from typing import Dict, Any, Optional
from IPython.display import display
from .app.backend.Online.transaction import TransactionContext 
class CounterServiceAPI:
    """
    คลาสจัดการ API ที่อ้างอิงโครงสร้าง XML ตรงตามไฟล์ Storage.py (100% Exact Match)
    """
    def __init__(self, url: str):
        self.url = url
        self.headers = {'Content-Type': 'text/xml'}

#     def _send_request(self, xml_payload: str, ctx: Any) -> Optional[str]:
#         soap_env = f"""<?xml version="1.0" encoding="UTF-8"?>
# <soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/" xmlns:por="http://portal.cs/">
#     <soapenv:Header/>
#     <soapenv:Body>
#         <por:CSService>
#             <arg0><![CDATA[{xml_payload}]]></arg0>
#         </por:CSService>
#     </soapenv:Body>
# </soapenv:Envelope>"""
        
#         try:
#             response = requests.post(self.url, headers=self.headers, data=soap_env.encode("utf-8"), timeout=20)
#             if "<return>" in response.text:
#                 decode = response.text.split("<return>")[-1].split("</return>")[0]
#                 xml_resp = base64.b64decode(decode).decode('utf-8')
#                 ctx.process_response(xml_resp) # อัปเดตข้อมูล State 
#                 self._display_summary(ctx)
#                 return xml_resp
#             else:
#                 print("[ERROR] รูปแบบ Response ไม่ถูกต้อง")
#                 return None
#         except Exception as e:
#             print(f"[ERROR] การเชื่อมต่อล้มเหลว: {e}")
#             return None
    def _send_request(self, xml_payload: str, ctx: TransactionContext) -> Optional[str]:
            # [NEW] เก็บค่า XML ก่อนยิง API ลงใน Context
            ctx.latest_request_xml = xml_payload 

            soap_env = f"""<?xml version="1.0" encoding="UTF-8"?>
    <soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/" xmlns:por="http://portal.cs/">
        <soapenv:Header/><soapenv:Body><por:CSService><arg0><![CDATA[{xml_payload}]]></arg0></por:CSService></soapenv:Body>
    </soapenv:Envelope>"""
            try:
                response = requests.post(self.url, headers=self.headers, data=soap_env.encode("utf-8"), timeout=30)
                if "<return>" in response.text:
                    decode = response.text.split("<return>")[-1].split("</return>")[0]
                    xml_resp = base64.b64decode(decode).decode('utf-8')
                    
                    # [NEW] เก็บค่า Raw Decode ลงใน Context
                    ctx.latest_raw_decoded_response = xml_resp
                    
                    ctx.process_response(xml_resp)
                    
                    if ctx.response_data:
                        keys = ['SUCCESS', 'CODE', 'DESCRIPTOR', 'TX_ID', 'BILL_AMT']
                        display(pd.DataFrame([{k: ctx.response_data.get(k) for k in keys if ctx.response_data.get(k)}]))
                    return xml_resp
                else:
                    raise ValueError("Response ไม่มี Tag <return>")
            except Exception as e:
                raise Exception(f"API Error: {e}")
    def _display_summary(self, ctx: Any):
        if ctx.response_data:
            keys_to_show = ['SUCCESS', 'CODE', 'DESCRIPTOR', 'TX_ID', 'BILL_AMT']
            filtered = {k: ctx.response_data.get(k) for k in keys_to_show if ctx.response_data.get(k)}
            display(pd.DataFrame([filtered]))

    # ==========================================================
    # ACTION METHODS (ตรงตาม Storage.py ทุกประการ)
    # ==========================================================
    
    def data_exchange(self, ctx: Any) -> Optional[str]:
        ctx._refresh_timestamp()
        payload = f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{ctx.vendor_id}</VENDOR_ID><SERVICE_ID>{ctx.service_id}</SERVICE_ID><METHOD>DataExchange</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{ctx.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{ctx.vendor_id}</VENDOR_ID><SERV_ID>{ctx.service_id}</SERV_ID><SERVICE_ID>{ctx.service_id}</SERVICE_ID><STORE_ID>{ctx.store_id}</STORE_ID><STATION_ID>1</STATION_ID><BUS_DATE>{ctx.sys_date}</BUS_DATE><BUS_TIME>{ctx.sys_time}</BUS_TIME><SYS_DATE>{ctx.sys_date}</SYS_DATE><SYS_TIME>{ctx.sys_time}</SYS_TIME><COMMON_TRN_ID>{ctx.common_trn_id}</COMMON_TRN_ID><SEQ_NO></SEQ_NO><CLIENT_SERV_SEQ></CLIENT_SERV_SEQ><SHIFT_ID>9</SHIFT_ID><TRANS_TYPE>N</TRANS_TYPE><ACCT_NO></ACCT_NO><BILL_AMT>{ctx.bill_amt}</BILL_AMT><ROUND_BILL_AMT>{ctx.bill_amt}</ROUND_BILL_AMT><VAT_AMT>{ctx.vat_amt}</VAT_AMT><REPT_TYPE>{ctx.rept_type}</REPT_TYPE><REPT_NO></REPT_NO><PREV_REF_SEQ></PREV_REF_SEQ><PREV_REF_DATE></PREV_REF_DATE><SERV_CHARGE_NO></SERV_CHARGE_NO><ITEM_NAME>{ctx.item_name}</ITEM_NAME><ITEM_SELECTION>N</ITEM_SELECTION><EMPLOYEE_ID>{ctx.employee_id}</EMPLOYEE_ID><POS_TAX_ID>{ctx.pos_tax_id}</POS_TAX_ID><DATA_1>{ctx.data_1}</DATA_1><DATA_2>{ctx.data_2}</DATA_2><DATA_3>{ctx.data_3}</DATA_3><DATA_4>{ctx.data_4}</DATA_4><DATA_5>{ctx.data_5}</DATA_5><DATA_6>{ctx.data_6}</DATA_6><DATA_7>{ctx.data_7}</DATA_7><DATA_9>{ctx.data_9}</DATA_9><ZONE>{ctx.zone}</ZONE><PAYMENT_TYPE>001</PAYMENT_TYPE><CANCEL_ID></CANCEL_ID><CUST_NAME>{ctx.cust_name}</CUST_NAME><CUST_ADDR_1>{ctx.cust_addr_1}</CUST_ADDR_1><CUST_ADDR_2>{ctx.cust_addr_2}</CUST_ADDR_2><CUST_ADDR_3>{ctx.cust_addr_3}</CUST_ADDR_3><CUST_PHONE_NO>{ctx.cust_phone_no}</CUST_PHONE_NO></DATA></SERVICE_BOX></HQ_REQUEST>"""
        return self._send_request(payload, ctx)

    def cancel(self, ctx: Any) -> Optional[str]:
        # Cancel ส่งแค่ข้อมูลบางส่วน อิงค่า TX_ID จากการ Response รอบก่อน
        payload = f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{ctx.vendor_id}</VENDOR_ID><SERVICE_ID>{ctx.service_id}</SERVICE_ID><METHOD>Cancel</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{ctx.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{ctx.resp_vendor_id}</VENDOR_ID><SERV_ID>{ctx.resp_serv_id}</SERV_ID><SERVICE_ID>{ctx.resp_serv_id}</SERVICE_ID><STORE_ID>{ctx.store_id}</STORE_ID><STATION_ID>1</STATION_ID><BUS_DATE>{ctx.sys_date}</BUS_DATE><BUS_TIME>{ctx.sys_time}</BUS_TIME><TX_ID>{ctx.resp_tx_id}</TX_ID><PAYMENT_TYPE>001</PAYMENT_TYPE><CANCEL_ID></CANCEL_ID></DATA></SERVICE_BOX></HQ_REQUEST>"""
        return self._send_request(payload, ctx)

    def data_exchange_confirm(self, ctx: Any) -> Optional[str]:
        # ดึง DATA ต่างๆ มาจาก Response (ตรงตาม self.store[2][6][x] เดิม)
        r_amt = ctx.response_data.get('BILL_AMT', ctx.bill_amt)
        payload = f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{ctx.vendor_id}</VENDOR_ID><SERVICE_ID>{ctx.service_id}</SERVICE_ID><METHOD>DataExchangeConfirm</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{ctx.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{ctx.resp_vendor_id}</VENDOR_ID><SERV_ID>{ctx.resp_serv_id}</SERV_ID><SERVICE_ID>{ctx.resp_serv_id}</SERVICE_ID><STATION_ID>1</STATION_ID><STORE_ID>{ctx.store_id}</STORE_ID><BUS_DATE>{ctx.sys_date}</BUS_DATE><BUS_TIME>{ctx.sys_time}</BUS_TIME><SYS_DATE>{ctx.sys_date}</SYS_DATE><SYS_TIME>{ctx.sys_time}</SYS_TIME><TX_ID>{ctx.resp_tx_id}</TX_ID><SEQ_NO>{ctx.seq_no}</SEQ_NO><EMPLOYEE_ID>{ctx.employee_id}</EMPLOYEE_ID><CLIENT_SERV_SEQ>{ctx.seq_no}</CLIENT_SERV_SEQ><SERV_ID>{ctx.service_id}</SERV_ID><BILL_AMT>{r_amt}</BILL_AMT><ROUND_BILL_AMT>{r_amt}</ROUND_BILL_AMT><ACCT_NO></ACCT_NO><VAT_AMT>{ctx.vat_amt}</VAT_AMT><DATA_1>{ctx.response_data.get('DATA_1', ctx.data_1)}</DATA_1><DATA_2>{ctx.response_data.get('DATA_2', ctx.data_2)}</DATA_2><DATA_3>{ctx.response_data.get('DATA_3', ctx.data_3)}</DATA_3><DATA_4>{ctx.response_data.get('DATA_4', ctx.data_4)}</DATA_4><DATA_5>{ctx.response_data.get('DATA_5', ctx.data_5)}</DATA_5><DATA_6>{ctx.response_data.get('DATA_6', ctx.data_6)}</DATA_6><DATA_7>{ctx.response_data.get('DATA_7', ctx.data_7)}</DATA_7><DATA_9>{ctx.response_data.get('DATA_9', ctx.data_9)}</DATA_9><ZONE>{ctx.zone}</ZONE><PAYMENT_TYPE>001</PAYMENT_TYPE><TOT_BILL_TRANS></TOT_BILL_TRANS><TOT_BILL_AMT></TOT_BILL_AMT><TOT_VENDOR_TRANS></TOT_VENDOR_TRANS><TOT_VENDOR_AMT></TOT_VENDOR_AMT><TOT_COUNTER_TRANS></TOT_COUNTER_TRANS><TOT_COUNTER_AMT></TOT_COUNTER_AMT><TOT_CLIENT_TRANS></TOT_CLIENT_TRANS><TOT_CLIENT_AMT></TOT_CLIENT_AMT><TOT_BILL_TRANS_OR></TOT_BILL_TRANS_OR><TOT_BILL_AMT_OR></TOT_BILL_AMT_OR><CANCEL_ID></CANCEL_ID><CANCEL_ID></CANCEL_ID><CUST_NAME>{ctx.response_data.get('CUST_NAME', ctx.cust_name)}</CUST_NAME><CUST_ADDR_1>{ctx.response_data.get('CUST_ADDR_1', ctx.cust_addr_1)}</CUST_ADDR_1><CUST_ADDR_2>{ctx.response_data.get('CUST_ADDR_2', ctx.cust_addr_2)}</CUST_ADDR_2><CUST_ADDR_3>{ctx.response_data.get('CUST_ADDR_3', ctx.cust_addr_3)}</CUST_ADDR_3><CUST_PHONE_NO>{ctx.response_data.get('CUST_PHONE_NO', ctx.cust_phone_no)}</CUST_PHONE_NO></DATA></SERVICE_BOX></HQ_REQUEST>"""
        return self._send_request(payload, ctx)

    def online_receipt(self, ctx: Any) -> Optional[str]:
        # OR ไม่ต้องการ DATA_1 ถึง DATA_9
        r_amt = ctx.response_data.get('BILL_AMT', ctx.bill_amt)
        payload = f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{ctx.vendor_id}</VENDOR_ID><SERVICE_ID>{ctx.service_id}</SERVICE_ID><METHOD>OR</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{ctx.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{ctx.resp_vendor_id}</VENDOR_ID><SERVICE_ID>{ctx.resp_serv_id}</SERVICE_ID><SERV_ID>{ctx.resp_serv_id}</SERV_ID><STORE_ID>{ctx.store_id}</STORE_ID><STATION_ID>1</STATION_ID><BUS_DATE>{ctx.sys_date}</BUS_DATE><BUS_TIME>{ctx.sys_time}</BUS_TIME><SYS_DATE>{ctx.sys_date}</SYS_DATE><SYS_TIME>{ctx.sys_time}</SYS_TIME><TX_ID>{ctx.resp_tx_id}</TX_ID><BILL_AMT>{r_amt}</BILL_AMT><ROUND_BILL_AMT>{r_amt}</ROUND_BILL_AMT><VAT_AMT>{ctx.vat_amt}</VAT_AMT><PAYMENT_TYPE>001</PAYMENT_TYPE><CANCEL_ID></CANCEL_ID></DATA></SERVICE_BOX></HQ_REQUEST>"""
        return self._send_request(payload, ctx)

    def or_cancel(self, ctx: Any) -> Optional[str]:
        payload = f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{ctx.vendor_id}</VENDOR_ID><SERVICE_ID>{ctx.service_id}</SERVICE_ID><METHOD>ORCancel</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{ctx.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{ctx.resp_vendor_id}</VENDOR_ID><SERVICE_ID>{ctx.resp_serv_id}</SERVICE_ID><SERV_ID>{ctx.resp_serv_id}</SERV_ID><STORE_ID>{ctx.store_id}</STORE_ID><STATION_ID>1</STATION_ID><BUS_DATE>{ctx.sys_date}</BUS_DATE><BUS_TIME>{ctx.sys_time}</BUS_TIME><TX_ID>{ctx.resp_tx_id}</TX_ID><PAYMENT_TYPE>001</PAYMENT_TYPE><CANCEL_ID></CANCEL_ID></DATA></SERVICE_BOX></HQ_REQUEST>"""
        return self._send_request(payload, ctx)

    def or_confirm(self, ctx: Any) -> Optional[str]:
        r_amt = ctx.response_data.get('BILL_AMT', ctx.bill_amt)
        # ORConfirm ต้องส่ง DATA คืนกลับไปด้วย พร้อม Tag ห้อยท้ายเหมือน ExchangeConfirm
        payload = f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{ctx.vendor_id}</VENDOR_ID><SERVICE_ID>{ctx.service_id}</SERVICE_ID><METHOD>ORConfirm</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{ctx.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{ctx.resp_vendor_id}</VENDOR_ID><SERVICE_ID>{ctx.resp_serv_id}</SERVICE_ID><SERV_ID>{ctx.resp_serv_id}</SERV_ID><STATION_ID>1</STATION_ID><STORE_ID>{ctx.store_id}</STORE_ID><STATION_ID>1</STATION_ID><BUS_DATE>{ctx.sys_date}</BUS_DATE><BUS_TIME>{ctx.sys_time}</BUS_TIME><BILL_AMT>{r_amt}</BILL_AMT><ROUND_BILL_AMT>{r_amt}</ROUND_BILL_AMT><VAT_AMT>{ctx.vat_amt}</VAT_AMT><TX_ID>{ctx.resp_tx_id}</TX_ID><SEQ_NO>{ctx.seq_no}</SEQ_NO><CLIENT_SERV_SEQ>{ctx.seq_no}</CLIENT_SERV_SEQ><SERV_ID>{ctx.resp_serv_id}</SERV_ID><DATA_1>{ctx.response_data.get('DATA_1', ctx.data_1)}</DATA_1><DATA_2>{ctx.response_data.get('DATA_2', ctx.data_2)}</DATA_2><DATA_3>{ctx.response_data.get('DATA_3', ctx.data_3)}</DATA_3><DATA_4>{ctx.response_data.get('DATA_4', ctx.data_4)}</DATA_4><DATA_5>{ctx.response_data.get('DATA_5', ctx.data_5)}</DATA_5><DATA_6>{ctx.response_data.get('DATA_6', ctx.data_6)}</DATA_6><DATA_7>{ctx.response_data.get('DATA_7', ctx.data_7)}</DATA_7><DATA_9>{ctx.response_data.get('DATA_9', ctx.data_9)}</DATA_9><ZONE>{ctx.zone}</ZONE><PAYMENT_TYPE>001</PAYMENT_TYPE><TOT_BILL_TRANS></TOT_BILL_TRANS><TOT_BILL_AMT></TOT_BILL_AMT><TOT_VENDOR_TRANS></TOT_VENDOR_TRANS><TOT_VENDOR_AMT></TOT_VENDOR_AMT><TOT_COUNTER_TRANS></TOT_COUNTER_TRANS><TOT_COUNTER_AMT></TOT_COUNTER_AMT><TOT_CLIENT_TRANS></TOT_CLIENT_TRANS><TOT_CLIENT_AMT></TOT_CLIENT_AMT><TOT_BILL_TRANS_OR></TOT_BILL_TRANS_OR><TOT_BILL_AMT_OR></TOT_BILL_AMT_OR><CANCEL_ID></CANCEL_ID></DATA></SERVICE_BOX></HQ_REQUEST>"""
        return self._send_request(payload, ctx)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[75], line 8
#       6 from typing import Dict, Any, Optional
#       7 from IPython.display import display
# ----> 8 from .app.backend.Online.transaction import TransactionContext
#       9 class CounterServiceAPI:
#      10     """
#      11     คลาสจัดการ API ที่อ้างอิงโครงสร้าง XML ตรงตามไฟล์ Storage.py (100% Exact Match)
#      12     """
#
# ImportError: attempted relative import with no known parent package

# %%
def get_base_context():
    """สร้าง Context ใหม่ทุกครั้งก่อนเริ่ม Test Case ป้องกัน Data ติดค้าง"""
    return TransactionContext(
        STORE_ID="09884",
        VENDOR_ID="0994000015402",
        SERVICE_ID="21",
        ITEM_NAME="รับบริจาคเงิน",
        BILL_AMT="100",
        DATA_1='68017353925680227',
        DATA_2='00202000029256806'
    )

URL = "http://qacspos.counterservice.co.th:80/DCWSCDSONLINE/WSCDSService"
api = CounterServiceAPI(URL)

# %%
# [Case 1] Normal Flow: ยิง Exchange แล้ว Cancel
print("\n[Case 1] DataExchange -> Cancel")
ctx = get_base_context()
api.data_exchange(ctx)
api.cancel(ctx)

# # [Case 2] Dup ติด 3: Exchange -> Cancel -> Exchange (ซ้ำ)
# print("\n[Case 2] Dup ติด 3")
# ctx = get_base_context()
# api.data_exchange(ctx)
# api.cancel(ctx)
# api.data_exchange(ctx) # ยิง API Dup ติด 3

# # [Case 3] Dup ติด 1: ยิง Exchange เบิ้ล 2 ครั้งรวด
# print("\n[Case 3] Dup ติด 1")
# ctx = get_base_context()
# api.data_exchange(ctx)
# api.data_exchange(ctx) # ยิง API Dup ติด 1

# # [Case 4] Dup ติด 3 (และ Confirm): Exchange -> Cancel -> Exchange -> Confirm -> Exchange
# print("\n[Case 4] Dup ติด 3 (Confirm)")
# ctx = get_base_context()
# api.data_exchange(ctx)
# api.cancel(ctx)
# api.data_exchange(ctx) # Dup ติด 3
# api.data_exchange_confirm(ctx)
# api.data_exchange(ctx)

# # [Case 5] Dup ติด 6 (จบด้วย OR): 
# print("\n[Case 5] Dup ติด 6")
# ctx = get_base_context()
# api.data_exchange(ctx)
# api.cancel(ctx)
# api.data_exchange(ctx) # Dup ติด 6
# api.data_exchange_confirm(ctx)
# api.online_receipt(ctx) # Or
# api.data_exchange(ctx)
# Out:
# [Case 1] DataExchange -> Cancel
#   SUCCESS  CODE                      DESCRIPTOR
# 0   false  2002  ผู้ใช้ไม่สิทธิที่จะทำรายการนี้
#   SUCCESS CODE          DESCRIPTOR
# 0   false  147  ไม่พบรายการรับชำระ
# '<?xml version="1.0" encoding="UTF-8"?><HQ_RESPONSE><SUCCESS>false</SUCCESS><CODE>147</CODE><DESCRIPTOR>ไม่พบรายการรับชำระ</DESCRIPTOR><VENDOR_ID></VENDOR_ID><SERV_ID></SERV_ID><TX_ID></TX_ID><PRINTSLIP></PRINTSLIP><VAT></VAT><BILL_AMT></BILL_AMT><FEE></FEE><FEE_VAT></FEE_VAT><DATA_1></DATA_1><DATA_2></DATA_2><DATA_3></DATA_3><DATA_4></DATA_4><DATA_5></DATA_5><DATA_6></DATA_6><DATA_7></DATA_7><CUSTOMER_NAME></CUSTOMER_NAME><CUSTOMER_ADDR_1></CUSTOMER_ADDR_1><CUSTOMER_ADDR_2></CUSTOMER_ADDR_2><CUSTOMER_ADDR_3></CUSTOMER_ADDR_3><CUSTOMER_TEL_NO></CUSTOMER_TEL_NO><ACCT_NO></ACCT_NO><CUSTOMER_TAX_ID></CUSTOMER_TAX_ID><CUSTOMER_BRANCH_CODE></CUSTOMER_BRANCH_CODE><CUSTOMER_RECEIPT_NAME></CUSTOMER_RECEIPT_NAME><CUSTOMER_RECEIPT_ADDR></CUSTOMER_RECEIPT_ADDR></HQ_RESPONSE>'

# %%
# [Case 6] DataExchange -> DataExchangeConfirm
print("\n[Case 6] DataExchange -> DataExchangeConfirm")
ctx = get_base_context()
api.data_exchange(ctx)
api.data_exchange_confirm(ctx)

# [Case 7] DataExchangeConfirm ซ้ำ Runno เดิม (133 รับชำระซ้ำซ้อน)
print("\n[Case 7] DataExchangeConfirm ซ้ำ (133 รับชำระซ้ำซ้อน)")
api.data_exchange_confirm(ctx) # ใช้ ctx ตัวเดิมจาก Case 6 ยิงซ้ำทันที

# [Case 8] เต็มระบบ OR Flow
print("\n[Case 8] OR Flow สเต็ปครบถ้วน")
ctx = get_base_context()
api.data_exchange(ctx) # จำเป็นต้องมีข้อมูลตั้งต้นใน Context ก่อน
api.online_receipt(ctx) # Or
api.or_cancel(ctx)      # OrCancel
api.online_receipt(ctx) # Or ด้วยรายการ ORCancel
api.or_confirm(ctx)     # ORConfirm
api.or_confirm(ctx)     # ORConfirm Runno เดิม (133 รับชำระซ้ำซ้อน)
api.online_receipt(ctx) # OR ด้วยรายการ ORConfirm (134 รายการยกเลิกซ้ำซ้อน)

# [Case 9] DataExchange -> DataExchangeConfirm กรณีแก้ไขเงินขา Confirm
print("\n[Case 9] แก้ไขจำนวนเงินขา Confirm")
ctx = get_base_context()
api.data_exchange(ctx)
ctx.bill_amt = str(float(ctx.bill_amt) + 2) # จำลองการแก้เงินแบบเดิม
api.data_exchange_confirm(ctx)
# Out:
# [Case 6] DataExchange -> DataExchangeConfirm
#   SUCCESS CODE                                  DESCRIPTOR
# 0   false  999  ปัญหาไม่ได้จัดประเภท กรุณาติดต่อ Help desk
#   SUCCESS CODE                                  DESCRIPTOR
# 0   false  999  ปัญหาไม่ได้จัดประเภท กรุณาติดต่อ Help desk
# [Case 7] DataExchangeConfirm ซ้ำ (133 รับชำระซ้ำซ้อน)
#   SUCCESS CODE                                  DESCRIPTOR
# 0   false  999  ปัญหาไม่ได้จัดประเภท กรุณาติดต่อ Help desk
# [Case 8] OR Flow สเต็ปครบถ้วน
#   SUCCESS CODE                                  DESCRIPTOR
# 0   false  999  ปัญหาไม่ได้จัดประเภท กรุณาติดต่อ Help desk
#   SUCCESS CODE          DESCRIPTOR
# 0   false  147  ไม่พบรายการรับชำระ
#   SUCCESS CODE         DESCRIPTOR
# 0   false  137  ไม่พบรายการยกเลิก
#   SUCCESS CODE          DESCRIPTOR
# 0   false  147  ไม่พบรายการรับชำระ
#   SUCCESS CODE         DESCRIPTOR
# 0   false  137  ไม่พบรายการยกเลิก
#   SUCCESS CODE         DESCRIPTOR
# 0   false  137  ไม่พบรายการยกเลิก
# ...

# %%
from pydantic_settings import BaseSettings
import secrets

PROMOTION = 'PROMOTION'
MAP_LEN_TO_TYPE = {"10":"3","13":"4","12":"0"}
STORE ='09884'
SYSTEM = STATION = SHIFT = "1"
POST ='POST'

class Settings(BaseSettings):
    # Database
    POSTGRES_URL: str = "postgresql+psycopg2://sa:Admin2000@localhost:5432/PROMOTION"

    SQLSERVER_URL: str = (
    "mssql+pyodbc://sa:Admin2000@localhost/PROMOTION"
    "?driver=ODBC+Driver+17+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
    MYSQL_URL: str = 'local.amazonaws.com'
    MYSQL_USER: str ='scawsadmin'
    MYSQL_PASSWORD: str ='1e29dbb9fcec80471f7f98626a414abf'
    MYSQL_DATABASE: str ='master'

    SQL_SERVER_URL: str = 'localhost'
    SQL_SERVER_USER: str ='sa'
    SQL_SERVER_PASSWORD: str ='Admin2000'
    SQL_SERVER_DATABASE: str ='POSG2'


    SECRET_KEY: str =secrets.token_hex(32)
    ALGORITHM: str = "HS256"
    ACCESS_TOKEN_EXPIRE_MINUTES: int = 300
    DISABLE_AUTH: bool = True
    # MinIO
    MINIO_ENDPOINT: str = "localhost:9000"
    MINIO_ROOT_USER: str = "Administrator"
    MINIO_ROOT_PASSWORD: str = "Admin2000"
    MINIO_BUCKET: str = 'file-promotion'
    MINIO_SECURE: bool = False  # Set True for HTTPS

    class Config:
        env_file = ".env"


class amb_config(BaseSettings):
    
    getbarcode_url = "http://localhost/RequestBarcode"
    issue_api_url = "https://localhost/transaction/issue"
    deduct_api_url = "https://localhost.elb.amazonaws.com/transaction/deduct/v2"

    issue_deduct_x_api_key ='6owdLRnM9TgDWtF9y4AE7svEFJ6moPDUfDMTowvM'

    getbalance_get_url = "https://localhost/getbalance"
    getbalance_Authorization= 'Bearer eyjlv0VZ9lrDl8gPsYxxxxxx'
    inquery_url = "http://localhost/AllMemberInquiryProfile/InquiryProfile"
    class Config:
        env_file = ".env"

settings = Settings()
settings_amb = amb_config()


__All__ =['amd_setting','settings']

# %% [markdown]
# TABEL_LINE_LEFT = "thin"
# TABEL_LINE_RIGHT = "thin"
# TABEL_LINE_TOP = "thin"
# TABEL_LINE_BOTTOM = "thin"
# FONT_BARCODE = "Bar-Code 39"          # ชื่อฟอนต์ Barcode (สมมติ)
# FONT_NOMAL = "Anuphan"
# BACKGROUND_FONT_NOMAL = "Anuphan"
# HEARDER_FONT_SIZE = 30
# BACKGROUND_FONT_SIZE = 12
# BACKGROUND_COLOR = "000000"      # สีตัวอักษร Header
# HEARDER_COLOR = "DDDDDD"         # สีพื้นหลัง Header
# SOLID = "solid"
# BACKGROUND_WRAP_TEXT = True
# BACKGROUND_HORIZONTAL = "center"
# BACKGROUND_VERTICAL = "center"
# COLUMN_BARCODE_NAMES = ['BARCODE CODE39', 'COUPON CODE39']
# PRINT_SIZE_LEFT = 0.25     #1.9
# PRINT_SIZE_RIGHT = 0.25     #1.9
# PRINT_SIZE_TOP = 0.75     #2.5
# PRINT_SIZE_BOTTOM = 0.75     #2.5
# PRINT_SIZE_HEADER = 0.30     #1.3
# PRINT_SIZE_FOOTER = 0.30     #1.3
# PRINT_WIDTH = 1
# PRINT_HEIGT = 0
# PRINT_SCALE = 100
# WIDTH_COLUMN=[10,10,6.3,6.3,7.5,5.3,5.3,5.3,11,11,16.5,53,7.5,10,50,15.3,53,8.6,15,15,15,15]
# PRINT_TEXT_HEARDER_RIGHT = "&[Page] of &[Pages]"
# PRINT_TEXT_HEARDER_CENTER = "&[Tab]"
#
# ef get_export_files(
#     versionid: Optional[str] = Query(None, description="รหัส Version ID"),
#     fileid: Optional[str] = Query(None, description="รหัส File ID"),
#     db: Session = Depends(get_db)
# ):
#     """
#     API สำหรับดึงข้อมูลจาก vw_export_file
#     รองรับการค้นหาด้วย versionid และ fileid (หากไม่ส่งมา จะดึงข้อมูลทั้งหมด)
#     """
#     def clean_data(df: pd.DataFrame) -> pd.DataFrame:
#     # เติมค่าว่างด้วย string เปล่า และลบช่องว่างส่วนเกิน
#         df = df.fillna("")
#         df = df.map(lambda x: str(x).strip() if isinstance(x, str) else x)
#         return df
#
#     try:
#         # 1. สร้าง Base Query ตั้งต้น
#         query = db.query(VwExportFile)
#         if versionid:
#             query = query.filter(VwExportFile.version_id == versionid)
#
#         if fileid:
#             query = query.filter(VwExportFile.file_id == fileid)
#
#
#         df = pd.read_sql(query.statement, query.session.get_bind())
#
#         df = clean_data(df)
#         if df.empty:
#             return JSONResponse(status_code=403, content={"success": False, "message": "No data found."})
#         date_columns = ['Active From', 'Active To', 'OPTIMAL_DATE']
#
#         for col in date_columns:
#             if col in df.columns:
#                 df[col] = pd.to_datetime(df[col], errors='coerce')
#
#                 df[col] = df[col].apply(
#                     lambda x: x.strftime('%d/%m/%y') if pd.notnull(x) else ''
#                 )
#
#         df = df.astype(str)
#
#         sort_cols = [c for c in ["OPTIMAL_DATE", "WORKSHEET"] if c in df.columns]
#         if sort_cols:
#             df = df.sort_values(by=sort_cols)
#
#         output = io.BytesIO()
#         workbook = openpyxl.Workbook()
#         worksheet = workbook.active
#         worksheet.title = "Export_Data" # type: ignore
#
#         # 3. Define Styles
#         thin_border = Border(
#             left=Side(style=TABEL_LINE_LEFT),
#             right=Side(style=TABEL_LINE_RIGHT),
#             top=Side(style=TABEL_LINE_TOP),
#             bottom=Side(style=TABEL_LINE_BOTTOM)
#         )
#         thick_top_border = Border(
#             top=Side(style='thick'),
#             left=Side(style=TABEL_LINE_LEFT),
#             right=Side(style=TABEL_LINE_RIGHT),
#             bottom=Side(style=TABEL_LINE_BOTTOM)
#         )
#
#         barcode_font = Font(name=FONT_BARCODE, size=HEARDER_FONT_SIZE)
#         default_font = Font(name=FONT_NOMAL, size=BACKGROUND_FONT_SIZE)
#         header_font = Font(
#             name=BACKGROUND_FONT_NOMAL,
#             color=BACKGROUND_COLOR,
#             bold=True,
#             size=BACKGROUND_FONT_SIZE
#         )
#
#         light_grey_fill = PatternFill(start_color="E0E0E0", end_color="E0E0E0", fill_type="solid")
#         header_fill = PatternFill(start_color=HEARDER_COLOR, end_color=HEARDER_COLOR, fill_type=SOLID)
#         alignment_style = Alignment(wrap_text=BACKGROUND_WRAP_TEXT, horizontal=BACKGROUND_HORIZONTAL, vertical=BACKGROUND_VERTICAL)
#
#         # 4. Write Data (เขียนครั้งเดียวต่อยาวลงมา)
#         headers = list(df.columns)
#
#         # เขียน Header ที่บรรทัดที่ 1
#         worksheet.append(headers) # type: ignore
#
#         # เขียนข้อมูลทั้งหมด (ต่อยาวลงมา)
#         for row in df.itertuples(index=False):
#             worksheet.append(list(row)) # type: ignore
#
#         # 5. Formatting Logic (ทำทีเดียวทั้ง Sheet)
#         col_map = {name: i+1 for i, name in enumerate(headers)}
#         att_mode_idx = col_map.get("AttachmentMode")
#         barcode_col_indices = [col_map[c] for c in COLUMN_BARCODE_NAMES if c in col_map]
#
#         prev_first_col_val = None
#         max_col = worksheet.max_column # type: ignore
#
#         # เริ่ม Loop ตั้งแต่แถว 2 จนจบ
#         for r_idx, row_cells in enumerate(worksheet.iter_rows(min_row=2, max_col=max_col), start=2): # type: ignore
#             curr_first_col_val = row_cells[0].value
#
#             # เช็ค Attachment Mode (สีพื้นหลัง)
#             is_exclude = False
#             if att_mode_idx:
#                 att_val = row_cells[att_mode_idx - 1].value
#                 is_exclude = str(att_val).strip().upper() not in ["INCLUDE",""]
#
#             # Logic เส้นขอบ
#             current_border = thin_border
#             if r_idx == 2 or curr_first_col_val != prev_first_col_val:
#                 current_border = thick_top_border
#
#             prev_first_col_val = curr_first_col_val
#
#             # Apply Style ราย Cell
#             for c_idx, cell in enumerate(row_cells):
#                 cell_col_num = c_idx + 1
#
#                 cell.font = default_font
#                 cell.border = current_border
#                 cell.alignment = alignment_style
#
#                 if is_exclude:
#                     cell.fill = light_grey_fill
#
#                 if cell_col_num in barcode_col_indices:
#                     cell.font = barcode_font
#
#         # 6. Header Style & Widths
#         for i, col_name in enumerate(headers):
#             cell = worksheet.cell(row=1, column=i+1)  # type: ignore
#             cell.font = header_font
#             cell.fill = header_fill
#             cell.border = thin_border
#             cell.alignment = alignment_style
#
#             if i < len(WIDTH_COLUMN):
#                 worksheet.column_dimensions[get_column_letter(i+1)].width = WIDTH_COLUMN[i]  # type: ignore
#             else:
#                 worksheet.column_dimensions[get_column_letter(i+1)].width = 15  # type: ignore
#
#         # 7. Page Setup
#         worksheet.row_dimensions[1].height = 105  # type: ignore
#         worksheet.page_setup.paperSize = worksheet.PAPERSIZE_A3  # type: ignore
#         worksheet.page_setup.orientation = worksheet.ORIENTATION_LANDSCAPE  # type: ignore
#         worksheet.print_title_rows = "1:1"  # type: ignore
#         worksheet.oddHeader.center.text = PRINT_TEXT_HEARDER_CENTER  # type: ignore
#         worksheet.oddHeader.right.text = PRINT_TEXT_HEARDER_RIGHT  # type: ignore
#
#         # 8. Save & Return
#         workbook.save(output)
#         output.seek(0)
#         filename = f"Promotion_{datetime.now().strftime('%Y%m%d_%H%M')}.xlsx"
#
#         headers_http = {
#             'Content-Disposition': f'attachment; filename="{filename}"'
#         }
#
#         return StreamingResponse(
#             io.BytesIO(output.getvalue()),
#             media_type='application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#             headers=headers_http
#         )
#
#     except Exception as e:
#         print(f"Export Error: {e}")
#         return JSONResponse(status_code=500, content={"success": False, "message": str(e)})

# %%
# [Case 10] Validation DATA Length
print("\n[Case 10] Validation DATA_1 Length")
variations = [
    ("ความยาวมากกว่าเดิม", "6104274821" + "1"),
    ("ความยาวน้อยกว่าเดิม", "6104274821"[1:]),
    ("ความยาวเท่าเดิม", "6104274821"),
    ("ความยาวเป็น Null", "")
]

for desc, val in variations:
    print(f"\n---> ทดสอบ: {desc} (ค่า: '{val}')")
    ctx = get_base_context()
    ctx.data_1 = val
    api.data_exchange(ctx)
    if ctx.response_data.get('SUCCESS') == 'true':
        api.cancel(ctx)

# [Case 11] Validation Amount (ค่าต่ำสุด/สูงสุด)
print("\n[Case 11] Validation Amount")
amt_cases = [
    ("ค่าเงินเป็น null", ""),
    ("เงิน MIN", "1"),
    ("เงิน MAX", "30000"),
    ("เงินต่ำกว่า Min", "0"),
    ("เงินสูงกว่า MAX", "30001"),
    ("ทศนิยมไม่ลงตัว", "50.34"),
    ("ทศนิยมลงตัว", "50.50")
]

for desc, amt in amt_cases:
    print(f"\n---> ทดสอบ: {desc} (Amount: {amt})")
    ctx = get_base_context()
    ctx.bill_amt = amt
    api.data_exchange(ctx)
    if ctx.response_data.get('SUCCESS') == 'true':
        api.cancel(ctx)

# [Case 12] Validation FEE (ทดสอบ Zone)
print("\n[Case 12] Validation FEE (Zone & Amount)")
zones = ["1", "2"]
amounts = [("ขั้น 1", 50.0), ("ขั้น 2", 200.0)]

for z in zones:
    for step, amt in amounts:
        print(f"\n---> ทดสอบ: ZONE {z} | {step} จำนวนเงิน {amt} บาท")
        ctx = get_base_context()
        ctx.zone = z
        ctx.bill_amt = str(amt)
        api.data_exchange(ctx)
        if ctx.response_data.get('SUCCESS') == 'true':
            api.cancel(ctx)
# Out:
# [Case 10] Validation DATA_1 Length
#
# ---> ทดสอบ: ความยาวมากกว่าเดิม (ค่า: '61042748211')
#   SUCCESS CODE               DESCRIPTOR
# 0   false  123  ความยาวข้อมูลไม่ถูกต้อง
# ---> ทดสอบ: ความยาวน้อยกว่าเดิม (ค่า: '104274821')
#   SUCCESS CODE               DESCRIPTOR
# 0   false  123  ความยาวข้อมูลไม่ถูกต้อง
# ---> ทดสอบ: ความยาวเท่าเดิม (ค่า: '6104274821')
#   SUCCESS CODE               DESCRIPTOR
# 0   false  123  ความยาวข้อมูลไม่ถูกต้อง
# ---> ทดสอบ: ความยาวเป็น Null (ค่า: '')
#   SUCCESS CODE               DESCRIPTOR
# 0   false  123  ความยาวข้อมูลไม่ถูกต้อง
# [Case 11] Validation Amount
#
# ---> ทดสอบ: ค่าเงินเป็น null (Amount: )
#   SUCCESS CODE                        DESCRIPTOR
# 0   false  124  รับชำระจำนวนเงินขั้นต่ำ 1.00 บาท
# ---> ทดสอบ: เงิน MIN (Amount: 1)
#   SUCCESS CODE                                  DESCRIPTOR
# 0   false  999  ปัญหาไม่ได้จัดประเภท กรุณาติดต่อ Help desk
# ---> ทดสอบ: เงิน MAX (Amount: 30000)
# ...
