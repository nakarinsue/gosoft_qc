# %%
from CS.Lib.GlobalConfig import DataStore
from CS.FormatXml import XMLFormatter
from CS.Lib._ConStant import Action 
URLS = "http://qacspos-temp.counterservice.co.th:80/DCWSCDSONLINE/WSCDSService"
data = DataStore()
xmls = XMLFormatter(DataStore)

# %%
data.update("Data1",'0994000160151')

# %%
data.get_current()
# Out:
# {'FUNTION': 'INITIAL',
#  'SUCCESS': '',
#  'CODE': '',
#  'DESCRIPTOR': '',
#  'STORE_ID': '09884',
#  'MACHINE_ID': '3',
#  'VENDOR_CODE': '',
#  'SERVICE_ID': '',
#  'VENDOR_ID': '',
#  'ITEM_NAME': '',
#  'COMMON_TX_ID': '53',
#  'SHIFT_ID': '2',
#  'TX_TYPE': 'N',
#  'ITEM_SELECTIC': 'N',
#  'PAYMENT_TYPE': '001',
#  'ZONE': 1,
#  'EMPLOYEE_ID': '6765696',
#  'POS_TAX_ID': '0240476246377',
#  'RECEIPT_NO': '226',
#  'RECEIPT_TYPE': 'H',
#  'PAYMENT_CHANNEL': 'C05',
#  'PRINTSLIP': '',
#  'BILL_AMT_ABOVE_MAX': 90001,
#  'BILL_AMT_MAX': 90000,
#  'BILL_AMT_CENTER': 49000,
#  'BILL_AMT_MIN': 1,
#  'BILL_AMT_BELOW_MIN': 0,
#  'BILL_AMT_NULL': '',
#  'BILL_AMT_ZERO': 0,
#  'BILL_AMT_DECIMAL': 0,
#  'BILL_AMT_NON_DECIMAL': 0,
#  'BILL_AMT_EDIT': 0,
#  'BILL_AMT': 0,
#  'BILL_AMT_ROUND': 0,
#  'BILL_AMT_VAT': 0,
#  'FEE': '',
#  'FEE_VAT': '',
#  'CUSTOMER_NAME': 'พิชาภพ',
#  'CUSTOMER_ADDR_1': '50 ถ.ธูปหอม ต.บึงเปือยใหญ่ใหญ่ จ.ลำพูน 67930',
# ...

# %%
data.update("Data1",'2412412412')

# %%
data.save('dataexchange')

# %%
data.get_save_value('dataexchange')
# Out:
# {'FUNTION': 'INITIAL',
#  'SUCCESS': '',
#  'CODE': '',
#  'DESCRIPTOR': '',
#  'STORE_ID': '09884',
#  'MACHINE_ID': '3',
#  'VENDOR_CODE': '',
#  'SERVICE_ID': '',
#  'VENDOR_ID': '',
#  'ITEM_NAME': '',
#  'COMMON_TX_ID': '53',
#  'SHIFT_ID': '2',
#  'TX_TYPE': 'N',
#  'ITEM_SELECTIC': 'N',
#  'PAYMENT_TYPE': '001',
#  'ZONE': 1,
#  'EMPLOYEE_ID': '6765696',
#  'POS_TAX_ID': '0240476246377',
#  'RECEIPT_NO': '226',
#  'RECEIPT_TYPE': 'H',
#  'PAYMENT_CHANNEL': 'C05',
#  'PRINTSLIP': '',
#  'BILL_AMT_ABOVE_MAX': 90001,
#  'BILL_AMT_MAX': 90000,
#  'BILL_AMT_CENTER': 49000,
#  'BILL_AMT_MIN': 1,
#  'BILL_AMT_BELOW_MIN': 0,
#  'BILL_AMT_NULL': '',
#  'BILL_AMT_ZERO': 0,
#  'BILL_AMT_DECIMAL': 0,
#  'BILL_AMT_NON_DECIMAL': 0,
#  'BILL_AMT_EDIT': 0,
#  'BILL_AMT': 0,
#  'BILL_AMT_ROUND': 0,
#  'BILL_AMT_VAT': 0,
#  'FEE': '',
#  'FEE_VAT': '',
#  'CUSTOMER_NAME': 'พิชาภพ',
#  'CUSTOMER_ADDR_1': '50 ถ.ธูปหอม ต.บึงเปือยใหญ่ใหญ่ จ.ลำพูน 67930',
# ...

# %%
xmls.build(Action.DATAEXCHANGE.value())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 xmls.build(Action.DATAEXCHANGE.value())
#
# NameError: name 'Action' is not defined

# %%
Minutes=00
Hours=3
def setData():
    Data = DATA(DATA_1='500221016800003595',DATA_2='080368141060001746',DATA_3=10)        # GenData
    # Data.setonlineTx(Minutes=Minutes,Hours=Hours)
    Data.setStore_ID("09882")
    Data.setBAMT(BILL_AMT="80",AMTmax="49000",AMTmin="1")
    Data.setVENDOR_ID("0994000160151")
    Data.setSERVICE_ID("02")
    Data.settime(Minutes,Hours,1)
    DaTa1 = (list(Data.sum()))          
    respron = Respron(DaTa1,URL)   
    return Data,DaTa1,respron
Data,DaTa1,respron = setData()
Databas()

DaTa1 = []
