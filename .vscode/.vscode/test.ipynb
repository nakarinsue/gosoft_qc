# %%
import openpyxl
from typing import Dict, List
import pandas as pd
storage_options = {
    'key': 'Administrator',
    'secret': 'Admin2000',
    'client_kwargs': {'endpoint_url': f'http://localhost:9000'}
}

class ExcelImportManager:
    @staticmethod
    def get_sheet_visibility(file_path: str) -> Dict[str, List[str]]:
        wb = openpyxl.load_workbook(file_path, read_only=True)
        
        visible_sheets = []
        hidden_sheets = []
        
        for sheet in wb.worksheets:
            if sheet.sheet_state == 'visible':
                visible_sheets.append(sheet.title)
            else:
                hidden_sheets.append(sheet.title)
                
        wb.close()
        
        return {
            'visible': visible_sheets,
            'hidden': hidden_sheets
        }

    @staticmethod
    def read_only_visible_sheets(file_path: str) -> Dict[str, pd.DataFrame]:
        sheet_info = ExcelImportManager.get_sheet_visibility(file_path)
        visible_sheet_names = sheet_info['visible']
        data_frames = pd.read_excel(file_path, storage_options=storage_options, sheet_name=visible_sheet_names, dtype=str)

        data_frames = pd.read_excel(file_path, sheet_name=visible_sheet_names)
        
        return data_frames

# %%
import openpyxl
import pandas as pd
import io
from typing import Dict, List, Union
from urllib.parse import urlparse
import boto3
from botocore.client import Config

# ---------------------------------------------------------
# 1. ส่วนทดสอบการเชื่อมต่อ MinIO
# ---------------------------------------------------------
s3_test = boto3.client('s3', 
                  endpoint_url='http://localhost:9000', 
                  aws_access_key_id='Administrator', 
                  aws_secret_access_key='Admin2000',
                  config=Config(signature_version='s3v4'))

response = s3_test.list_buckets()
print('✅ เชื่อมต่อ MinIO สำเร็จ! นี่คือ Bucket ที่มีอยู่:')
for bucket in response['Buckets']:
    print(f' - {bucket['Name']}')

# ---------------------------------------------------------
# 2. คลาสจัดการ Excel
# ---------------------------------------------------------
class ExcelImportManager:
    @staticmethod
    def _get_file_stream(file_path: str) -> Union[str, io.BytesIO]:
        '''ฟังก์ชันดึงข้อมูลไฟล์รองรับ Local และ MinIO'''
        if file_path.startswith('s3://'):
            parsed_url = urlparse(file_path)
            bucket_name = parsed_url.netloc
            object_key = parsed_url.path.lstrip('/')
            
            # 📍 แก้ไข: ย้าย Config ของ MinIO เข้ามาไว้ในนี้ด้วย
            s3 = boto3.client('s3', 
                              endpoint_url='http://localhost:9000', 
                              aws_access_key_id='Administrator', 
                              aws_secret_access_key='Admin2000',
                              config=Config(signature_version='s3v4'))
                              
            obj = s3.get_object(Bucket=bucket_name, Key=object_key)
            file_stream = io.BytesIO(obj['Body'].read())
            file_stream.seek(0) # รีเซ็ต Cursor
            return file_stream
        
        return file_path

    @staticmethod
    def get_sheet_visibility(file_path: str) -> Dict[str, List[str]]:
        file_stream = ExcelImportManager._get_file_stream(file_path)
        
        wb = openpyxl.load_workbook(file_stream, data_only=True)
        
        visible_sheets = []
        hidden_sheets = []
        
        for sheet in wb.worksheets:
            if sheet.sheet_state == 'visible':
                visible_sheets.append(sheet.title)
            else:
                hidden_sheets.append(sheet.title)
                
        wb.close()
        return {'visible': visible_sheets, 'hidden': hidden_sheets}

    @staticmethod
    def read_only_visible_sheets(file_path: str) -> Dict[str, pd.DataFrame]:
        sheet_info = ExcelImportManager.get_sheet_visibility(file_path)
        visible_sheet_names = sheet_info['visible']
        
        file_stream = ExcelImportManager._get_file_stream(file_path)
        
        # ให้ Pandas อ่านเฉพาะ Sheet ที่กำหนด
        data_frames = pd.read_excel(file_stream, sheet_name=visible_sheet_names)
        
        return data_frames

# ---------------------------------------------------------
# 3. เรียกใช้งาน
# ---------------------------------------------------------
if __name__ == '__main__':
    file_path = 's3://promotion-files/20260307/00/ธันวาคม 2568 Corporate -ซื้อครบรับฟรีพรีเมียม - Pook.xlsx'
    
    print('\n⏳ กำลังดึงข้อมูลและแยก Sheet...')
    sheet_info = ExcelImportManager.get_sheet_visibility(file_path)
    print(f'✅ Sheet ที่แสดงอยู่: {sheet_info['visible']}')
    print(f'❌ Sheet ที่ซ่อนอยู่: {sheet_info['hidden']}')

    print('\n⏳ กำลังแปลงเป็น DataFrame...')
    data_frames = ExcelImportManager.read_only_visible_sheets(file_path)

    for sheet_name, df in data_frames.items():
        print(f'\n--- ข้อมูลจาก Sheet: {sheet_name} ---')
        print(df.head())
# Out:
# ✅ เชื่อมต่อ MinIO สำเร็จ! นี่คือ Bucket ที่มีอยู่:
#  - bucket-promotion
#  - default-bucket
#  - localhost
#  - promotion
#  - promotion-bucket
#  - promotion-files
#
# ⏳ กำลังดึงข้อมูลและแยก Sheet...
# ✅ Sheet ที่แสดงอยู่: ['          Excel_Report         ']
# ❌ Sheet ที่ซ่อนอยู่: []
#
# ⏳ กำลังแปลงเป็น DataFrame...
#
# --- ข้อมูลจาก Sheet:           Excel_Report          ---
#    Promotion Code       Receipt Promotion Name  \
# 0          298268  ฟรีCalendarCardพี่จองคัลแลน
# 1          298268  ฟรีCalendarCardพี่จองคัลแลน
# 2          298268  ฟรีCalendarCardพี่จองคัลแลน
# 3          298268  ฟรีCalendarCardพี่จองคัลแลน
# 4          298268  ฟรีCalendarCardพี่จองคัลแลน
#
#                    Promotion Name   Promotion Type    Group Name Active From  \
# 0  ครบ150บ.ขึ้นไป ฟรีCalendarCard  Multi Condition  ฟรีพรีเมี่ยม  15/12/2025
# 1  ครบ150บ.ขึ้นไป ฟรีCalendarCard  Multi Condition  ฟรีพรีเมี่ยม  15/12/2025
# 2  ครบ150บ.ขึ้นไป ฟรีCalendarCard  Multi Condition  ฟรีพรีเมี่ยม  15/12/2025
# 3  ครบ150บ.ขึ้นไป ฟรีCalendarCard  Multi Condition  ฟรีพรีเมี่ยม  15/12/2025
# 4  ครบ150บ.ขึ้นไป ฟรีCalendarCard  Multi Condition  ฟรีพรีเมี่ยม  15/12/2025
#
#     Active To  Redemption Limit Per Transaction  Redemption Limit Per Day  \
# 0  15/01/2026                                 1                       NaN
# 1  15/01/2026                                 1                       NaN
# 2  15/01/2026                                 1                       NaN
# 3  15/01/2026                                 1                       NaN
# 4  15/01/2026                                 1                       NaN
#
#    Maximum Redemption Limit  ...                                 Entity Name  \
# 0                       NaN  ...                              CounterService
# 1                       NaN  ...                                  24SHOPPING
# 2                       NaN  ...          7-11สินค้าไม่คำนวณแจกSKU (แลกซื้อ)
# 3                       NaN  ...                   7-11สินค้าถุงผ้า ถุงทนทาน
# 4                       NaN  ...  7-11สินค้ายกเว้นไม่คำนวณแจกPMA ( แลกซื้อ )
#
#   Condition MA ID  Condition MA Name LevelID Reward Type Reward Value  \
# 0             NaN                NaN       1    FreeItem          NaN
# 1             NaN                NaN       1    FreeItem          NaN
# 2             NaN                NaN       1    FreeItem          NaN
# 3             NaN                NaN       1    FreeItem          NaN
# 4             NaN                NaN       1    FreeItem          NaN
#
#    Reward MA ID Reward MA Name  External Id  \
# 0           NaN            NaN          NaN
# 1           NaN            NaN          NaN
# 2           NaN            NaN          NaN
# 3           NaN            NaN          NaN
# 4           NaN            NaN          NaN
#
#                                                Notes
# 0  *เฉพาะ All Member ซื้อสินค้าครบ 150บาท ขึ้นไป/...
# 1  *เฉพาะ All Member ซื้อสินค้าครบ 150บาท ขึ้นไป/...
# 2  *เฉพาะ All Member ซื้อสินค้าครบ 150บาท ขึ้นไป/...
# 3  *เฉพาะ All Member ซื้อสินค้าครบ 150บาท ขึ้นไป/...
# 4  *เฉพาะ All Member ซื้อสินค้าครบ 150บาท ขึ้นไป/...
#
# [5 rows x 32 columns]

# %%
import os 
os.environ['MINIO_ENDPOINT'] = 'http://localhost:9000'
os.environ['MINIO_ROOT_USER'] = 'Administrator' # ตัวอย่าง Access Key
os.environ['MINIO_ROOT_PASSWORD'] = 'Admin2000' # ตัวอย่าง Secret Key
file_path = 's3://promotion-files/20260307/00/ธันวาคม 2568 Corporate -ซื้อครบรับฟรีพรีเมียม - Pook.xlsx'

# โค้ดที่เหลือเรียกเหมือนเดิมเป๊ะครับ
data_frames = ExcelImportManager.read_only_visible_sheets(file_path)
for sheet_name, df in data_frames.items():
    print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[11], line 8
#       5 file_path = "s3://promotion-files/20260307/00/ธันวาคม 2568 Corporate -ซื้อครบรับฟรีพรีเมียม - Pook.xlsx"
#       7 # โค้ดที่เหลือเรียกเหมือนเดิมเป๊ะครับ
# ----> 8 data_frames = ExcelImportManager.read_only_visible_sheets(file_path)
#       9 for sheet_name, df in data_frames.items():
#      10     print(df.head())
#
# Cell In[10], line 60, in ExcelImportManager.read_only_visible_sheets(file_path)
#      57 @staticmethod
#      58 def read_only_visible_sheets(file_path: str) -> Dict[str, pd.DataFrame]:
#      59     # 1. หาชื่อ Sheet ที่ไม่ถูกซ่อน
# ---> 60     sheet_info = ExcelImportManager.get_sheet_visibility(file_path)
#      61     visible_sheet_names = sheet_info["visible"]
#      63     # 2. ดึง Stream อีกรอบสำหรับ Pandas
#
# Cell In[10], line 40, in ExcelImportManager.get_sheet_visibility(file_path)
#      38 @staticmethod
#      39 def get_sheet_visibility(file_path: str) -> Dict[str, List[str]]:
# ---> 40     file_stream = ExcelImportManager._get_file_stream(file_path)
#      42     # ถ้าเป็น BytesIO (จาก S3) ไม่ต้องใช้ read_only=True เพราะข้อมูลอยู่ใน Memory แล้ว
#      43     wb = openpyxl.load_workbook(file_stream, data_only=True)
#
# Cell In[10], line 31, in ExcelImportManager._get_file_stream(file_path)
#      28 object_key = parsed_url.path.lstrip('/')
#      30 s3 = boto3.client('s3') # จำเป็นต้องตั้งค่า AWS Credentials ไว้ในระบบแล้ว
# ---> 31 obj = s3.get_object(Bucket=bucket_name, Key=object_key)
#      32 file_stream = io.BytesIO(obj['Body'].read())
#      33 return file_stream
#
# File d:\gosoft_qc\.venv\Lib\site-packages\botocore\client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File d:\gosoft_qc\.venv\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File d:\gosoft_qc\.venv\Lib\site-packages\botocore\client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1074     error_code = request_context.get(
#    1075         'error_code_override'
#    1076     ) or error_info.get("Code")
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#    1080     return parsed_response
#
# ClientError: An error occurred (InvalidAccessKeyId) when calling the GetObject operation: The AWS Access Key Id you provided does not exist in our records.

# %%
import psutil
import time

def monitor_system_load():
    print(f"{'Time':<10} | {'CPU %':<10} | {'RAM %':<10} | {'Top Process'}")
    print("-" * 50)
    
    try:
        while True:
            # ดึงค่า CPU และ RAM
            cpu_usage = psutil.cpu_percent(interval=1)
            ram_usage = psutil.virtual_memory().percent
            
            # หา Process ที่กินทรัพยากรสูงสุด
            processes = sorted(psutil.process_iter(['name', 'cpu_percent']), 
                               key=lambda x: x.info['cpu_percent'], reverse=True)
            top_proc = processes[0].info['name'] if processes else "N/A"
            
            current_time = time.strftime("%H:%M:%S")
            print(f"{current_time:<10} | {cpu_usage:<10}% | {ram_usage:<10}% | {top_proc}")
            
            # กรณี CPU สูงเกิน 80% ให้แจ้งเตือน (Potential Overheating)
            if cpu_usage > 80:
                print(f"--- [WARNING] High Load detected from: {top_proc} ---")
                
            time.sleep(2)
    except KeyboardInterrupt:
        print("\nStop Monitoring.")

if __name__ == "__main__":
    # ติดตั้ง Library ก่อนใช้งาน: pip install psutil
    monitor_system_load()
# Out:
# Time       | CPU %      | RAM %      | Top Process
# --------------------------------------------------
# 20:07:26   | 29.8      % | 89.3      % | System Idle Process
# 20:07:29   | 25.0      % | 89.2      % | System Idle Process
# 20:07:32   | 34.1      % | 89.0      % | System Idle Process
# 20:07:35   | 40.1      % | 89.4      % | System Idle Process
# 20:07:38   | 33.1      % | 89.1      % | System Idle Process
# 20:07:41   | 29.3      % | 88.6      % | System Idle Process
# 20:07:45   | 24.1      % | 88.7      % | System Idle Process
# 20:07:48   | 20.7      % | 88.6      % | System Idle Process
# 20:07:51   | 16.5      % | 88.6      % | System Idle Process
# 20:07:54   | 22.9      % | 88.7      % | System Idle Process
# 20:07:57   | 25.6      % | 88.9      % | System Idle Process
# 20:08:00   | 24.0      % | 88.9      % | System Idle Process
# 20:08:03   | 19.6      % | 89.0      % | System Idle Process
# 20:08:06   | 18.7      % | 89.0      % | System Idle Process
# 20:08:09   | 20.2      % | 89.0      % | System Idle Process
# 20:08:12   | 26.3      % | 89.2      % | System Idle Process
# 20:08:15   | 26.3      % | 89.4      % | System Idle Process
# 20:08:18   | 21.4      % | 89.2      % | System Idle Process
# 20:08:21   | 17.1      % | 89.2      % | System Idle Process
# 20:08:24   | 30.1      % | 89.4      % | System Idle Process
# 20:08:27   | 25.2      % | 89.2      % | System Idle Process
# 20:08:30   | 20.0      % | 89.3      % | System Idle Process
# 20:08:33   | 20.2      % | 89.4      % | System Idle Process
# 20:08:36   | 22.1      % | 89.3      % | System Idle Process
# 20:08:39   | 24.3      % | 89.3      % | System Idle Process
# 20:08:42   | 23.5      % | 89.4      % | System Idle Process
# 20:08:45   | 20.2      % | 89.5      % | System Idle Process
# 20:08:49   | 19.3      % | 88.9      % | System Idle Process
# 20:08:52   | 36.3      % | 89.5      % | System Idle Process
# 20:08:55   | 29.3      % | 89.7      % | System Idle Process
# 20:08:58   | 29.7      % | 88.9      % | System Idle Process
# 20:09:01   | 25.2      % | 88.9      % | System Idle Process
# 20:09:04   | 40.6      % | 89.2      % | System Idle Process
# 20:09:07   | 27.3      % | 89.1      % | System Idle Process
# 20:09:10   | 18.7      % | 89.1      % | System Idle Process
# 20:09:13   | 47.0      % | 89.2      % | System Idle Process
# 20:09:16   | 20.0      % | 89.2      % | System Idle Process
# 20:09:19   | 31.4      % | 89.1      % | System Idle Process
# 20:09:22   | 37.2      % | 88.8      % | System Idle Process
# 20:09:25   | 26.5      % | 89.2      % | System Idle Process
# 20:09:28   | 42.3      % | 89.7      % | System Idle Process
# 20:09:31   | 27.4      % | 89.7      % | System Idle Process
# 20:09:34   | 49.3      % | 89.9      % | System Idle Process
# 20:09:37   | 39.7      % | 89.9      % | System Idle Process
# 20:09:40   | 43.3      % | 90.3      % | System Idle Process
# 20:09:43   | 36.6      % | 90.9      % | System Idle Process
# 20:09:46   | 49.1      % | 91.0      % | System Idle Process
# 20:09:49   | 20.9      % | 90.9      % | System Idle Process
# 20:09:52   | 27.8      % | 91.0      % | System Idle Process
# 20:09:56   | 22.3      % | 91.1      % | System Idle Process
# 20:09:59   | 30.7      % | 91.1      % | System Idle Process
# 20:10:02   | 25.0      % | 90.8      % | System Idle Process
# 20:10:05   | 25.2      % | 90.9      % | System Idle Process
# 20:10:08   | 27.6      % | 90.9      % | System Idle Process
# 20:10:11   | 23.4      % | 91.0      % | System Idle Process
# 20:10:14   | 36.6      % | 91.2      % | System Idle Process
# 20:10:17   | 45.5      % | 90.1      % | System Idle Process
# 20:10:20   | 33.4      % | 89.6      % | System Idle Process
# 20:10:23   | 37.1      % | 89.9      % | System Idle Process
# 20:10:26   | 47.5      % | 90.3      % | System Idle Process
# 20:10:29   | 40.0      % | 90.3      % | System Idle Process
# 20:10:32   | 54.3      % | 90.8      % | System Idle Process
# 20:10:35   | 58.5      % | 91.2      % | System Idle Process
# 20:10:38   | 55.0      % | 91.1      % | System Idle Process
# 20:10:41   | 32.7      % | 91.0      % | System Idle Process
# 20:10:44   | 31.5      % | 90.8      % | System Idle Process
# 20:10:48   | 21.3      % | 90.6      % | System Idle Process
# 20:10:51   | 20.1      % | 90.7      % | System Idle Process
# 20:10:54   | 36.1      % | 90.8      % | System Idle Process
# 20:10:57   | 24.6      % | 90.7      % | System Idle Process
# 20:11:00   | 21.6      % | 90.6      % | System Idle Process
# 20:11:03   | 21.8      % | 90.8      % | System Idle Process
# 20:11:06   | 21.8      % | 90.7      % | System Idle Process
# 20:11:09   | 23.1      % | 90.8      % | System Idle Process
# 20:11:12   | 18.3      % | 90.8      % | System Idle Process
# 20:11:15   | 41.4      % | 91.0      % | System Idle Process
# 20:11:18   | 25.8      % | 90.9      % | System Idle Process
# 20:11:21   | 23.5      % | 91.0      % | System Idle Process
# 20:11:24   | 35.5      % | 91.1      % | System Idle Process
# 20:11:27   | 26.0      % | 91.0      % | System Idle Process
# 20:11:30   | 47.3      % | 91.5      % | System Idle Process
# 20:11:33   | 31.2      % | 91.8      % | System Idle Process
# 20:11:36   | 40.4      % | 91.5      % | System Idle Process
# 20:11:39   | 20.3      % | 91.4      % | System Idle Process
# 20:11:42   | 29.8      % | 91.3      % | System Idle Process
# 20:11:45   | 21.6      % | 91.5      % | System Idle Process
# 20:11:49   | 29.8      % | 91.3      % | System Idle Process
# 20:11:52   | 31.2      % | 91.4      % | System Idle Process
# 20:11:55   | 32.7      % | 91.5      % | System Idle Process
# 20:11:58   | 25.6      % | 91.3      % | System Idle Process
# 20:12:01   | 23.7      % | 91.3      % | System Idle Process
# 20:12:04   | 47.2      % | 91.3      % | System Idle Process
# 20:12:07   | 41.8      % | 91.3      % | System Idle Process
# 20:12:10   | 23.4      % | 91.4      % | System Idle Process
# 20:12:13   | 32.8      % | 91.2      % | System Idle Process
# 20:12:16   | 53.3      % | 90.5      % | System Idle Process
# 20:12:19   | 42.0      % | 87.1      % | System Idle Process
# 20:12:23   | 46.2      % | 85.8      % | System Idle Process
# 20:12:26   | 45.6      % | 84.3      % | System Idle Process
# 20:12:29   | 37.6      % | 83.2      % | System Idle Process
# 20:12:32   | 21.7      % | 83.3      % | System Idle Process
# 20:12:35   | 58.5      % | 83.5      % | System Idle Process
# 20:12:38   | 45.2      % | 83.3      % | System Idle Process
# 20:12:41   | 28.3      % | 83.4      % | System Idle Process
# 20:12:44   | 39.4      % | 83.4      % | System Idle Process
# 20:12:47   | 26.7      % | 83.3      % | System Idle Process
# 20:12:50   | 21.5      % | 83.2      % | System Idle Process
# 20:12:53   | 22.3      % | 83.2      % | System Idle Process
# 20:12:56   | 18.0      % | 83.2      % | System Idle Process
# 20:13:00   | 33.5      % | 83.2      % | System Idle Process
# 20:13:03   | 43.3      % | 83.6      % | System Idle Process
# 20:13:06   | 53.4      % | 84.9      % | System Idle Process
#
# Stop Monitoring.

# %%
import psutil
import os
import time

def monitor_ram_usage():
    # มาตรฐานการตรวจสอบระดับ Enterprise
    THRESHOLD_MB = 500  # ตั้งค่าแจ้งเตือนถ้ากิน RAM เกิน 500MB
    
    print(f"{'PID':<10} | {'Process Name':<25} | {'Memory (MB)':<15} | {'Status'}")
    print("-" * 65)

    try:
        while True:
            # ดึงข้อมูลทุุก Process และคำนวณ Memory (Resident Set Size)
            proc_list = []
            for proc in psutil.process_iter(['pid', 'name', 'memory_info']):
                try:
                    mem_mb = proc.info['memory_info'].rss / (1024 * 1024)
                    proc_list.append({
                        'pid': proc.info['pid'],
                        'name': proc.info['name'],
                        'mem_mb': mem_mb
                    })
                except (psutil.NoSuchProcess, psutil.AccessDenied):
                    continue

            # เรียงลำดับตามการใช้ RAM จากมากไปน้อย
            top_10 = sorted(proc_list, key=lambda x: x['mem_mb'], reverse=True)[:10]

            # ล้างหน้าจอ (สำหรับ Windows)
            os.system('cls' if os.name == 'nt' else 'clear')
            print(f"System RAM Usage: {psutil.virtual_memory().percent}%")
            print(f"{'PID':<10} | {'Process Name':<25} | {'Memory (MB)':<15} | {'Status'}")
            print("-" * 65)

            for p in top_10:
                status = "!!! DANGER !!!" if p['mem_mb'] > THRESHOLD_MB else "Normal"
                print(f"{p['pid']:<10} | {p['name']:<25} | {p['mem_mb']:<15.2f} | {status}")

            time.sleep(3) # อัปเดตทุก 3 วินาที
            
    except KeyboardInterrupt:
        print("\nExit Monitoring.")

if __name__ == "__main__":
    monitor_ram_usage()
# Out:
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# System RAM Usage: 95.1%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4487.54         | !!! DANGER !!!
# 23200      | Code.exe                  | 530.13          | !!! DANGER !!!
# 25028      | Code.exe                  | 350.52          | Normal
# 18276      | Code.exe                  | 235.53          | Normal
# 26188      | chrome.exe                | 235.45          | Normal
# 10520      | chrome.exe                | 213.05          | Normal
# 7004       | Code.exe                  | 208.22          | Normal
# 23448      | Docker Desktop.exe        | 184.59          | Normal
# 29600      | chrome.exe                | 179.55          | Normal
# 27016      | com.docker.backend.exe    | 158.39          | Normal
# System RAM Usage: 96.1%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4607.11         | !!! DANGER !!!
# 23200      | Code.exe                  | 530.13          | !!! DANGER !!!
# 25028      | Code.exe                  | 347.21          | Normal
# 18276      | Code.exe                  | 237.57          | Normal
# 26188      | chrome.exe                | 235.45          | Normal
# 10520      | chrome.exe                | 213.05          | Normal
# 7004       | Code.exe                  | 209.23          | Normal
# 23448      | Docker Desktop.exe        | 184.54          | Normal
# 29600      | chrome.exe                | 179.55          | Normal
# 27016      | com.docker.backend.exe    | 160.20          | Normal
# System RAM Usage: 96.6%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4718.71         | !!! DANGER !!!
# 23200      | Code.exe                  | 530.87          | !!! DANGER !!!
# 25028      | Code.exe                  | 353.32          | Normal
# 18276      | Code.exe                  | 237.07          | Normal
# 26188      | chrome.exe                | 235.45          | Normal
# 7004       | Code.exe                  | 221.38          | Normal
# 10520      | chrome.exe                | 213.05          | Normal
# 23448      | Docker Desktop.exe        | 184.62          | Normal
# 29600      | chrome.exe                | 179.55          | Normal
# 27016      | com.docker.backend.exe    | 160.25          | Normal
# System RAM Usage: 96.6%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4729.57         | !!! DANGER !!!
# 23200      | Code.exe                  | 530.91          | !!! DANGER !!!
# 25028      | Code.exe                  | 351.02          | Normal
# 18276      | Code.exe                  | 236.05          | Normal
# 26188      | chrome.exe                | 235.45          | Normal
# 10520      | chrome.exe                | 213.05          | Normal
# 7004       | Code.exe                  | 193.30          | Normal
# 23448      | Docker Desktop.exe        | 184.62          | Normal
# 29600      | chrome.exe                | 179.55          | Normal
# 27016      | com.docker.backend.exe    | 160.32          | Normal
# System RAM Usage: 95.3%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4735.88         | !!! DANGER !!!
# 23200      | Code.exe                  | 441.65          | Normal
# 25028      | Code.exe                  | 327.89          | Normal
# 26188      | chrome.exe                | 222.15          | Normal
# 10520      | chrome.exe                | 212.64          | Normal
# 18276      | Code.exe                  | 192.08          | Normal
# 29600      | chrome.exe                | 179.18          | Normal
# 23448      | Docker Desktop.exe        | 172.67          | Normal
# 7004       | Code.exe                  | 170.79          | Normal
# 27016      | com.docker.backend.exe    | 158.30          | Normal
# System RAM Usage: 94.3%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4733.35         | !!! DANGER !!!
# 23200      | Code.exe                  | 441.65          | Normal
# 25028      | Code.exe                  | 319.17          | Normal
# 4900       | MemCompression            | 234.41          | Normal
# 26188      | chrome.exe                | 222.15          | Normal
# 10520      | chrome.exe                | 212.64          | Normal
# 18276      | Code.exe                  | 192.77          | Normal
# 29600      | chrome.exe                | 179.18          | Normal
# 23448      | Docker Desktop.exe        | 169.01          | Normal
# 7004       | Code.exe                  | 159.07          | Normal
# System RAM Usage: 94.2%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4726.25         | !!! DANGER !!!
# 23200      | Code.exe                  | 441.72          | Normal
# 25028      | Code.exe                  | 318.83          | Normal
# 4900       | MemCompression            | 234.76          | Normal
# 26188      | chrome.exe                | 222.15          | Normal
# 10520      | chrome.exe                | 212.64          | Normal
# 18276      | Code.exe                  | 194.30          | Normal
# 29600      | chrome.exe                | 179.18          | Normal
# 23448      | Docker Desktop.exe        | 169.52          | Normal
# 27016      | com.docker.backend.exe    | 158.27          | Normal
# System RAM Usage: 94.6%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4726.20         | !!! DANGER !!!
# 23200      | Code.exe                  | 441.73          | Normal
# 25028      | Code.exe                  | 321.70          | Normal
# 4900       | MemCompression            | 250.03          | Normal
# 26188      | chrome.exe                | 222.16          | Normal
# 10520      | chrome.exe                | 212.64          | Normal
# 18276      | Code.exe                  | 193.27          | Normal
# 29600      | chrome.exe                | 179.18          | Normal
# 27016      | com.docker.backend.exe    | 173.45          | Normal
# 23448      | Docker Desktop.exe        | 169.52          | Normal
# System RAM Usage: 95.0%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4814.58         | !!! DANGER !!!
# 23200      | Code.exe                  | 441.73          | Normal
# 25028      | Code.exe                  | 322.13          | Normal
# 4900       | MemCompression            | 249.37          | Normal
# 26188      | chrome.exe                | 222.17          | Normal
# 10520      | chrome.exe                | 212.64          | Normal
# 18276      | Code.exe                  | 192.40          | Normal
# 29600      | chrome.exe                | 179.18          | Normal
# 27016      | com.docker.backend.exe    | 173.58          | Normal
# 23448      | Docker Desktop.exe        | 169.66          | Normal
# System RAM Usage: 95.1%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4812.15         | !!! DANGER !!!
# 23200      | Code.exe                  | 441.74          | Normal
# 25028      | Code.exe                  | 321.85          | Normal
# 4900       | MemCompression            | 254.05          | Normal
# 26188      | chrome.exe                | 222.17          | Normal
# 10520      | chrome.exe                | 212.64          | Normal
# 18276      | Code.exe                  | 192.18          | Normal
# 29600      | chrome.exe                | 179.20          | Normal
# 27016      | com.docker.backend.exe    | 173.59          | Normal
# 23448      | Docker Desktop.exe        | 169.59          | Normal
# System RAM Usage: 95.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4823.17         | !!! DANGER !!!
# 23200      | Code.exe                  | 441.80          | Normal
# 25028      | Code.exe                  | 324.26          | Normal
# 4900       | MemCompression            | 264.56          | Normal
# 26188      | chrome.exe                | 222.17          | Normal
# 10520      | chrome.exe                | 212.64          | Normal
# 18276      | Code.exe                  | 193.93          | Normal
# 29600      | chrome.exe                | 192.90          | Normal
# 27016      | com.docker.backend.exe    | 184.30          | Normal
# 23448      | Docker Desktop.exe        | 167.47          | Normal
# System RAM Usage: 96.1%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4881.24         | !!! DANGER !!!
# 23200      | Code.exe                  | 441.80          | Normal
# 25028      | Code.exe                  | 326.00          | Normal
# 4900       | MemCompression            | 265.21          | Normal
# 26188      | chrome.exe                | 222.20          | Normal
# 10520      | chrome.exe                | 204.43          | Normal
# 29600      | chrome.exe                | 196.57          | Normal
# 18276      | Code.exe                  | 194.83          | Normal
# 27016      | com.docker.backend.exe    | 187.40          | Normal
# 23448      | Docker Desktop.exe        | 167.47          | Normal
# System RAM Usage: 95.2%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4875.52         | !!! DANGER !!!
# 23200      | Code.exe                  | 441.80          | Normal
# 25028      | Code.exe                  | 323.13          | Normal
# 4900       | MemCompression            | 265.59          | Normal
# 26188      | chrome.exe                | 250.62          | Normal
# 10520      | chrome.exe                | 197.06          | Normal
# 18276      | Code.exe                  | 193.68          | Normal
# 27016      | com.docker.backend.exe    | 187.43          | Normal
# 23448      | Docker Desktop.exe        | 167.54          | Normal
# 7004       | Code.exe                  | 164.39          | Normal
# System RAM Usage: 95.3%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4892.87         | !!! DANGER !!!
# 23200      | Code.exe                  | 441.80          | Normal
# 25028      | Code.exe                  | 323.53          | Normal
# 4900       | MemCompression            | 265.75          | Normal
# 26188      | chrome.exe                | 237.16          | Normal
# 10520      | chrome.exe                | 197.06          | Normal
# 18276      | Code.exe                  | 193.12          | Normal
# 27016      | com.docker.backend.exe    | 188.46          | Normal
# 23448      | Docker Desktop.exe        | 167.54          | Normal
# 3468       | msedgewebview2.exe        | 153.74          | Normal
# System RAM Usage: 95.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4985.77         | !!! DANGER !!!
# 23200      | Code.exe                  | 441.80          | Normal
# 25028      | Code.exe                  | 322.20          | Normal
# 4900       | MemCompression            | 265.77          | Normal
# 26188      | chrome.exe                | 237.21          | Normal
# 10520      | chrome.exe                | 197.06          | Normal
# 18276      | Code.exe                  | 192.86          | Normal
# 27016      | com.docker.backend.exe    | 188.56          | Normal
# 23448      | Docker Desktop.exe        | 177.45          | Normal
# 3468       | msedgewebview2.exe        | 153.74          | Normal
# System RAM Usage: 96.3%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4995.86         | !!! DANGER !!!
# 23200      | Code.exe                  | 441.80          | Normal
# 25028      | Code.exe                  | 323.06          | Normal
# 4900       | MemCompression            | 268.01          | Normal
# 26188      | chrome.exe                | 236.91          | Normal
# 10520      | chrome.exe                | 195.77          | Normal
# 27016      | com.docker.backend.exe    | 194.85          | Normal
# 18276      | Code.exe                  | 193.26          | Normal
# 23448      | Docker Desktop.exe        | 176.48          | Normal
# 3468       | msedgewebview2.exe        | 153.76          | Normal
# System RAM Usage: 96.2%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 4994.74         | !!! DANGER !!!
# 23200      | Code.exe                  | 441.80          | Normal
# 25028      | Code.exe                  | 326.07          | Normal
# 4900       | MemCompression            | 294.53          | Normal
# 26188      | chrome.exe                | 236.92          | Normal
# 10520      | chrome.exe                | 195.36          | Normal
# 18276      | Code.exe                  | 195.02          | Normal
# 27016      | com.docker.backend.exe    | 194.87          | Normal
# 23448      | Docker Desktop.exe        | 176.59          | Normal
# 3468       | msedgewebview2.exe        | 153.76          | Normal
# System RAM Usage: 96.5%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5000.87         | !!! DANGER !!!
# 23200      | Code.exe                  | 441.80          | Normal
# 25028      | Code.exe                  | 328.36          | Normal
# 4900       | MemCompression            | 295.53          | Normal
# 26188      | chrome.exe                | 236.93          | Normal
# 27016      | com.docker.backend.exe    | 201.50          | Normal
# 10520      | chrome.exe                | 195.36          | Normal
# 18276      | Code.exe                  | 193.86          | Normal
# 23448      | Docker Desktop.exe        | 176.93          | Normal
# 3468       | msedgewebview2.exe        | 153.76          | Normal
# System RAM Usage: 94.6%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5035.05         | !!! DANGER !!!
# 4900       | MemCompression            | 369.33          | Normal
# 23200      | Code.exe                  | 325.11          | Normal
# 25028      | Code.exe                  | 309.71          | Normal
# 23448      | Docker Desktop.exe        | 249.35          | Normal
# 26188      | chrome.exe                | 221.18          | Normal
# 27016      | com.docker.backend.exe    | 211.94          | Normal
# 10520      | chrome.exe                | 195.06          | Normal
# 3468       | msedgewebview2.exe        | 153.76          | Normal
# 18276      | Code.exe                  | 151.71          | Normal
# System RAM Usage: 92.0%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5063.54         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.11          | Normal
# 25028      | Code.exe                  | 303.58          | Normal
# 23448      | Docker Desktop.exe        | 272.19          | Normal
# 26188      | chrome.exe                | 221.20          | Normal
# 27016      | com.docker.backend.exe    | 215.03          | Normal
# 10520      | chrome.exe                | 195.06          | Normal
# 3468       | msedgewebview2.exe        | 150.81          | Normal
# 18276      | Code.exe                  | 149.95          | Normal
# 22516      | Docker Desktop.exe        | 142.72          | Normal
# System RAM Usage: 92.5%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5097.89         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.11          | Normal
# 25028      | Code.exe                  | 303.86          | Normal
# 23448      | Docker Desktop.exe        | 282.94          | Normal
# 26188      | chrome.exe                | 220.64          | Normal
# 27016      | com.docker.backend.exe    | 217.38          | Normal
# 10520      | chrome.exe                | 195.06          | Normal
# 3468       | msedgewebview2.exe        | 150.79          | Normal
# 18276      | Code.exe                  | 150.55          | Normal
# 22516      | Docker Desktop.exe        | 139.52          | Normal
# System RAM Usage: 92.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5133.98         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.11          | Normal
# 25028      | Code.exe                  | 305.35          | Normal
# 23448      | Docker Desktop.exe        | 283.23          | Normal
# 27016      | com.docker.backend.exe    | 227.88          | Normal
# 26188      | chrome.exe                | 220.70          | Normal
# 18276      | Code.exe                  | 152.41          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 150.81          | Normal
# 22516      | Docker Desktop.exe        | 139.61          | Normal
# System RAM Usage: 92.9%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5170.45         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.12          | Normal
# 25028      | Code.exe                  | 307.34          | Normal
# 23448      | Docker Desktop.exe        | 286.20          | Normal
# 27016      | com.docker.backend.exe    | 248.66          | Normal
# 26188      | chrome.exe                | 220.70          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 18276      | Code.exe                  | 151.27          | Normal
# 3468       | msedgewebview2.exe        | 150.82          | Normal
# 22516      | Docker Desktop.exe        | 139.61          | Normal
# System RAM Usage: 91.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5190.12         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.12          | Normal
# 25028      | Code.exe                  | 308.29          | Normal
# 27016      | com.docker.backend.exe    | 248.76          | Normal
# 26188      | chrome.exe                | 220.83          | Normal
# 18276      | Code.exe                  | 152.03          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 150.82          | Normal
# 22516      | Docker Desktop.exe        | 140.77          | Normal
# 17572      | chrome.exe                | 139.75          | Normal
# System RAM Usage: 91.6%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5205.21         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.13          | Normal
# 25028      | Code.exe                  | 307.21          | Normal
# 27016      | com.docker.backend.exe    | 248.80          | Normal
# 26188      | chrome.exe                | 220.83          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 18276      | Code.exe                  | 149.97          | Normal
# 3468       | msedgewebview2.exe        | 147.31          | Normal
# 22516      | Docker Desktop.exe        | 140.32          | Normal
# 17572      | chrome.exe                | 139.57          | Normal
# System RAM Usage: 92.0%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5280.03         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.14          | Normal
# 25028      | Code.exe                  | 303.30          | Normal
# 27016      | com.docker.backend.exe    | 254.98          | Normal
# 26188      | chrome.exe                | 220.90          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 18276      | Code.exe                  | 150.71          | Normal
# 3468       | msedgewebview2.exe        | 147.31          | Normal
# 22516      | Docker Desktop.exe        | 140.31          | Normal
# 17572      | chrome.exe                | 139.09          | Normal
# System RAM Usage: 94.0%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5631.28         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.14          | Normal
# 25028      | Code.exe                  | 306.27          | Normal
# 27016      | com.docker.backend.exe    | 255.46          | Normal
# 26188      | chrome.exe                | 220.90          | Normal
# 18276      | Code.exe                  | 152.64          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 147.31          | Normal
# 22516      | Docker Desktop.exe        | 140.79          | Normal
# 17572      | chrome.exe                | 139.07          | Normal
# System RAM Usage: 94.2%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5634.92         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.15          | Normal
# 25028      | Code.exe                  | 306.25          | Normal
# 27016      | com.docker.backend.exe    | 256.13          | Normal
# 26188      | chrome.exe                | 220.91          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 18276      | Code.exe                  | 151.32          | Normal
# 3468       | msedgewebview2.exe        | 148.01          | Normal
# 22516      | Docker Desktop.exe        | 140.80          | Normal
# 17572      | chrome.exe                | 139.07          | Normal
# System RAM Usage: 95.4%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5835.14         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.16          | Normal
# 25028      | Code.exe                  | 306.82          | Normal
# 27016      | com.docker.backend.exe    | 256.13          | Normal
# 26188      | chrome.exe                | 219.91          | Normal
# 18276      | Code.exe                  | 151.94          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 148.03          | Normal
# 22516      | Docker Desktop.exe        | 140.85          | Normal
# 17572      | chrome.exe                | 139.07          | Normal
# System RAM Usage: 95.6%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5900.05         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.16          | Normal
# 25028      | Code.exe                  | 305.65          | Normal
# 27016      | com.docker.backend.exe    | 256.15          | Normal
# 26188      | chrome.exe                | 219.91          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 18276      | Code.exe                  | 150.06          | Normal
# 3468       | msedgewebview2.exe        | 148.04          | Normal
# 22516      | Docker Desktop.exe        | 140.62          | Normal
# 7004       | Code.exe                  | 139.13          | Normal
# System RAM Usage: 95.6%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5897.06         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.18          | Normal
# 25028      | Code.exe                  | 306.66          | Normal
# 27016      | com.docker.backend.exe    | 256.15          | Normal
# 26188      | chrome.exe                | 219.91          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 18276      | Code.exe                  | 150.74          | Normal
# 3468       | msedgewebview2.exe        | 148.04          | Normal
# 22516      | Docker Desktop.exe        | 140.45          | Normal
# 7004       | Code.exe                  | 139.67          | Normal
# System RAM Usage: 95.7%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5896.50         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.19          | Normal
# 25028      | Code.exe                  | 309.45          | Normal
# 27016      | com.docker.backend.exe    | 256.15          | Normal
# 26188      | chrome.exe                | 219.91          | Normal
# 18276      | Code.exe                  | 152.83          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 148.04          | Normal
# 22516      | Docker Desktop.exe        | 140.41          | Normal
# 7004       | Code.exe                  | 140.16          | Normal
# System RAM Usage: 95.7%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5896.52         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.19          | Normal
# 25028      | Code.exe                  | 311.94          | Normal
# 27016      | com.docker.backend.exe    | 256.16          | Normal
# 26188      | chrome.exe                | 219.91          | Normal
# 18276      | Code.exe                  | 151.67          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 148.04          | Normal
# 7004       | Code.exe                  | 140.42          | Normal
# 22516      | Docker Desktop.exe        | 140.21          | Normal
# System RAM Usage: 95.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5896.55         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.20          | Normal
# 25028      | Code.exe                  | 310.25          | Normal
# 27016      | com.docker.backend.exe    | 256.16          | Normal
# 26188      | chrome.exe                | 220.06          | Normal
# 18276      | Code.exe                  | 152.41          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 148.07          | Normal
# 7004       | Code.exe                  | 141.23          | Normal
# 22516      | Docker Desktop.exe        | 140.23          | Normal
# System RAM Usage: 95.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5896.08         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.21          | Normal
# 25028      | Code.exe                  | 304.21          | Normal
# 27016      | com.docker.backend.exe    | 256.16          | Normal
# 26188      | chrome.exe                | 220.06          | Normal
# 17572      | chrome.exe                | 156.73          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 18276      | Code.exe                  | 150.23          | Normal
# 3468       | msedgewebview2.exe        | 148.07          | Normal
# 7004       | Code.exe                  | 141.53          | Normal
# System RAM Usage: 95.6%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5896.10         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.22          | Normal
# 25028      | Code.exe                  | 304.27          | Normal
# 27016      | com.docker.backend.exe    | 256.16          | Normal
# 26188      | chrome.exe                | 220.06          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 18276      | Code.exe                  | 150.88          | Normal
# 3468       | msedgewebview2.exe        | 148.07          | Normal
# 7004       | Code.exe                  | 141.53          | Normal
# 22516      | Docker Desktop.exe        | 140.19          | Normal
# System RAM Usage: 95.7%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5896.11         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.23          | Normal
# 25028      | Code.exe                  | 307.55          | Normal
# 27016      | com.docker.backend.exe    | 256.16          | Normal
# 26188      | chrome.exe                | 220.12          | Normal
# 18276      | Code.exe                  | 151.55          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 148.07          | Normal
# 7004       | Code.exe                  | 141.52          | Normal
# 22516      | Docker Desktop.exe        | 140.19          | Normal
# System RAM Usage: 95.7%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5897.37         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.24          | Normal
# 25028      | Code.exe                  | 308.02          | Normal
# 27016      | com.docker.backend.exe    | 256.16          | Normal
# 26188      | chrome.exe                | 220.12          | Normal
# 18276      | Code.exe                  | 151.92          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 148.07          | Normal
# 7004       | Code.exe                  | 141.29          | Normal
# 22516      | Docker Desktop.exe        | 140.17          | Normal
# System RAM Usage: 95.7%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5895.75         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.24          | Normal
# 25028      | Code.exe                  | 308.75          | Normal
# 27016      | com.docker.backend.exe    | 256.17          | Normal
# 26188      | chrome.exe                | 220.12          | Normal
# 18276      | Code.exe                  | 152.65          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 148.07          | Normal
# 7004       | Code.exe                  | 141.95          | Normal
# 22516      | Docker Desktop.exe        | 140.17          | Normal
# System RAM Usage: 95.7%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5897.64         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.27          | Normal
# 25028      | Code.exe                  | 308.51          | Normal
# 27016      | com.docker.backend.exe    | 256.17          | Normal
# 26188      | chrome.exe                | 220.12          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 18276      | Code.exe                  | 150.26          | Normal
# 3468       | msedgewebview2.exe        | 148.07          | Normal
# 7004       | Code.exe                  | 142.49          | Normal
# 22516      | Docker Desktop.exe        | 140.17          | Normal
# System RAM Usage: 95.7%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5898.91         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.27          | Normal
# 25028      | Code.exe                  | 308.31          | Normal
# 27016      | com.docker.backend.exe    | 256.18          | Normal
# 26188      | chrome.exe                | 220.12          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 18276      | Code.exe                  | 150.98          | Normal
# 3468       | msedgewebview2.exe        | 148.09          | Normal
# 7004       | Code.exe                  | 143.04          | Normal
# 22516      | Docker Desktop.exe        | 140.25          | Normal
# System RAM Usage: 96.0%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5897.05         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.31          | Normal
# 25028      | Code.exe                  | 311.90          | Normal
# 27016      | com.docker.backend.exe    | 256.18          | Normal
# 26188      | chrome.exe                | 220.12          | Normal
# 18276      | Code.exe                  | 151.64          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 148.09          | Normal
# 7004       | Code.exe                  | 143.14          | Normal
# 22516      | Docker Desktop.exe        | 140.25          | Normal
# System RAM Usage: 95.1%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5769.07         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.40          | Normal
# 25028      | Code.exe                  | 306.54          | Normal
# 27016      | com.docker.backend.exe    | 256.18          | Normal
# 26188      | chrome.exe                | 220.12          | Normal
# 18276      | Code.exe                  | 152.80          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 148.09          | Normal
# 7004       | Code.exe                  | 142.88          | Normal
# 22516      | Docker Desktop.exe        | 140.25          | Normal
# System RAM Usage: 95.1%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5770.95         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.35          | Normal
# 25028      | Code.exe                  | 306.30          | Normal
# 27016      | com.docker.backend.exe    | 256.18          | Normal
# 26188      | chrome.exe                | 220.12          | Normal
# 18276      | Code.exe                  | 152.87          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 148.09          | Normal
# 7004       | Code.exe                  | 143.14          | Normal
# 22516      | Docker Desktop.exe        | 140.27          | Normal
# System RAM Usage: 95.2%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5769.09         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.36          | Normal
# 25028      | Code.exe                  | 305.88          | Normal
# 27016      | com.docker.backend.exe    | 256.18          | Normal
# 26188      | chrome.exe                | 220.12          | Normal
# 18276      | Code.exe                  | 151.96          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 148.09          | Normal
# 7004       | Code.exe                  | 143.16          | Normal
# 22516      | Docker Desktop.exe        | 140.27          | Normal
# System RAM Usage: 95.2%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5769.11         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.36          | Normal
# 25028      | Code.exe                  | 306.33          | Normal
# 27016      | com.docker.backend.exe    | 256.18          | Normal
# 26188      | chrome.exe                | 220.12          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 18276      | Code.exe                  | 151.00          | Normal
# 3468       | msedgewebview2.exe        | 148.09          | Normal
# 7004       | Code.exe                  | 143.13          | Normal
# 22516      | Docker Desktop.exe        | 140.32          | Normal
# System RAM Usage: 95.2%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5768.76         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.37          | Normal
# 25028      | Code.exe                  | 309.62          | Normal
# 27016      | com.docker.backend.exe    | 256.18          | Normal
# 26188      | chrome.exe                | 220.12          | Normal
# 18276      | Code.exe                  | 151.80          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 148.11          | Normal
# 7004       | Code.exe                  | 143.22          | Normal
# 22516      | Docker Desktop.exe        | 140.44          | Normal
# System RAM Usage: 95.2%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5768.20         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.38          | Normal
# 25028      | Code.exe                  | 310.07          | Normal
# 27016      | com.docker.backend.exe    | 256.18          | Normal
# 26188      | chrome.exe                | 220.12          | Normal
# 18276      | Code.exe                  | 152.17          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 148.23          | Normal
# 7004       | Code.exe                  | 143.21          | Normal
# 22516      | Docker Desktop.exe        | 140.37          | Normal
# System RAM Usage: 95.2%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5768.91         | !!! DANGER !!!
# 23200      | Code.exe                  | 325.38          | Normal
# 25028      | Code.exe                  | 309.32          | Normal
# 27016      | com.docker.backend.exe    | 258.80          | Normal
# 26188      | chrome.exe                | 220.12          | Normal
# 18276      | Code.exe                  | 152.86          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 3468       | msedgewebview2.exe        | 148.23          | Normal
# 7004       | Code.exe                  | 143.22          | Normal
# 22516      | Docker Desktop.exe        | 140.37          | Normal
# System RAM Usage: 94.0%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5381.78         | !!! DANGER !!!
# 25028      | Code.exe                  | 266.05          | Normal
# 27016      | com.docker.backend.exe    | 258.13          | Normal
# 23200      | Code.exe                  | 229.96          | Normal
# 26188      | chrome.exe                | 201.70          | Normal
# 4900       | MemCompression            | 169.63          | Normal
# 10520      | chrome.exe                | 151.52          | Normal
# 22516      | Docker Desktop.exe        | 134.13          | Normal
# 17572      | chrome.exe                | 131.46          | Normal
# 11236      | Taskmgr.exe               | 122.59          | Normal
# System RAM Usage: 91.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5380.17         | !!! DANGER !!!
# 4900       | MemCompression            | 436.91          | Normal
# 25028      | Code.exe                  | 266.71          | Normal
# 27016      | com.docker.backend.exe    | 258.14          | Normal
# 26188      | chrome.exe                | 201.71          | Normal
# 23200      | Code.exe                  | 201.21          | Normal
# 22516      | Docker Desktop.exe        | 133.98          | Normal
# 10520      | chrome.exe                | 132.52          | Normal
# 17572      | chrome.exe                | 131.46          | Normal
# 11236      | Taskmgr.exe               | 122.62          | Normal
# System RAM Usage: 88.7%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5380.20         | !!! DANGER !!!
# 25028      | Code.exe                  | 269.81          | Normal
# 27016      | com.docker.backend.exe    | 258.17          | Normal
# 26188      | chrome.exe                | 201.71          | Normal
# 23200      | Code.exe                  | 201.22          | Normal
# 4900       | MemCompression            | 137.59          | Normal
# 22516      | Docker Desktop.exe        | 133.68          | Normal
# 10520      | chrome.exe                | 132.52          | Normal
# 17572      | chrome.exe                | 131.46          | Normal
# 11236      | Taskmgr.exe               | 122.62          | Normal
# System RAM Usage: 88.7%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5380.20         | !!! DANGER !!!
# 25028      | Code.exe                  | 270.08          | Normal
# 27016      | com.docker.backend.exe    | 258.16          | Normal
# 26188      | chrome.exe                | 201.74          | Normal
# 23200      | Code.exe                  | 201.23          | Normal
# 4900       | MemCompression            | 139.77          | Normal
# 22516      | Docker Desktop.exe        | 133.68          | Normal
# 10520      | chrome.exe                | 132.74          | Normal
# 17572      | chrome.exe                | 131.45          | Normal
# 11236      | Taskmgr.exe               | 122.62          | Normal
# System RAM Usage: 88.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5382.62         | !!! DANGER !!!
# 25028      | Code.exe                  | 270.42          | Normal
# 27016      | com.docker.backend.exe    | 258.16          | Normal
# 26188      | chrome.exe                | 201.74          | Normal
# 23200      | Code.exe                  | 201.29          | Normal
# 4900       | MemCompression            | 140.67          | Normal
# 22516      | Docker Desktop.exe        | 133.70          | Normal
# 10520      | chrome.exe                | 132.75          | Normal
# 17572      | chrome.exe                | 131.46          | Normal
# 11236      | Taskmgr.exe               | 122.64          | Normal
# System RAM Usage: 88.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5382.70         | !!! DANGER !!!
# 25028      | Code.exe                  | 269.92          | Normal
# 27016      | com.docker.backend.exe    | 258.16          | Normal
# 26188      | chrome.exe                | 201.74          | Normal
# 23200      | Code.exe                  | 201.52          | Normal
# 4900       | MemCompression            | 140.83          | Normal
# 22516      | Docker Desktop.exe        | 133.70          | Normal
# 10520      | chrome.exe                | 132.75          | Normal
# 17572      | chrome.exe                | 131.46          | Normal
# 11236      | Taskmgr.exe               | 122.64          | Normal
# System RAM Usage: 88.7%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5382.78         | !!! DANGER !!!
# 25028      | Code.exe                  | 265.18          | Normal
# 27016      | com.docker.backend.exe    | 258.17          | Normal
# 26188      | chrome.exe                | 201.74          | Normal
# 23200      | Code.exe                  | 201.66          | Normal
# 4900       | MemCompression            | 141.32          | Normal
# 22516      | Docker Desktop.exe        | 133.69          | Normal
# 10520      | chrome.exe                | 132.75          | Normal
# 17572      | chrome.exe                | 131.43          | Normal
# 11236      | Taskmgr.exe               | 122.64          | Normal
# System RAM Usage: 88.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5384.79         | !!! DANGER !!!
# 25028      | Code.exe                  | 268.12          | Normal
# 27016      | com.docker.backend.exe    | 258.18          | Normal
# 26188      | chrome.exe                | 201.74          | Normal
# 23200      | Code.exe                  | 201.61          | Normal
# 4900       | MemCompression            | 142.81          | Normal
# 22516      | Docker Desktop.exe        | 133.71          | Normal
# 10520      | chrome.exe                | 132.75          | Normal
# 17572      | chrome.exe                | 131.43          | Normal
# 11236      | Taskmgr.exe               | 122.66          | Normal
# System RAM Usage: 88.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 5386.37         | !!! DANGER !!!
# 25028      | Code.exe                  | 268.82          | Normal
# 27016      | com.docker.backend.exe    | 258.18          | Normal
# 26188      | chrome.exe                | 201.74          | Normal
# 23200      | Code.exe                  | 201.61          | Normal
# 4900       | MemCompression            | 143.81          | Normal
# 22516      | Docker Desktop.exe        | 133.71          | Normal
# 10520      | chrome.exe                | 132.75          | Normal
# 17572      | chrome.exe                | 131.43          | Normal
# 11236      | Taskmgr.exe               | 122.66          | Normal
# System RAM Usage: 88.8%
# ...
# 7084       | Microsoft.PowerBI.EnterpriseGateway.exe | 374.57          | Normal
# 18276      | Code.exe                  | 248.88          | Normal
# 25028      | Code.exe                  | 212.57          | Normal
# 26188      | chrome.exe                | 177.57          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 158.31          | Normal
# 23200      | Code.exe                  | 149.71          | Normal
# 16924      | Dell.TechHub.Instrumentation.SubAgent.exe | 123.48          | Normal
# System RAM Usage: 74.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1802.72         | !!! DANGER !!!
# 4900       | MemCompression            | 630.87          | !!! DANGER !!!
# 7084       | Microsoft.PowerBI.EnterpriseGateway.exe | 374.57          | Normal
# 25028      | Code.exe                  | 212.57          | Normal
# 18276      | Code.exe                  | 198.71          | Normal
# 26188      | chrome.exe                | 177.57          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 158.31          | Normal
# 23200      | Code.exe                  | 149.71          | Normal
# 16924      | Dell.TechHub.Instrumentation.SubAgent.exe | 123.50          | Normal
# System RAM Usage: 75.4%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1802.72         | !!! DANGER !!!
# 4900       | MemCompression            | 631.84          | !!! DANGER !!!
# 7084       | Microsoft.PowerBI.EnterpriseGateway.exe | 374.57          | Normal
# 18276      | Code.exe                  | 230.38          | Normal
# 25028      | Code.exe                  | 223.36          | Normal
# 26188      | chrome.exe                | 177.57          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 158.31          | Normal
# 23200      | Code.exe                  | 149.71          | Normal
# 16924      | Dell.TechHub.Instrumentation.SubAgent.exe | 123.61          | Normal
# System RAM Usage: 75.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1802.77         | !!! DANGER !!!
# 4900       | MemCompression            | 635.46          | !!! DANGER !!!
# 7084       | Microsoft.PowerBI.EnterpriseGateway.exe | 374.72          | Normal
# 18276      | Code.exe                  | 253.29          | Normal
# 25028      | Code.exe                  | 212.68          | Normal
# 26188      | chrome.exe                | 177.57          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 158.66          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# 16924      | Dell.TechHub.Instrumentation.SubAgent.exe | 123.67          | Normal
# System RAM Usage: 75.5%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1802.78         | !!! DANGER !!!
# 4900       | MemCompression            | 635.46          | !!! DANGER !!!
# 7084       | Microsoft.PowerBI.EnterpriseGateway.exe | 374.71          | Normal
# 25028      | Code.exe                  | 214.35          | Normal
# 18276      | Code.exe                  | 210.56          | Normal
# 26188      | chrome.exe                | 177.57          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 158.66          | Normal
# 23200      | Code.exe                  | 149.66          | Normal
# 16924      | Dell.TechHub.Instrumentation.SubAgent.exe | 123.64          | Normal
# System RAM Usage: 75.5%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1802.78         | !!! DANGER !!!
# 4900       | MemCompression            | 635.46          | !!! DANGER !!!
# 7084       | Microsoft.PowerBI.EnterpriseGateway.exe | 374.86          | Normal
# 18276      | Code.exe                  | 218.14          | Normal
# 25028      | Code.exe                  | 212.10          | Normal
# 26188      | chrome.exe                | 177.57          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 158.66          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# 16924      | Dell.TechHub.Instrumentation.SubAgent.exe | 123.64          | Normal
# System RAM Usage: 75.6%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1802.82         | !!! DANGER !!!
# 4900       | MemCompression            | 635.56          | !!! DANGER !!!
# 7084       | Microsoft.PowerBI.EnterpriseGateway.exe | 374.86          | Normal
# 18276      | Code.exe                  | 218.13          | Normal
# 25028      | Code.exe                  | 209.27          | Normal
# 26188      | chrome.exe                | 177.57          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 158.66          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# 2072       | dwm.exe                   | 126.45          | Normal
# System RAM Usage: 75.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1802.86         | !!! DANGER !!!
# 4900       | MemCompression            | 635.56          | !!! DANGER !!!
# 7084       | Microsoft.PowerBI.EnterpriseGateway.exe | 374.86          | Normal
# 18276      | Code.exe                  | 236.34          | Normal
# 25028      | Code.exe                  | 212.25          | Normal
# 26188      | chrome.exe                | 177.57          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 158.66          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# 2072       | dwm.exe                   | 126.52          | Normal
# System RAM Usage: 77.5%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1803.02         | !!! DANGER !!!
# 4900       | MemCompression            | 645.43          | !!! DANGER !!!
# 7084       | Microsoft.PowerBI.EnterpriseGateway.exe | 374.86          | Normal
# 18276      | Code.exe                  | 219.33          | Normal
# 25028      | Code.exe                  | 218.56          | Normal
# 26188      | chrome.exe                | 206.86          | Normal
# 2072       | dwm.exe                   | 180.92          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 159.55          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# System RAM Usage: 77.3%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1804.36         | !!! DANGER !!!
# 4900       | MemCompression            | 599.32          | !!! DANGER !!!
# 7084       | Microsoft.PowerBI.EnterpriseGateway.exe | 374.78          | Normal
# 18276      | Code.exe                  | 238.39          | Normal
# 25028      | Code.exe                  | 212.45          | Normal
# 26188      | chrome.exe                | 206.86          | Normal
# 2072       | dwm.exe                   | 181.00          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 160.40          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# System RAM Usage: 76.8%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1803.36         | !!! DANGER !!!
# 4900       | MemCompression            | 599.37          | !!! DANGER !!!
# 7084       | Microsoft.PowerBI.EnterpriseGateway.exe | 374.81          | Normal
# 18276      | Code.exe                  | 219.48          | Normal
# 25028      | Code.exe                  | 211.32          | Normal
# 26188      | chrome.exe                | 193.89          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 161.32          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# 2072       | dwm.exe                   | 132.46          | Normal
# System RAM Usage: 74.6%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1803.36         | !!! DANGER !!!
# 4900       | MemCompression            | 551.81          | !!! DANGER !!!
# 7084       | Microsoft.PowerBI.EnterpriseGateway.exe | 374.75          | Normal
# 18276      | Code.exe                  | 238.50          | Normal
# 25028      | Code.exe                  | 209.65          | Normal
# 26188      | chrome.exe                | 193.89          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 161.89          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# 16924      | Dell.TechHub.Instrumentation.SubAgent.exe | 123.67          | Normal
# System RAM Usage: 72.3%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1803.29         | !!! DANGER !!!
# 4900       | MemCompression            | 551.45          | !!! DANGER !!!
# 7084       | Microsoft.PowerBI.EnterpriseGateway.exe | 374.75          | Normal
# 18276      | Code.exe                  | 218.06          | Normal
# 25028      | Code.exe                  | 212.31          | Normal
# 26188      | chrome.exe                | 193.89          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 161.66          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# 16924      | Dell.TechHub.Instrumentation.SubAgent.exe | 123.67          | Normal
# System RAM Usage: 72.4%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1803.29         | !!! DANGER !!!
# 4900       | MemCompression            | 551.31          | !!! DANGER !!!
# 18276      | Code.exe                  | 248.25          | Normal
# 25028      | Code.exe                  | 215.23          | Normal
# 26188      | chrome.exe                | 193.89          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 161.65          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# 16924      | Dell.TechHub.Instrumentation.SubAgent.exe | 123.67          | Normal
# 2296       | TMBMSRV.exe               | 117.84          | Normal
# System RAM Usage: 72.3%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1803.29         | !!! DANGER !!!
# 4900       | MemCompression            | 551.27          | !!! DANGER !!!
# 18276      | Code.exe                  | 230.22          | Normal
# 25028      | Code.exe                  | 212.58          | Normal
# 26188      | chrome.exe                | 193.89          | Normal
# 27016      | com.docker.backend.exe    | 168.32          | Normal
# 11236      | Taskmgr.exe               | 161.67          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# 16924      | Dell.TechHub.Instrumentation.SubAgent.exe | 123.69          | Normal
# 2296       | TMBMSRV.exe               | 117.84          | Normal
# System RAM Usage: 72.5%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1803.34         | !!! DANGER !!!
# 4900       | MemCompression            | 551.61          | !!! DANGER !!!
# 18276      | Code.exe                  | 250.79          | Normal
# 25028      | Code.exe                  | 212.00          | Normal
# 26188      | chrome.exe                | 193.89          | Normal
# 27016      | com.docker.backend.exe    | 168.33          | Normal
# 11236      | Taskmgr.exe               | 161.67          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# 16924      | Dell.TechHub.Instrumentation.SubAgent.exe | 123.69          | Normal
# 2296       | TMBMSRV.exe               | 117.87          | Normal
# System RAM Usage: 72.3%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1803.34         | !!! DANGER !!!
# 4900       | MemCompression            | 551.48          | !!! DANGER !!!
# 25028      | Code.exe                  | 212.42          | Normal
# 18276      | Code.exe                  | 210.14          | Normal
# 26188      | chrome.exe                | 194.09          | Normal
# 27016      | com.docker.backend.exe    | 168.33          | Normal
# 11236      | Taskmgr.exe               | 161.67          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# 16924      | Dell.TechHub.Instrumentation.SubAgent.exe | 123.69          | Normal
# 2296       | TMBMSRV.exe               | 117.88          | Normal
# System RAM Usage: 72.5%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1802.97         | !!! DANGER !!!
# 4900       | MemCompression            | 551.47          | !!! DANGER !!!
# 18276      | Code.exe                  | 239.70          | Normal
# 25028      | Code.exe                  | 215.32          | Normal
# 26188      | chrome.exe                | 194.09          | Normal
# 27016      | com.docker.backend.exe    | 168.33          | Normal
# 11236      | Taskmgr.exe               | 161.68          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# 16924      | Dell.TechHub.Instrumentation.SubAgent.exe | 123.69          | Normal
# 2296       | TMBMSRV.exe               | 117.88          | Normal
# System RAM Usage: 72.4%
# PID        | Process Name              | Memory (MB)     | Status
# -----------------------------------------------------------------
# 29224      | vmmemWSL                  | 1803.02         | !!! DANGER !!!
# 4900       | MemCompression            | 553.24          | !!! DANGER !!!
# 18276      | Code.exe                  | 227.79          | Normal
# 25028      | Code.exe                  | 216.74          | Normal
# 26188      | chrome.exe                | 195.57          | Normal
# 27016      | com.docker.backend.exe    | 168.33          | Normal
# 11236      | Taskmgr.exe               | 158.80          | Normal
# 23200      | Code.exe                  | 149.72          | Normal
# 16924      | Dell.TechHub.Instrumentation.SubAgent.exe | 123.69          | Normal
# 2296       | TMBMSRV.exe               | 117.88          | Normal
#
# Exit Monitoring.

# %%
from datetime import datetime
import random
import string

def get_enterprise_timestamps():
    """
    รวมการสร้าง Timestamp ทุกรูปแบบไว้ในที่เดียว 
    เพื่อให้เรียกใช้งานง่ายและจัดการได้เป็นระบบ
    """
    now = datetime.now()
    
    # รูปแบบมาตรฐาน (Standard Display) - 2026/03/22 20:49:15
    standard = now.strftime("%Y/%m/%d %H:%M:%S")
    
    # แบบที่ 1: Compact ID (Ym + 4 Random) - 2026039999
    compact = f"{now.strftime('%Y%m%d')}"
    
    # แบบที่ 2: Minio/File-Safe (Ymd + 12 Random) - 20260322_123456789012
    random_suffix = ''.join(random.choices(string.digits, k=12))
    file_name = f"{now.strftime('%Y%m%d')}_{random_suffix}"
    
    # แบบที่ 3: ISO 8601 (API/DB Standard) - 2026-03-22T20:49:15
    iso = now.strftime('%Y-%m-%dT%H:%M:%S')
    
    return {
        "standard": standard,
        "compact": compact,
        "file_name": file_name,
        "iso": iso
    }

# --- 🚀 วิธีเรียกใช้งานที่ง่ายที่สุด ---
ts = get_enterprise_timestamps()

# เลือกใช้ตามสถานการณ์
print(f"บันทึก Log: {ts['standard']}")
print(f"สร้าง Batch ID: {ts['compact']}")
print(f"ตั้งชื่อไฟล์ Minio: {ts['file_name']}")
print(f"ส่งค่าเข้า API: {ts['iso']}")
# Out:
# บันทึก Log: 2026/03/22 20:57:33
# สร้าง Batch ID: 20260322
# ตั้งชื่อไฟล์ Minio: 20260322_732927253103
# ส่งค่าเข้า API: 2026-03-22T20:57:33

# %%
# สมมติว่าไฟล์ ExcelImportManager อยู่ในไฟล์เดียวกับสคริปต์นี้
# หรือ import เข้ามา: from app.backend.utils.excel_manager import ExcelImportManager

file_path = r'D:\gosoft_qc\พฤศจิกายน 2568 7Delivery-Pook.xlsx'
file_path = f's3://promotion-files/20260307/00/ธันวาคม 2568 Corporate -ซื้อครบรับฟรีพรีเมียม - Pook.xlsx'

# 1. ดึงแค่ชื่อ Sheet มาดูก่อน (แยก ซ่อน/ไม่ซ่อน)
sheet_info = ExcelImportManager.get_sheet_visibility(file_path)
print(f'✅ Sheet ที่แสดงอยู่: {sheet_info['visible']}')
print(f'❌ Sheet ที่ซ่อนอยู่: {sheet_info['hidden']}')

# 2. สั่งอ่านข้อมูล (DataFrame) เฉพาะ Sheet ที่แสดงอยู่
# จะคืนค่ากลับมาเป็น Dictionary ที่มี Key เป็นชื่อ Sheet และ Value เป็นข้อมูล
data_frames = ExcelImportManager.read_only_visible_sheets(file_path)

for sheet_name, df in data_frames.items():
    print(f'\n--- ข้อมูลจาก Sheet: {sheet_name} ---')
    print(df.head()) # ปริ้นท์ดูข้อมูล 5 บรรทัดแรก
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 file_path = f's3://promotion-files/20260307/00/ธันวาคม 2568 Corporate -ซื้อครบรับฟรีพรีเมียม - Pook.xlsx'
#       7 # 1. ดึงแค่ชื่อ Sheet มาดูก่อน (แยก ซ่อน/ไม่ซ่อน)
# ----> 8 sheet_info = ExcelImportManager.get_sheet_visibility(file_path)
#       9 print(f'✅ Sheet ที่แสดงอยู่: {sheet_info['visible']}')
#      10 print(f'❌ Sheet ที่ซ่อนอยู่: {sheet_info['hidden']}')
#
# NameError: name 'ExcelImportManager' is not defined

# %%
import requests
import json
from datetime import datetime,timezone,timedelta
import random
import string

# %%
def inquery_profile(member: str) -> dict:
    try:

        payload = json.dumps({
        "stationId": "1",
        "storeId": "09884",
        "channelId": "CN01",
        "identifyId": _getbarcode_type_number.get(str(len(member)), '0'),
        "identifyValue": member,
        "requestTime": _get_timestamps().get('stadard')
        })
        headers = {
            'Content-Type': 'application/json'
        }
        response = requests.post(_inquery_url, headers=headers, data=payload, timeout=10)
        response.raise_for_status()
        print(response.json())
        return response.json()
    except Exception as e:
        return {"status": "error", "message": f"inquery profile API Error: {str(e)}"}

# %%
import ast
import logging
from pathlib import Path
from typing import Set, Tuple


# ---------------- LOGGING ----------------

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s | %(levelname)s | %(message)s'
)

logger = logging.getLogger('Scanner')


# ---------------- AST VISITOR ----------------

class FunctionCallVisitor(ast.NodeVisitor):

    def __init__(self, file_path: Path):
        self.file_path = str(file_path)
        self.current_function = None
        self.calls: Set[Tuple[str, str]] = set()

    def visit_FunctionDef(self, node: ast.FunctionDef):
        prev = self.current_function
        self.current_function = f'{self.file_path}:{node.name}'

        self.generic_visit(node)

        self.current_function = prev

    def visit_Call(self, node: ast.Call):
        if self.current_function:
            name = self._get_name(node.func)
            if name:
                self.calls.add((self.current_function, name))

        self.generic_visit(node)

    def _get_name(self, node):
        if isinstance(node, ast.Name):
            return node.id
        if isinstance(node, ast.Attribute):
            return node.attr
        return None


# ---------------- MAIN SCANNER ----------------

class GlobalFunctionScanner:

    IGNORE_DIRS = {
        '.git',
        '__pycache__',
        'venv',
        '.venv',
        'node_modules',
        'dist',
        'build'
    }

    def __init__(self, root: str, dry_run=False):
        self.root = Path(root)
        self.graph: Set[Tuple[str, str]] = set()
        self.dry_run = dry_run

    # ---------------------------------

    def scan_all_python_files(self):

        logger.info('Scanning folders...')

        for path in self.root.rglob('*.py'):

            if any(part in self.IGNORE_DIRS for part in path.parts):
                continue

            yield path

    # ---------------------------------

    def parse_file(self, file: Path):

        try:
            source = file.read_text(encoding='utf-8')
            tree = ast.parse(source)
        except PermissionError:
            logger.warning(f'Permission denied: {file}')
            return
        except Exception as e:
            logger.warning(f'Parse fail {file}: {e}')
            return

        visitor = FunctionCallVisitor(file)
        visitor.visit(tree)

        self.graph.update(visitor.calls)

    # ---------------------------------

    def build_graph(self):

        for file in self.scan_all_python_files():
            logger.info(f'Parsing {file}')
            self.parse_file(file)

    # ---------------------------------

    def export_mermaid(self, output='GLOBAL_FUNCTION_FLOW.md'):

        if self.dry_run:
            logger.info('Dry-run enabled (skip export)')
            return

        lines = ['```mermaid', 'graph TD']

        for caller, callee in sorted(self.graph):
            caller = caller.replace(''', '').replace('.', '_')
            callee = callee.replace(''', '').replace('.', '_')

            lines.append(f'    '{caller}' --> '{callee}'')

        lines.append('```')

        Path(output).write_text('\n'.join(lines), encoding='utf-8')

        logger.info(f'Diagram created: {output}')

    # ---------------------------------

    def run(self):

        logger.info(f'Start scanning root: {self.root}')

        self.build_graph()
        self.export_mermaid()

        logger.info(f'Total edges: {len(self.graph)}')

# %%
import ast
from pathlib import Path
from typing import Dict, List, Set


class FunctionCallVisitor(ast.NodeVisitor):
    '''
    AST Visitor สำหรับเก็บ function call
    '''

    def __init__(self, file_name: str):
        self.file_name = file_name
        self.current_function = None
        self.calls = []

    def visit_FunctionDef(self, node: ast.FunctionDef):
        prev = self.current_function
        self.current_function = f'{self.file_name}:{node.name}'

        self.generic_visit(node)

        self.current_function = prev

    def visit_Call(self, node: ast.Call):
        if self.current_function:
            func_name = self._get_call_name(node.func)
            if func_name:
                self.calls.append(
                    (self.current_function, func_name)
                )

        self.generic_visit(node)

    def _get_call_name(self, node):
        if isinstance(node, ast.Name):
            return node.id

        if isinstance(node, ast.Attribute):
            return node.attr

        return None


# --------------------------------------------------


class ProjectScanner:
    '''
    Scan python project และสร้าง function flow diagram
    '''

    def __init__(self, root_path: str):
        self.root = Path(root_path)
        self.graph: Set[tuple] = set()

    # --------------------------

    def scan_files(self) -> List[Path]:
        return list(self.root.rglob('*.py'))

    # --------------------------

    def parse_file(self, file: Path):

        try:
            source = file.read_text(encoding='utf-8')
            tree = ast.parse(source)
        except Exception:
            return

        visitor = FunctionCallVisitor(file.name)
        visitor.visit(tree)

        for edge in visitor.calls:
            self.graph.add(edge)

    # --------------------------

    def build_call_graph(self):

        for file in self.scan_files():
            self.parse_file(file)

    # --------------------------

    def export_mermaid(self, output='function_flow.md'):

        lines = ['```mermaid', 'graph TD']

        for caller, callee in sorted(self.graph):
            caller = caller.replace('.', '_')
            callee = callee.replace('.', '_')
            lines.append(f'    '{caller}' --> '{callee}'')

        lines.append('```')

        Path(output).write_text('\n'.join(lines), encoding='utf-8')

        print(f'Diagram generated -> {output}')

    # --------------------------

    def run(self):
        self.build_call_graph()
        self.export_mermaid()

# %%
scanner = GlobalFunctionScanner('./app/')
scanner.run()

# %%
import sqlite3
from pathlib import Path
from datetime import datetime
import os


class FilePathIndexer:

    def __init__(self, root_path: str, db_path: str = 'files.db'):
        self.root_path = Path(root_path).resolve()
        self.db_path = db_path

        if not self.root_path.exists():
            raise FileNotFoundError(self.root_path)

        self.conn = sqlite3.connect(self.db_path)
        self._create_table()

    def _create_table(self):
        self.conn.execute('''
        CREATE TABLE IF NOT EXISTS files (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            file_name TEXT,
            full_path TEXT UNIQUE,
            extension TEXT,
            size INTEGER,
            created_at TEXT,
            modified_at TEXT
        )
        ''')
        self.conn.commit()

    def scan(self):
        cursor = self.conn.cursor()

        for root, _, files in os.walk(self.root_path):
            for name in files:
                file_path = Path(root) / name

                try:
                    stat = file_path.stat()

                    cursor.execute('''
                        INSERT OR IGNORE INTO files
                        (file_name, full_path, extension, size,
                         created_at, modified_at)
                        VALUES (?, ?, ?, ?, ?, ?)
                    ''', (
                        name,
                        str(file_path),
                        file_path.suffix.lower(),
                        stat.st_size,
                        datetime.fromtimestamp(stat.st_ctime).isoformat(),
                        datetime.fromtimestamp(stat.st_mtime).isoformat(),
                    ))

                except PermissionError:
                    print('Permission denied:', file_path)

        self.conn.commit()

    def close(self):
        self.conn.close()

# %%
# ===== RUN =====
if __name__ == '__main__':
    indexer = FilePathIndexer(
        root_path=r'C:\Users\nakarinsue\Documents', 
        db_path='files.db'
    )

    indexer.scan()
    indexer.close()

    print('Index completed.')

# %%
import requests
import json

url = 'https://sdl-master-api-uat.cpall.co.th/api/products/internal'

payload = json.dumps({
 'storeId': '11104',
 'productCode': [
  '5100320','5100322','5100323'
 ],
 'checkInventory': True,
 'checkPeriodTime': True,
 'ContentLanguage': 'th'
})
headers = {
	'x-api-key': '4K2kmEfGTYZHVXFNqdKTAX3MES5NYvWV',
	'device_type': '3',
	'api-version': '7',
	'Content-Type': 'application/json'
}

response = requests.request('POST', url, headers=headers, data=payload)

print(response.text)
# Out:
# {"returnCode":"0000","returnMessage":"success","result":[{"product_barcode":"8858746100926","product_barcode_list":["8858746100926"],"product_code":"5100320","product_name":"ถุงขยะ my items 24x28นิ้ว","product_image":"https://media-uat.cpall.co.th/products/5100320_050920221403.jpg","product_image_hd":"https://media-uat.cpall.co.th/products/5100320_050920221403.jpg","product_image_list":["https://media-uat.cpall.co.th/products/5100320_050920221403.jpg"],"product_sell_price":39,"product_hq_price":39,"product_type_id":3,"product_type_name":"on shelf","isSaleWithOther":true,"product_description":"<p>ถุงขยะ my items เหนียว ทนทาน ปราศจากกลิ่น รับน้ำหนักได้มาก ออกแบบมาให้หยิบใช้งานง่าย</p>","product_type_order":3,"pma":"51","cat_pma":"01","sub_cat_pma":"04","is_one_touch_item":false,"product_sections_total_required_qty":0,"is_product_sections_required":false,"product_sections":[],"product_discount_price":0,"is_dynamic_price":false,"product_min_price":0,"product_max_price":0,"promotions":[{"promotion_code":"","promotion_product_type_id":0,"promotion_product_type_name":"เจ","promotion_product_type_image":"https://media-uat.cpall.co.th/logos/j_2022.png","promotion_product_type_corner_image":"https://media-uat.cpall.co.th/logos/j_2022.png","trigger_value":0,"trigger_type":0,"remark":"[เจ] \n    - สินค้าเจ"}],"product_positions":"","is_reorder_able":true,"status_id":1,"create_date":"2024-10-11T02:41:34.000Z","item_type":"S","product_specification":[],"originalPrice":39,"product_options":[],"toppings":null,"check_period_time":false,"on_demand":true,"is_sold_out":false,"inv_mvmnt_qty":9999,"update_dttm":1772975582932,"inv_detail":[{"storeId":"11104","qty":9999,"is_hub":false}],"hub_type":0,"isHubThirdParty":false}],"dcPeriodTime":[{"dc_id":"","period_list":[]}]}

# %%
[
  {
    'header': {
      'pro_code': 288455,
      'end_date': '2025-11-23',
      'limit_day': 0,
      'pro_name': 'ส่วนลดศรีจันทร์เอ็นชานเท็ดสีเนื้อ ด.',
      'limit_item': 0,
      'pro_receipt_name': 'ส่วนลดศรีจันทร์เอ็นชานเท็ดสีเนื้อ ด.',
      'limit_redemp': 0,
      'reward_value': '39.00',
      'pro_group': 'ตลาดนัด',
      'reward_type': 'New Price',
      'reward_ma': '',
      'member_requ': '',
      'reward_name': '',
      'notes': 'รองพื้นศรีจันทร์เอ็นชานเท็ด #120สีเนื้อ ด. 1 ชิ้น พิเศษ 39 บาท ปกติ 49 บาท ( เฉพาะสาขาที่ร่วมรายการ )',
      'start_date': '2025-10-24',
      'limit_tran': 10,
    },
    'file': {
      'file_name': '00213-ครั้งที่ 1 โปรโมชั่น เดือนพฤศจิกายน 2568 ตลาดนัด 00213 ( Test ).xlsx',
      'user_mk': '',
      'sheet': 'ตลาดนัด',
    },
    'bucket': {
      'bucket': 1,
      'trigger_value': '1',
      'trigger_type': 'Quantity',
      'barcode': '8858696808200',
      'entity_name': 'pรองพื้นศรีจันทร์เอ็นชานเท็ด 120สีเนื้อ(ด) 7 ก.',
      'coupon': '',
      'entity_code': '5003106',
      'entity_type': 'Item',
      'condition': '',
      'mode': 'Include',
      'condition_name': 'รองพื้นศรีจันทร์เอ็นชานเท็ด #120 ด.',
      'condition_id': ''
    }
  }
]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(str(response.text).format_map())
#
# TypeError: str.format_map() takes exactly one argument (0 given)

# %%
from minio import Minio
from minio.error import S3Error
import io

# การตั้งค่า Client (ควรดึงค่าจาก Environment Variables)
minio_client = Minio(
    'localhost:9000',
    access_key='Administrator',
    secret_key='Admin2000',
    secure=False # เปลี่ยนเป็น True หากใช้ HTTPS
)

BUCKET_NAME = 'promotion-files'

# --- 1. ฟังก์ชันดึงไฟล์ (Get File) ---
def get_minio_file(file_name: str):
    '''ดึงข้อมูลไฟล์จาก MinIO ในรูปแบบ Bytes'''
    try:
        response = minio_client.get_object(BUCKET_NAME, file_name)
        return response.read()
    except S3Error as e:
        print(f'Error getting file: {e}')
        return None
    finally:
        if 'response' in locals():
            response.close()
            response.release_conn()

# --- 2. ฟังก์ชันลบไฟล์ (Delete File) ---
def delete_minio_file(file_name: str):
    '''ลบไฟล์ออกจาก Bucket'''
    try:
        minio_client.remove_object(BUCKET_NAME, file_name)
        return True
    except S3Error as e:
        print(f'Error deleting file: {e}')
        return False

# --- 3. ฟังก์ชันแก้ไขชื่อไฟล์ (Rename/Move) ---
def rename_minio_file(old_name: str, new_name: str):
    '''
    แก้ไขชื่อไฟล์ใน MinIO (ใช้วิธี Copy ไปชื่อใหม่แล้วลบชื่อเดิม)
    '''
    try:
        # 1. Copy ไฟล์ไปยังชื่อใหม่
        from minio.commonconfig import CopySource
        minio_client.copy_object(
            BUCKET_NAME,
            new_name,
            CopySource(BUCKET_NAME, old_name),
        )
        # 2. ลบไฟล์เดิมออก
        minio_client.remove_object(BUCKET_NAME, old_name)
        return True
    except S3Error as e:
        print(f'Error renaming file: {e}')
        return False
def delete_minio_bucket(bucket_name: str, force: bool = False):
    '''
    ลบ Bucket ออกจากระบบ
    :param bucket_name: ชื่อ Bucket ที่ต้องการลบ
    :param force: หากเป็น True จะลบไฟล์ทั้งหมดข้างในก่อนลบ Bucket
    '''
    try:
        # ตรวจสอบว่ามี Bucket อยู่จริงหรือไม่
        if not minio_client.bucket_exists(bucket_name):
            print(f'Bucket '{bucket_name}' does not exist.')
            return False

        if force:
            # ลบไฟล์ทั้งหมดใน Bucket ก่อน (มาตรฐาน S3 ต้องว่างก่อนลบ)
            objects_to_delete = minio_client.list_objects(bucket_name, recursive=True)
            for obj in objects_to_delete:
                minio_client.remove_object(bucket_name, obj.object_name)
            print(f'All objects in '{bucket_name}' have been deleted.')

        # ลบ Bucket
        minio_client.remove_bucket(bucket_name)
        print(f'Bucket '{bucket_name}' deleted successfully.')
        return True

    except S3Error as e:
        print(f'Error occurred: {e}')
        return False

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# aiobotocore               3.2.0
# aiohappyeyeballs          2.6.1
# aiohttp                   3.13.3
# aioitertools              0.13.0
# aiosignal                 1.4.0
# annotated-doc             0.0.4
# annotated-types           0.7.0
# anyio                     4.12.1
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.2.0
# attrs                     25.4.0
# babel                     2.18.0
# bcrypt                    3.2.2
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# boto3                     1.42.53
# botocore                  1.42.53
# certifi                   2026.2.25
# cffi                      2.0.0
# charset-normalizer        3.4.5
# click                     8.3.1
# colorama                  0.4.6
# comm                      0.2.3
# cryptography              46.0.5
# debugpy                   1.8.20
# decorator                 5.2.1
# defusedxml                0.7.1
# dnspython                 2.8.0
# ecdsa                     0.19.1
# email-validator           2.3.0
# et_xmlfile                2.0.0
# executing                 2.2.1
# fastapi                   0.129.0
# fastjsonschema            2.21.2
# fqdn                      1.5.1
# frozenlist                1.8.0
# fsspec                    2026.2.0
# greenlet                  3.3.2
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# icecream                  2.1.10
# idna                      3.11
# ipykernel                 7.2.0
# ipython                   9.10.0
# ipython_pygments_lexers   1.1.1
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# jmespath                  1.1.0
# jose                      1.0.0
# json5                     0.13.0
# jsonpointer               3.0.0
# jsonschema                4.26.0
# jsonschema-specifications 2025.9.1
# jupyter_client            8.8.0
# jupyter_core              5.9.1
# jupyter-events            0.12.0
# jupyter-lsp               2.3.0
# jupyter_server            2.17.0
# jupyter_server_terminals  0.5.4
# jupyterlab                4.5.5
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# lark                      1.3.1
# MarkupSafe                3.0.3
# matplotlib-inline         0.2.1
# minio                     7.2.20
# mistune                   3.2.0
# multidict                 6.7.1
# nbclient                  0.10.4
# nbconvert                 7.17.0
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# networkx                  3.6.1
# notebook_shim             0.2.4
# numpy                     2.4.2
# openpyxl                  3.1.5
# oracledb                  3.4.2
# packaging                 26.0
# pandas                    3.0.1
# pandocfilters             1.5.1
# parso                     0.8.6
# passlib                   1.7.4
# pip                       26.0.1
# platformdirs              4.9.2
# prometheus_client         0.24.1
# prompt_toolkit            3.0.52
# propcache                 0.4.1
# psutil                    7.2.2
# psycopg2                  2.9.11
# psycopg2-binary           2.9.11
# pure_eval                 0.2.3
# pyan3                     2.0.0
# pyasn1                    0.6.2
# pycparser                 3.0
# pycryptodome              3.23.0
# pydantic                  2.12.5
# pydantic_core             2.41.5
# pydantic-settings         2.13.1
# Pygments                  2.19.2
# PyMySQL                   1.1.2
# pyodbc                    5.3.0
# python-dateutil           2.9.0.post0
# python-dotenv             1.2.1
# python-jose               3.5.0
# python-json-logger        4.0.0
# python-multipart          0.0.22
# pywinpty                  3.0.3
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# referencing               0.37.0
# requests                  2.32.5
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rpds-py                   0.30.0
# rsa                       4.9.1
# s3fs                      2026.2.0
# s3transfer                0.16.0
# Send2Trash                2.1.0
# setuptools                82.0.0
# six                       1.17.0
# soupsieve                 2.8.3
# SQLAlchemy                2.0.46
# stack-data                0.6.3
# starlette                 0.52.1
# terminado                 0.18.1
# tinycss2                  1.4.0
# tornado                   6.5.4
# traitlets                 5.14.3
# typing_extensions         4.15.0
# typing-inspection         0.4.2
# tzdata                    2025.3
# uri-template              1.3.0
# urllib3                   2.6.3
# uv                        0.10.9
# uvicorn                   0.41.0
# voila                     0.5.11
# wcwidth                   0.6.0
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# websockets                16.0
# wrapt                     2.1.1
# xlsxwriter                3.2.9
# xmltodict                 1.0.4
# yarl                      1.22.0

# %%
import random
import base64
import requests
import xmltodict as xd
import pandas as pd
from datetime import datetime, timedelta
import oracledb
from dataclasses import dataclass, field
from typing import Any, Dict, Optional,Literal
import json
from icecream import ic
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)


@dataclass
class StoreConfig:
    store_id: str = "09892"
    zone: str = "1"
    employee_id: str = "0555505"
    pos_tax_id: str = "1537264827382"
    vendor_id: str = "82204"
    service_id: str = "00"
    item_name: str = "Test"
    vat_amt: str = "0"
    rept_type: str = "H"
    payment_channel: str = "C05"

@dataclass
class CustomerInfo:
    name: str = ""
    addr_1: str = ""
    addr_2: str = ""
    addr_3: str = ""
    phone_no: str = ""

@dataclass
class BillInfo:
    amt_min: str = "1"
    amt_max: str = "90000"
    bill_amt: str = "50"

@dataclass
class TransactionContext:
    """Class เก็บ Context ของการทำ Transaction ทั้งหมด แทนการใช้ Array ซ้อน Array"""
    store: StoreConfig = field(default_factory=StoreConfig)
    customer: CustomerInfo = field(default_factory=CustomerInfo)
    bill: BillInfo = field(default_factory=BillInfo)
    
    data_1: Any = None
    data_2: Any = None
    data_3: Any = None
    data_4: Any = None
    data_5: Any = None
    data_6: Any = None
    data_7: Any = None
    data_9: Any = None
    
    step: int = 1
    bus_date: str = field(default_factory=lambda: datetime.now().strftime("%Y/%m/%d"))
    bus_time: str = field(default_factory=lambda: datetime.now().strftime("%X"))
    common_trn_id: str = field(default_factory=lambda: str(random.randint(0, 100)))

    ref_data: Dict[str, str] = field(default_factory=dict)

    def prepare_data(self):
        """แปลงค่า int (Gen เลขสุ่ม) และ list (วนลูปตาม step) ให้เป็น String พร้อมใช้งาน"""
        data_fields = ['data_1', 'data_2', 'data_3', 'data_4', 'data_5', 'data_6', 'data_7', 'data_9']
        for attr in data_fields:
            val = getattr(self, attr)
            if isinstance(val, int):
                setattr(self, attr, ''.join([str(random.randint(0, 9)) for _ in range(val)]))
            elif isinstance(val, list):
                setattr(self, attr, str(val[self.step % len(val)]))
            elif val is None:
                setattr(self, attr, "")
            else:
                setattr(self, attr, str(val))
        self.step += 1

    def load_reference_from_response(self, response_dict: Dict[str, Any]):
        """
        ดึงและคำนวณค่าจาก Response ก่อนหน้า เพื่อใช้ประกอบ Payload ของ Action ถัดไป
        ครอบคลุม Logic การทำ Substring และการบวกค่า SUM_SEQ, SUM_AMT จากโค้ดต้นฉบับ
        """
        tx_id_full = str(response_dict.get('TX_ID', ''))
        bill_amt_full = str(response_dict.get('BILL_AMT', '0'))
        tx_id_full.split("|")
        seq_no1 = tx_id_full[0][:5]
        tx_id2 = tx_id_full[:8] if len(tx_id_full) >= 8 else tx_id_full
        
        sum_seq = ""
        sum_amt = ""
        
        # 2. คำนวณ SUM_SEQ และ SUM_AMT
        # ใช้ .zfill(5) แทนฟังก์ชัน CHECK_Length เดิม เพื่อเติมเลข 0 ด้านหน้าให้ครบ 5 หลัก
        if len(seq_no1) == 5:
            # กรณี Single Transaction
            try:
                sum_seq = str(int(seq_no1) + 1).zfill(5)
                sum_amt = str(float(bill_amt_full) + 2)
            except ValueError:
                sum_seq = seq_no1
                sum_amt = bill_amt_full
                
        elif len(seq_no1) > 5:
            # กรณี Multiple Transaction (มีการใช้เครื่องหมาย | คั่น)
            try:
                # โค้ดเดิม: ดึงตำแหน่ง [0:5] และ [6:11] มาบวก 2
                seq_no2 = str(int(seq_no1[0:5]) + 2).zfill(5)
                seq_no3 = str(int(seq_no1[6:11]) + 2).zfill(5) if len(seq_no1) >= 11 else ""
                sum_seq = f"{seq_no2}|{seq_no3}" if seq_no3 else seq_no2
                
                # จัดการ BILL_AMT ที่มี | คั่น
                if "|" in bill_amt_full:
                    parts = bill_amt_full.split("|")
                    amt1 = str(float(parts[0]) + 2)
                    amt2 = parts[1] 
                    sum_amt = f"{amt1}|{amt2}"
                else:
                    sum_amt = str(float(bill_amt_full) + 2)
            except Exception:
                # ป้องกัน Error กรณี Parsing ไม่สำเร็จ ให้ใช้ค่าตั้งต้น
                sum_seq = seq_no1
                sum_amt = bill_amt_full

        # 3. จัดเก็บลง Dictionary เพื่อให้ SoapPayloadBuilder เรียกใช้ได้ง่าย
        self.ref_data = {
            'VENDOR_ID': str(response_dict.get('VENDOR_ID', '')),
            'SERV_ID': str(response_dict.get('SERV_ID', '')),
            'TX_ID': tx_id2,
            'SEQ_NO': seq_no1,
            'SUM_SEQ': sum_seq,      # ค่าที่ถูกบวก +1 หรือ +2 แล้ว
            'BILL_AMT': bill_amt_full,
            'SUM_AMT': sum_amt,      # ค่าที่ถูกบวก +2 แล้ว
            
            # เก็บข้อมูล DATA 1-9
            'DATA_1': str(response_dict.get('DATA_1', '')),
            'DATA_2': str(response_dict.get('DATA_2', '')),
            'DATA_3': str(response_dict.get('DATA_3', '')),
            'DATA_4': str(response_dict.get('DATA_4', '')),
            'DATA_5': str(response_dict.get('DATA_5', '')),
            'DATA_6': str(response_dict.get('DATA_6', '')),
            'DATA_7': str(response_dict.get('DATA_7', '')),
            'DATA_9': str(response_dict.get('DATA_9', '')),
            
            # เก็บข้อมูลลูกค้า (แมปจาก XML Response ที่คุณตั้งไว้ใน Llistout)
            'CUST_NAME': str(response_dict.get('CUSTOMER_NAME', '')),
            'CUST_ADDR_1': str(response_dict.get('CUSTOMER_ADDR_1', '')),
            'CUST_ADDR_2': str(response_dict.get('CUSTOMER_ADDR_2', '')),
            'CUST_ADDR_3': str(response_dict.get('CUSTOMER_ADDR_3', '')),
            'CUST_PHONE_NO': str(response_dict.get('CUSTOMER_TEL_NO', ''))
        }

# ==========================================
# 2. Payload Builders (สร้าง XML)
# ==========================================

class SoapPayloadBuilder:
    """ทำหน้าที่สร้าง XML สำหรับยิง API ทุกรูปแบบ (แยกส่วนหน้าที่ชัดเจน ตามมาตรฐาน Enterprise)"""
    
    @staticmethod
    def build_data_exchange(tx: TransactionContext) -> str:
        return f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{tx.store.vendor_id}</VENDOR_ID><SERVICE_ID>{tx.store.service_id}</SERVICE_ID><METHOD>DataExchange</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{tx.store.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{tx.store.vendor_id}</VENDOR_ID><SERV_ID>{tx.store.service_id}</SERV_ID><SERVICE_ID>{tx.store.service_id}</SERVICE_ID><STORE_ID>{tx.store.store_id}</STORE_ID><STATION_ID>1</STATION_ID><BUS_DATE>{tx.bus_date}</BUS_DATE><BUS_TIME>{tx.bus_time}</BUS_TIME><SYS_DATE>{tx.bus_date}</SYS_DATE><SYS_TIME>{tx.bus_time}</SYS_TIME><COMMON_TRN_ID>{tx.common_trn_id}</COMMON_TRN_ID><SEQ_NO></SEQ_NO><CLIENT_SERV_SEQ></CLIENT_SERV_SEQ><SHIFT_ID>9</SHIFT_ID><TRANS_TYPE>N</TRANS_TYPE><ACCT_NO></ACCT_NO><BILL_AMT>{tx.bill.bill_amt}</BILL_AMT><ROUND_BILL_AMT>{tx.bill.bill_amt}</ROUND_BILL_AMT><VAT_AMT>{tx.store.vat_amt}</VAT_AMT><REPT_TYPE>{tx.store.rept_type}</REPT_TYPE><REPT_NO></REPT_NO><PREV_REF_SEQ></PREV_REF_SEQ><PREV_REF_DATE></PREV_REF_DATE><SERV_CHARGE_NO></SERV_CHARGE_NO><ITEM_NAME>{tx.store.item_name}</ITEM_NAME><ITEM_SELECTION>N</ITEM_SELECTION><EMPLOYEE_ID>{tx.store.employee_id}</EMPLOYEE_ID><POS_TAX_ID>{tx.store.pos_tax_id}</POS_TAX_ID><DATA_1>{tx.data_1}</DATA_1><DATA_2>{tx.data_2}</DATA_2><DATA_3>{tx.data_3}</DATA_3><DATA_4>{tx.data_4}</DATA_4><DATA_5>{tx.data_5}</DATA_5><DATA_6>{tx.data_6}</DATA_6><DATA_7>{tx.data_7}</DATA_7><DATA_9>{tx.data_9}</DATA_9><ZONE>{tx.store.zone}</ZONE><PAYMENT_TYPE>001</PAYMENT_TYPE><CANCEL_ID></CANCEL_ID><CUST_NAME>{tx.customer.name}</CUST_NAME><CUST_ADDR_1>{tx.customer.addr_1}</CUST_ADDR_1><CUST_ADDR_2>{tx.customer.addr_2}</CUST_ADDR_2><CUST_ADDR_3>{tx.customer.addr_3}</CUST_ADDR_3><CUST_PHONE_NO>{tx.customer.phone_no}</CUST_PHONE_NO></DATA></SERVICE_BOX></HQ_REQUEST>"""

    @staticmethod
    def build_cancel(tx: TransactionContext) -> str:
        ref = tx.ref_data
        return f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{tx.store.vendor_id}</VENDOR_ID><SERVICE_ID>{tx.store.service_id}</SERVICE_ID><METHOD>Cancel</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{tx.store.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{ref.get('VENDOR_ID', '')}</VENDOR_ID><SERV_ID>{ref.get('SERV_ID', '')}</SERV_ID><SERVICE_ID>{ref.get('SERV_ID', '')}</SERVICE_ID><STORE_ID>{tx.store.store_id}</STORE_ID><STATION_ID>1</STATION_ID><BUS_DATE>{tx.bus_date}</BUS_DATE><BUS_TIME>{tx.bus_time}</BUS_TIME><TX_ID>{ref.get('TX_ID', '')}</TX_ID><PAYMENT_TYPE>001</PAYMENT_TYPE><CANCEL_ID></CANCEL_ID></DATA></SERVICE_BOX></HQ_REQUEST>"""

    @staticmethod
    def build_data_exchange_confirm(tx: TransactionContext) -> str:
        ref = tx.ref_data
        return f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{tx.store.vendor_id}</VENDOR_ID><SERVICE_ID>{tx.store.service_id}</SERVICE_ID><METHOD>DataExchangeConfirm</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{tx.store.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{ref.get('VENDOR_ID', '')}</VENDOR_ID><SERV_ID>{ref.get('SERV_ID', '')}</SERV_ID><SERVICE_ID>{ref.get('SERV_ID', '')}</SERVICE_ID><STATION_ID>1</STATION_ID><STORE_ID>{tx.store.store_id}</STORE_ID><BUS_DATE>{tx.bus_date}</BUS_DATE><BUS_TIME>{tx.bus_time}</BUS_TIME><SYS_DATE>{tx.bus_date}</SYS_DATE><SYS_TIME>{tx.bus_time}</SYS_TIME><TX_ID>{ref.get('TX_ID', '')}</TX_ID><SEQ_NO>{ref.get('SEQ_NO', '')}</SEQ_NO><EMPLOYEE_ID>{tx.store.employee_id}</EMPLOYEE_ID><CLIENT_SERV_SEQ>{ref.get('SEQ_NO', '')}</CLIENT_SERV_SEQ><SERV_ID>{tx.store.service_id}</SERV_ID><BILL_AMT>{ref.get('BILL_AMT', '')}</BILL_AMT><ROUND_BILL_AMT>{ref.get('BILL_AMT', '')}</ROUND_BILL_AMT><ACCT_NO></ACCT_NO><VAT_AMT>{tx.store.vat_amt}</VAT_AMT><DATA_1>{ref.get('DATA_1', '')}</DATA_1><DATA_2>{ref.get('DATA_2', '')}</DATA_2><DATA_3>{ref.get('DATA_3', '')}</DATA_3><DATA_4>{ref.get('DATA_4', '')}</DATA_4><DATA_5>{ref.get('DATA_5', '')}</DATA_5><DATA_6>{ref.get('DATA_6', '')}</DATA_6><DATA_7>{ref.get('DATA_7', '')}</DATA_7><DATA_9>{ref.get('DATA_9', '')}</DATA_9><ZONE>{tx.store.zone}</ZONE><PAYMENT_TYPE>001</PAYMENT_TYPE><TOT_BILL_TRANS></TOT_BILL_TRANS><TOT_BILL_AMT></TOT_BILL_AMT><TOT_VENDOR_TRANS></TOT_VENDOR_TRANS><TOT_VENDOR_AMT></TOT_VENDOR_AMT><TOT_COUNTER_TRANS></TOT_COUNTER_TRANS><TOT_COUNTER_AMT></TOT_COUNTER_AMT><TOT_CLIENT_TRANS></TOT_CLIENT_TRANS><TOT_CLIENT_AMT></TOT_CLIENT_AMT><TOT_BILL_TRANS_OR></TOT_BILL_TRANS_OR><TOT_BILL_AMT_OR></TOT_BILL_AMT_OR><CANCEL_ID></CANCEL_ID><CANCEL_ID></CANCEL_ID><CUST_NAME>{ref.get('CUST_NAME', '')}</CUST_NAME><CUST_ADDR_1>{ref.get('CUST_ADDR_1', '')}</CUST_ADDR_1><CUST_ADDR_2>{ref.get('CUST_ADDR_2', '')}</CUST_ADDR_2><CUST_ADDR_3>{ref.get('CUST_ADDR_3', '')}</CUST_ADDR_3><CUST_PHONE_NO>{ref.get('CUST_PHONE_NO', '')}</CUST_PHONE_NO></DATA></SERVICE_BOX></HQ_REQUEST>"""

    @staticmethod
    def build_print(tx: TransactionContext) -> str:
        ref = tx.ref_data
        return f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{tx.store.vendor_id}</VENDOR_ID><SERVICE_ID>{tx.store.service_id}</SERVICE_ID><METHOD>REPRINTSLIP</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{tx.store.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{ref.get('VENDOR_ID', '')}</VENDOR_ID><SERV_ID>{ref.get('SERV_ID', '')}</SERV_ID><SERVICE_ID>{ref.get('SERV_ID', '')}</SERVICE_ID><STORE_ID>{tx.store.store_id}</STORE_ID><STATION_ID>1</STATION_ID><BUS_DATE>{tx.bus_date}</BUS_DATE><BUS_TIME>{tx.bus_time}</BUS_TIME><COMMON_TRN_ID>{tx.common_trn_id}</COMMON_TRN_ID><SEQ_NO>{ref.get('SEQ_NO', '')}</SEQ_NO><CLIENT_SERV_SEQ>{ref.get('SEQ_NO', '')}</CLIENT_SERV_SEQ><SHIFT_ID>9</SHIFT_ID><TRANS_TYPE>N</TRANS_TYPE><ACCT_NO></ACCT_NO><BILL_AMT>{ref.get('BILL_AMT', '')}</BILL_AMT><ROUND_BILL_AMT>{ref.get('BILL_AMT', '')}</ROUND_BILL_AMT><VAT_AMT>{tx.store.vat_amt}</VAT_AMT><REPT_TYPE>{tx.store.rept_type}</REPT_TYPE><TX_ID>{ref.get('TX_ID', '')}</TX_ID><REPT_NO></REPT_NO><PREV_REF_SEQ></PREV_REF_SEQ><PREV_REF_DATE></PREV_REF_DATE><SERV_CHARGE_NO></SERV_CHARGE_NO><ITEM_NAME>{tx.store.item_name}</ITEM_NAME><ITEM_SELECTION>N</ITEM_SELECTION><EMPLOYEE_ID>{tx.store.employee_id}</EMPLOYEE_ID><POS_TAX_ID>{tx.store.pos_tax_id}</POS_TAX_ID><DATA_1>{ref.get('DATA_1', '')}</DATA_1><DATA_2>{ref.get('DATA_2', '')}</DATA_2><DATA_3>{ref.get('DATA_3', '')}</DATA_3><DATA_4>{ref.get('DATA_4', '')}</DATA_4><DATA_5>{ref.get('DATA_5', '')}</DATA_5><DATA_6>{ref.get('DATA_6', '')}</DATA_6><DATA_7>{ref.get('DATA_7', '')}</DATA_7><DATA_9>{ref.get('DATA_9', '')}</DATA_9><ZONE>{tx.store.zone}</ZONE><CANCEL_ID></CANCEL_ID></DATA></SERVICE_BOX></HQ_REQUEST>"""

    @staticmethod
    def build_or(tx: TransactionContext) -> str:
        ref = tx.ref_data
        return f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{tx.store.vendor_id}</VENDOR_ID><SERVICE_ID>{tx.store.service_id}</SERVICE_ID><METHOD>OR</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{tx.store.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{ref.get('VENDOR_ID', '')}</VENDOR_ID><SERVICE_ID>{ref.get('SERV_ID', '')}</SERVICE_ID><SERV_ID>{ref.get('SERV_ID', '')}</SERV_ID><STORE_ID>{tx.store.store_id}</STORE_ID><STATION_ID>1</STATION_ID><BUS_DATE>{tx.bus_date}</BUS_DATE><BUS_TIME>{tx.bus_time}</BUS_TIME><SYS_DATE>{tx.bus_date}</SYS_DATE><SYS_TIME>{tx.bus_time}</SYS_TIME><TX_ID>{ref.get('TX_ID', '')}</TX_ID><BILL_AMT>{ref.get('BILL_AMT', '')}</BILL_AMT><ROUND_BILL_AMT>{ref.get('BILL_AMT', '')}</ROUND_BILL_AMT><VAT_AMT>{tx.store.vat_amt}</VAT_AMT><PAYMENT_TYPE>001</PAYMENT_TYPE><CANCEL_ID></CANCEL_ID></DATA></SERVICE_BOX></HQ_REQUEST>"""

    @staticmethod
    def build_or_cancel(tx: TransactionContext) -> str:
        ref = tx.ref_data
        return f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{tx.store.vendor_id}</VENDOR_ID><SERVICE_ID>{tx.store.service_id}</SERVICE_ID><METHOD>ORCancel</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{tx.store.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{ref.get('VENDOR_ID', '')}</VENDOR_ID><SERVICE_ID>{ref.get('SERV_ID', '')}</SERVICE_ID><SERV_ID>{ref.get('SERV_ID', '')}</SERV_ID><STORE_ID>{tx.store.store_id}</STORE_ID><STATION_ID>1</STATION_ID><BUS_DATE>{tx.bus_date}</BUS_DATE><BUS_TIME>{tx.bus_time}</BUS_TIME><TX_ID>{ref.get('TX_ID', '')}</TX_ID><PAYMENT_TYPE>001</PAYMENT_TYPE><CANCEL_ID></CANCEL_ID></DATA></SERVICE_BOX></HQ_REQUEST>"""

    @staticmethod
    def build_or_confirm(tx: TransactionContext) -> str:
        ref = tx.ref_data
        return f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{tx.store.vendor_id}</VENDOR_ID><SERVICE_ID>{tx.store.service_id}</SERVICE_ID><METHOD>ORConfirm</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{tx.store.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{ref.get('VENDOR_ID', '')}</VENDOR_ID><SERVICE_ID>{ref.get('SERV_ID', '')}</SERVICE_ID><SERV_ID>{ref.get('SERV_ID', '')}</SERV_ID><STATION_ID>1</STATION_ID><STORE_ID>{tx.store.store_id}</STORE_ID><BUS_DATE>{tx.bus_date}</BUS_DATE><BUS_TIME>{tx.bus_time}</BUS_TIME><BILL_AMT>{ref.get('BILL_AMT', '')}</BILL_AMT><ROUND_BILL_AMT>{ref.get('BILL_AMT', '')}</ROUND_BILL_AMT><VAT_AMT>{tx.store.vat_amt}</VAT_AMT><TX_ID>{ref.get('TX_ID', '')}</TX_ID><SEQ_NO>{ref.get('SUM_SEQ', '')}</SEQ_NO><CLIENT_SERV_SEQ>{ref.get('SUM_SEQ', '')}</CLIENT_SERV_SEQ><SERV_ID>{ref.get('SERV_ID', '')}</SERV_ID><DATA_1>{ref.get('DATA_1', '')}</DATA_1><DATA_2>{ref.get('DATA_2', '')}</DATA_2><DATA_3>{ref.get('DATA_3', '')}</DATA_3><DATA_4>{ref.get('DATA_4', '')}</DATA_4><DATA_5>{ref.get('DATA_5', '')}</DATA_5><DATA_6>{ref.get('DATA_6', '')}</DATA_6><DATA_7>{ref.get('DATA_7', '')}</DATA_7><DATA_9>{ref.get('DATA_9', '')}</DATA_9><ZONE>{tx.store.zone}</ZONE><PAYMENT_TYPE>001</PAYMENT_TYPE><TOT_BILL_TRANS></TOT_BILL_TRANS><TOT_BILL_AMT></TOT_BILL_AMT><TOT_VENDOR_TRANS></TOT_VENDOR_TRANS><TOT_VENDOR_AMT></TOT_VENDOR_AMT><TOT_COUNTER_TRANS></TOT_COUNTER_TRANS><TOT_COUNTER_AMT></TOT_COUNTER_AMT><TOT_CLIENT_TRANS></TOT_CLIENT_TRANS><TOT_CLIENT_AMT></TOT_CLIENT_AMT><TOT_BILL_TRANS_OR></TOT_BILL_TRANS_OR><TOT_BILL_AMT_OR></TOT_BILL_AMT_OR><CANCEL_ID></CANCEL_ID></DATA></SERVICE_BOX></HQ_REQUEST>"""

    @staticmethod
    def build_amt_confirm(tx: TransactionContext) -> str:
        ref = tx.ref_data
        return f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{tx.store.vendor_id}</VENDOR_ID><SERVICE_ID>{tx.store.service_id}</SERVICE_ID><METHOD>DataExchangeConfirm</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{tx.store.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{ref.get('VENDOR_ID', '')}</VENDOR_ID><SERV_ID>{ref.get('SERV_ID', '')}</SERV_ID><SERVICE_ID>{ref.get('SERV_ID', '')}</SERVICE_ID><STATION_ID>1</STATION_ID><STORE_ID>{tx.store.store_id}</STORE_ID><BUS_DATE>{tx.bus_date}</BUS_DATE><BUS_TIME>{tx.bus_time}</BUS_TIME><SYS_DATE>{tx.bus_date}</SYS_DATE><SYS_TIME>{tx.bus_time}</SYS_TIME><TX_ID>{ref.get('TX_ID', '')}</TX_ID><SEQ_NO>{ref.get('SEQ_NO', '')}</SEQ_NO><EMPLOYEE_ID>{tx.store.employee_id}</EMPLOYEE_ID><CLIENT_SERV_SEQ>{ref.get('SEQ_NO', '')}</CLIENT_SERV_SEQ><SERV_ID>{tx.store.service_id}</SERV_ID><BILL_AMT>{ref.get('SUM_AMT', '')}</BILL_AMT><ROUND_BILL_AMT>{ref.get('SUM_AMT', '')}</ROUND_BILL_AMT><ACCT_NO></ACCT_NO><VAT_AMT>{tx.store.vat_amt}</VAT_AMT><DATA_1>{ref.get('DATA_1', '')}</DATA_1><DATA_2>{ref.get('DATA_2', '')}</DATA_2><DATA_3>{ref.get('DATA_3', '')}</DATA_3><DATA_4>{ref.get('DATA_4', '')}</DATA_4><DATA_5>{ref.get('DATA_5', '')}</DATA_5><DATA_6>{ref.get('DATA_6', '')}</DATA_6><DATA_7>{ref.get('DATA_7', '')}</DATA_7><DATA_9>{ref.get('DATA_9', '')}</DATA_9><ZONE>{tx.store.zone}</ZONE><PAYMENT_TYPE>001</PAYMENT_TYPE><TOT_BILL_TRANS></TOT_BILL_TRANS><TOT_BILL_AMT></TOT_BILL_AMT><TOT_VENDOR_TRANS></TOT_VENDOR_TRANS><TOT_VENDOR_AMT></TOT_VENDOR_AMT><TOT_COUNTER_TRANS></TOT_COUNTER_TRANS><TOT_COUNTER_AMT></TOT_COUNTER_AMT><TOT_CLIENT_TRANS></TOT_CLIENT_TRANS><TOT_CLIENT_AMT></TOT_CLIENT_AMT><TOT_BILL_TRANS_OR></TOT_BILL_TRANS_OR><TOT_BILL_AMT_OR></TOT_BILL_AMT_OR><CANCEL_ID></CANCEL_ID><CANCEL_ID></CANCEL_ID><CUST_NAME>{ref.get('CUST_NAME', '')}</CUST_NAME><CUST_ADDR_1>{ref.get('CUST_ADDR_1', '')}</CUST_ADDR_1><CUST_ADDR_2>{ref.get('CUST_ADDR_2', '')}</CUST_ADDR_2><CUST_ADDR_3>{ref.get('CUST_ADDR_3', '')}</CUST_ADDR_3><CUST_PHONE_NO>{ref.get('CUST_PHONE_NO', '')}</CUST_PHONE_NO></DATA></SERVICE_BOX></HQ_REQUEST>"""

    @staticmethod
    def build_std_tk_inquiry(tx: TransactionContext) -> str:
        return f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{tx.store.vendor_id}</VENDOR_ID><SERVICE_ID>{tx.store.service_id}</SERVICE_ID><METHOD>StdTkInquiry</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{tx.store.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{tx.store.vendor_id}</VENDOR_ID><SERV_ID>{tx.store.service_id}</SERV_ID><SERVICE_ID>{tx.store.service_id}</SERVICE_ID><STORE_ID>{tx.store.store_id}</STORE_ID><STATION_ID>1</STATION_ID><BUS_DATE>{tx.bus_date}</BUS_DATE><BUS_TIME>{tx.bus_time}</BUS_TIME><SYS_DATE>{tx.bus_date}</SYS_DATE><SYS_TIME>{tx.bus_time}</SYS_TIME><COMMON_TRN_ID>{tx.common_trn_id}</COMMON_TRN_ID><SEQ_NO></SEQ_NO><CLIENT_SERV_SEQ></CLIENT_SERV_SEQ><SHIFT_ID></SHIFT_ID><TRANS_TYPE></TRANS_TYPE><ACCT_NO></ACCT_NO><BILL_AMT>{tx.bill.bill_amt}</BILL_AMT><ROUND_BILL_AMT>{tx.bill.bill_amt}</ROUND_BILL_AMT><VAT_AMT>{tx.store.vat_amt}</VAT_AMT><REPT_TYPE>{tx.store.rept_type}</REPT_TYPE><REPT_NO></REPT_NO><PREV_REF_SEQ></PREV_REF_SEQ><PREV_REF_DATE></PREV_REF_DATE><SERV_CHARGE_NO></SERV_CHARGE_NO><ITEM_NAME>{tx.store.item_name}</ITEM_NAME><ITEM_SELECTION></ITEM_SELECTION><EMPLOYEE_ID>{tx.store.employee_id}</EMPLOYEE_ID><POS_TAX_ID>{tx.store.pos_tax_id}</POS_TAX_ID><DATA_1>{tx.data_1}</DATA_1><DATA_2>{tx.data_2}</DATA_2><DATA_3>{tx.data_3}</DATA_3><DATA_4>{tx.data_4}</DATA_4><DATA_5>{tx.data_5}</DATA_5><DATA_6>{tx.data_6}</DATA_6><DATA_7>{tx.data_7}</DATA_7><DATA_9>{tx.data_9}</DATA_9><ZONE>{tx.store.zone}</ZONE><PAYMENT_TYPE>001</PAYMENT_TYPE><CANCEL_ID></CANCEL_ID><CUST_NAME>{tx.customer.name}</CUST_NAME><CUST_ADDR_1>{tx.customer.addr_1}</CUST_ADDR_1><CUST_ADDR_2>{tx.customer.addr_2}</CUST_ADDR_2><CUST_ADDR_3>{tx.customer.addr_3}</CUST_ADDR_3><CUST_PHONE_NO>{tx.customer.phone_no}</CUST_PHONE_NO></DATA></SERVICE_BOX></HQ_REQUEST>"""

    @staticmethod
    def build_inquiry(tx: TransactionContext) -> str:
        return f"""<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>{tx.store.vendor_id}</VENDOR_ID><SERVICE_ID>{tx.store.service_id}</SERVICE_ID><METHOD>Inquiry</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>{tx.store.payment_channel}</PAYMENT_CHANNEL><VENDOR_ID>{tx.store.vendor_id}</VENDOR_ID><SERV_ID>{tx.store.service_id}</SERV_ID><SERVICE_ID>{tx.store.service_id}</SERVICE_ID><STORE_ID>{tx.store.store_id}</STORE_ID><STATION_ID>1</STATION_ID><BUS_DATE>{tx.bus_date}</BUS_DATE><BUS_TIME>{tx.bus_time}</BUS_TIME><SYS_DATE>{tx.bus_date}</SYS_DATE><SYS_TIME>{tx.bus_time}</SYS_TIME><COMMON_TRN_ID>{tx.common_trn_id}</COMMON_TRN_ID><SEQ_NO/><CLIENT_SERV_SEQ/><SHIFT_ID></SHIFT_ID><TRANS_TYPE>N</TRANS_TYPE><ACCT_NO/><BILL_AMT>{tx.bill.bill_amt}</BILL_AMT><ROUND_BILL_AMT/><VAT_AMT>{tx.store.vat_amt}</VAT_AMT><REPT_TYPE>{tx.store.rept_type}</REPT_TYPE><REPT_NO/><PREV_REF_SEQ/><PREV_REF_DATE/><SERV_CHARGE_NO/><ITEM_NAME>{tx.store.item_name}</ITEM_NAME><ITEM_SELECTION>N</ITEM_SELECTION><EMPLOYEE_ID>{tx.store.employee_id}</EMPLOYEE_ID><POS_TAX_ID/><DATA_1>{tx.data_1}</DATA_1><DATA_2>{tx.data_2}</DATA_2><DATA_3>{tx.data_3}</DATA_3><DATA_4>{tx.data_4}</DATA_4><DATA_5>{tx.data_5}</DATA_5><DATA_6>{tx.data_6}</DATA_6><DATA_7>{tx.data_7}</DATA_7><DATA_9>{tx.data_9}</DATA_9><ZONE>{tx.store.zone}</ZONE><PAYMENT_TYPE>001</PAYMENT_TYPE><CANCEL_ID/></DATA></SERVICE_BOX></HQ_REQUEST>"""

# ==========================================
# 3. Network & API Client (ตัวจัดการ API)
# ==========================================

class SoapApiClient:
    def __init__(self, endpoint_url: str):
        self.endpoint_url = endpoint_url

    def _wrap_soap_envelope(self, action_payload: str) -> str:
        return f"""<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/" xmlns:por="http://portal.cs/">
        <soapenv:Header/>
        <soapenv:Body><por:CSService><arg0><![CDATA[{action_payload}]]></arg0></por:CSService></soapenv:Body>
        </soapenv:Envelope>"""

    def send_request(self, xml_payload: str) -> str:
        """ส่งข้อมูลและถอดรหัส Base64 Return ให้พร้อมใช้งาน"""
        soap_data = self._wrap_soap_envelope(xml_payload)
        headers = {'Content-Type': 'text/xml'}
        
        try:
            response = requests.post(self.endpoint_url, headers=headers, data=soap_data.encode("utf-8"))
            response.raise_for_status()
            
            # Extract CDATA and Decode Base64
            encoded_val = response.text.split("<return>")[-1].split("</return>")[0]
            decoded_xml = base64.b64decode(encoded_val).decode('utf-8')
            return decoded_xml
            
        except requests.exceptions.RequestException as e:
            print(f"❌ API Connection Error: {e}")
            return ""

# ==========================================
# 4. Response Parser (จัดการข้อมูลขากลับ)
# ==========================================

class ResponseParser:
    FIELDS = ['SUCCESS', 'CODE', 'DESCRIPTOR', 'VENDOR_ID', 'SERV_ID', 'TX_ID', 'PRINTSLIP', 'VAT', 'BILL_AMT', 'FEE', 'FEE_VAT', 'DATA_1', 'DATA_2', 'DATA_3', 'DATA_4', 'DATA_5', 'DATA_6', 'DATA_7', 'DATA_9', 'CUSTOMER_NAME', 'CUSTOMER_ADDR_1', 'CUSTOMER_ADDR_2', 'CUSTOMER_ADDR_3', 'CUSTOMER_TEL_NO', 'ACCT_NO']

    @staticmethod
    def parse_to_dict(xml_response: str) -> Dict[str, Any]:
        """แปลง XML เป็น Dictionary ให้ใช้งานต่อได้ง่าย"""
        if not xml_response: return {}
        try:
            parsed_data = xd.parse(xml_response)
            hq_response = parsed_data.get('HQ_RESPONSE', {})
            return {field: hq_response.get(field, '') for field in ResponseParser.FIELDS}
        except Exception as e:
            print(f"❌ Parse Error: {e}")
            return {}

    @staticmethod
    def display_as_dataframe(response_dict: Dict[str, Any]):
        """แสดงผลเฉพาะ Field ที่มีข้อมูลผ่าน Pandas (ทดแทน Dataframe ตัวเดิม)"""
        filtered_dict = {k: v for k, v in response_dict.items() if v is not None and str(v).strip() != ''}
        df = pd.DataFrame([filtered_dict])
        display(df)  # ใช้ได้ทันทีหากรันใน Jupyter/Colab

# ==========================================
# 5. Database Connector (จัดการเชื่อมต่อ Oracle)
# ==========================================

class DatabaseConnector:
    def __init__(self, ip='10.182.236.52', service_name='ONLPRD'):
        self.dsn = oracledb.makedsn(ip, '1521', service_name=service_name)
        self.user = 'CS_DEV'
        self.pwd = '1234'

    def execute_query(self, sql_query: str):
        """ใช้ Context Manager (with) เพื่อให้มั่นใจว่า Connection จะถูกปิดเสมอเมื่อใช้งานเสร็จ"""
        try:
            with oracledb.connect(user=self.user, password=self.pwd, dsn=self.dsn) as conn:
                with conn.cursor() as cursor:
                    cursor.execute(sql_query)
                    
                    if sql_query.strip().upper().startswith("SELECT"):
                        result = cursor.fetchall()
                        return result[-1] if len(result) == 1 else result
                    else:
                        conn.commit()
                        print("✅ อัพเดทข้อมูลใน Database สำเร็จ")
                        return True
        except Exception as e:
            print(f"❌ Database Error: {e}")
            return None


class OracleManager(DatabaseConnector):
    """คลาสสำหรับจัดการระบบตรวจสอบฐานข้อมูล (Pre-Check & Post-Check)"""
    
    def get_dataframe(self, query: str, params: dict = None) -> pd.DataFrame:
        """Helper Function: ดึงข้อมูลจาก Database และแปลงเป็น Pandas DataFrame ทันที"""
        try:
            with oracledb.connect(user=self.user, password=self.pwd, dsn=self.dsn) as conn:
                # ใช้ pandas read_sql ช่วยให้ทำงานกับข้อมูลแบบตาราง (Excel/JSON) ได้ง่ายขึ้นมาก
                df = pd.read_sql(query, con=conn, params=params)
                return df
        except Exception as e:
            print(f"❌ Database Query Error: {e}")
            return pd.DataFrame()

    # ==========================================
    # Phase 1: Pre-Check (ตรวจสอบ Config 5 ตาราง)
    # ==========================================
    def check_vendor_config(self, vendor_id: str, service_id: str, action: Literal['show', 'export'] = 'show') -> Any:
        """ตรวจสอบ Config 5 ตาราง และเลือก Output เป็น JSON ('show') หรือไฟล์ Excel ('export')"""
        
        # ใช้ Bind Variable (:vendor_id) แทน f-string มาตรฐานระดับ Enterprise
        params = {"vendor_id": vendor_id, "service_id": service_id}
        
        # กำหนด 5 ตารางที่ต้องการตรวจสอบ (ปรับแก้ชื่อตารางที่ 4 และ 5 ได้ตามโครงสร้างจริงของคุณ)
        queries = {
            "Client_Config": "SELECT * FROM ONLSTD.WS_CLIENT_CONFIG WHERE VENDOR_ID = :vendor_id AND SERVICE_ID = :service_id",
            "Charge_Step": "SELECT * FROM ONLSTD.WS_CLIENT_CHARGE_STEP WHERE VENDOR_ID = :vendor_id AND SERVICE_ID = :service_id",
            "Reprint_Limit": "SELECT * FROM ONLSTD.WS_CLIENT_REPRINT WHERE VENDOR_ID = :vendor_id AND SERVICE_ID = :service_id",
            "AutoFix_Tx": "SELECT * FROM ONLSTD.WS_CLIENT_AUTOFIXTX WHERE VENDOR_ID = :vendor_id AND SERVICE_ID = :service_id",
            "Vendor_Master": "SELECT * FROM ONLSTD.WS_VENDOR_MASTER WHERE VENDOR_ID = :vendor_id" # อ้างอิงด้วย vendor_id อย่างเดียว
        }
        
        # Query ข้อมูลทั้งหมดเก็บไว้ในรูปแบบ Dictionary ของ DataFrame
        print(f"🔍 [Pre-Check] กำลังตรวจสอบ Config ของ Vendor: {vendor_id}...")
        results_df = {name: self.get_dataframe(sql, params) for name, sql in queries.items()}
        
        if action == 'show':
            # แปลง DataFrame เป็น JSON Dictionary
            json_result = {name: json.loads(df.to_json(orient='records')) for name, df in results_df.items()}
            print("✅ [Show Mode] สรุปข้อมูลรูปแบบ JSON สำเร็จ")
            return json_result
            
        elif action == 'export':
            # บันทึกแต่ละตารางลงคนละ Sheet ในไฟล์ Excel (.xlsx) เดียวกัน
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            file_name = f"VendorConfig_{vendor_id}_{timestamp}.xlsx"
            
            try:
                # จำเป็นต้องใช้ไลบรารี openpyxl หรือ xlsxwriter (pip install openpyxl)
                with pd.ExcelWriter(file_name, engine='openpyxl') as writer:
                    for name, df in results_df.items():
                        df.to_excel(writer, sheet_name=name, index=False)
                print(f"✅ [Export Mode] สร้างและบันทึกไฟล์ Excel สำเร็จ: {file_name}")
                return file_name
            except Exception as e:
                print(f"❌ Error Exporting Excel: {e}")
                return None

    # ==========================================
    # Phase 2: Post-Check (ค้นหา TX_ID หลังทำรายการ)
    # ==========================================
    def get_transaction_by_tx_id(self, tx_id: str) -> pd.DataFrame:
        """นำ TX_ID ที่ได้จาก Response มาค้นหาใน Database เพื่อยืนยันข้อมูล"""
        if not tx_id:
            print("⚠️ ไม่พบ TX_ID สำหรับใช้ค้นหาข้อมูล")
            return pd.DataFrame()
            
        print(f"🔍 [Post-Check] กำลังค้นหา Transaction: {tx_id} ในระบบ...")
        
        # มีการปรับ SQL เพื่อแสดงค่า STORE_ID และแสดง PAY เมื่อ TS TD มีข้อมูล
        query = """
            SELECT 
                TX_ID, 
                STORE_ID,
                CASE WHEN TS IS NOT NULL AND TD IS NOT NULL THEN PAY ELSE NULL END AS PAY_INFO,
                SYSTEM_DATE_TIME,
                Tbl.*
            FROM ONLSTD.WS_ONLINE_TX Tbl
            WHERE TX_ID = :tx_id OR R_SERVICE_RUNNO = :tx_id
        """
        params = {"tx_id": tx_id}
        
        df = self.get_dataframe(query, params)
        if df.empty:
            print("⚠️ ค้นหาสำเร็จ แต่ยังไม่พบข้อมูล Transaction นี้บันทึกลงใน Database")
        else:
            print("✅ พบข้อมูล Transaction ใน Database แล้ว")
        return df

# %%
URL = "http://qacspos.counterservice.co.th:80/DCWSCDSONLINE/WSCDSService"

# 1. สร้างและตั้งค่า Transaction 
tx = TransactionContext(data_1=10, data_2=13)
tx.store.store_id = "09884"
tx.store.vendor_id = "0994000160127"
tx.store.service_id = "00"
tx.bill.bill_amt = "80"

tx.prepare_data() # แปลงเลข Gen/List ให้พร้อมใช้งาน

# 2. จัดเตรียมเครื่องมือติดต่อ API
api_client = SoapApiClient(endpoint_url=URL)

# --- ACTION 1: DataExchange ---
print("▶️ กำลังส่ง DataExchange...")
exchange_xml = SoapPayloadBuilder.build_data_exchange(tx)
ic(exchange_xml)
response_xml = api_client.send_request(exchange_xml)

res_dict = ResponseParser.parse_to_dict(response_xml)
ResponseParser.display_as_dataframe(res_dict)

print(res_dict)
if res_dict.get('CODE') == "100":  
    print("\n▶️ กำลังส่ง Cancel ต่อเนื่อง...")
    tx.load_reference_from_response(res_dict) # โหลดค่าอ้างอิงจากรอบแรกมาเก็บไว้
    
    cancel_xml = SoapPayloadBuilder.build_cancel(tx)
    cancel_res_xml = api_client.send_request(cancel_xml)
    
    cancel_res_dict = ResponseParser.parse_to_dict(cancel_res_xml)
    ResponseParser.display_as_dataframe(cancel_res_dict)
# Out:
# ic| exchange_xml: '<?xml version="1.0" encoding="UTF-8"?><HQ_REQUEST><SERVICE_BOX><ADDRESS><VENDOR_ID>0994000160127</VENDOR_ID><SERVICE_ID>00</SERVICE_ID><METHOD>DataExchange</METHOD></ADDRESS><DATA><PAYMENT_CHANNEL>C05</PAYMENT_CHANNEL><VENDOR_ID>0994000160127</VENDOR_ID><SERV_ID>00</SERV_ID><SERVICE_ID>00</SERVICE_ID><STORE_ID>09884</STORE_ID><STATION_ID>1</STATION_ID><BUS_DATE>2026/03/12</BUS_DATE><BUS_TIME>09:43:50</BUS_TIME><SYS_DATE>2026/03/12</SYS_DATE><SYS_TIME>09:43:50</SYS_TIME><COMMON_TRN_ID>69</COMMON_TRN_ID><SEQ_NO></SEQ_NO><CLIENT_SERV_SEQ></CLIENT_SERV_SEQ><SHIFT_ID>9</SHIFT_ID><TRANS_TYPE>N</TRANS_TYPE><ACCT_NO></ACCT_NO><BILL_AMT>80</BILL_AMT><ROUND_BILL_AMT>80</ROUND_BILL_AMT><VAT_AMT>0</VAT_AMT><REPT_TYPE>H</REPT_TYPE><REPT_NO></REPT_NO><PREV_REF_SEQ></PREV_REF_SEQ><PREV_REF_DATE></PREV_REF_DATE><SERV_CHARGE_NO></SERV_CHARGE_NO><ITEM_NAME>Test</ITEM_NAME><ITEM_SELECTION>N</ITEM_SELECTION><EMPLOYEE_ID>0555505</EMPLOYEE_ID><POS_TAX_ID>1537264827382</POS_TAX_ID><DATA_1>5327075055</DATA_1><DATA_2>7374296968974</DATA_2><DATA_3></DATA_3><DATA_4></DATA_4><DATA_5></DATA_5><DATA_6></DATA_6><DATA_7></DATA_7><DATA_9></DATA_9><ZONE>1</ZONE><PAYMENT_TYPE>001</PAYMENT_TYPE><CANCEL_ID></CANCEL_ID><CUST_NAME></CUST_NAME><CUST_ADDR_1></CUST_ADDR_1><CUST_ADDR_2></CUST_ADDR_2><CUST_ADDR_3></CUST_ADDR_3><CUST_PHONE_NO></CUST_PHONE_NO></DATA></SERVICE_BOX></HQ_REQUEST>'
# ▶️ กำลังส่ง DataExchange...
#   SUCCESS CODE DESCRIPTOR      VENDOR_ID SERV_ID     TX_ID BILL_AMT FEE  \
# 0    true  100    success  0994000160127      00  14678528       80   0
#
#   FEE_VAT      DATA_1         DATA_2
# 0       0  5327075055  7374296968974
# {'SUCCESS': 'true', 'CODE': '100', 'DESCRIPTOR': 'success', 'VENDOR_ID': '0994000160127', 'SERV_ID': '00', 'TX_ID': '14678528', 'PRINTSLIP': None, 'VAT': None, 'BILL_AMT': '80', 'FEE': '0', 'FEE_VAT': '0', 'DATA_1': '5327075055', 'DATA_2': '7374296968974', 'DATA_3': None, 'DATA_4': None, 'DATA_5': None, 'DATA_6': None, 'DATA_7': None, 'DATA_9': '', 'CUSTOMER_NAME': None, 'CUSTOMER_ADDR_1': None, 'CUSTOMER_ADDR_2': None, 'CUSTOMER_ADDR_3': None, 'CUSTOMER_TEL_NO': None, 'ACCT_NO': None}
#
# ▶️ กำลังส่ง Cancel ต่อเนื่อง...
#   SUCCESS CODE DESCRIPTOR
# 0    true  100    success

# %%
URL = "http://qacspos.counterservice.co.th:80/DCWSCDSONLINE/WSCDSService"
db_manager = OracleManager(ip='10.182.236.52', service_name='ONLPRD')

# ------------------------------------------
# STEP 1: Pre-Check (เช็ค Config ก่อนเริ่มงาน)
# ------------------------------------------
vendor_to_check = "0994000160127"
service_to_check = "00"

# ให้ User เลือกว่าจะ 'show' หรือ 'export'
action_type = 'export' # เปลี่ยนเป็น 'show' ถ้าต้องการดู JSON

config_data = db_manager.check_vendor_config(
    vendor_id=vendor_to_check, 
    service_id=service_to_check, 
    action=action_type
)

# ถ้าเลือก 'show' ลองปริ้นข้อมูลออกมาดู
if action_type == 'show':
    print(json.dumps(config_data, indent=4, ensure_ascii=False))

# ------------------------------------------
# STEP 2: เตรียมและยิง API
# ------------------------------------------
tx = TransactionContext(data_1=10, data_2=13)
tx.store.vendor_id = vendor_to_check
tx.store.service_id = service_to_check
tx.prepare_data()

api_client = SoapApiClient(endpoint_url=URL)

print("\n▶️ กำลังส่ง DataExchange API...")
exchange_xml = SoapPayloadBuilder.build_data_exchange(tx)
response_xml = api_client.send_request(exchange_xml)

# แปลง Response XML เป็น Dict
res_dict = ResponseParser.parse_to_dict(response_xml)
ResponseParser.display_as_dataframe(res_dict)

# ------------------------------------------
# STEP 3: Post-Check (ตรวจเช็ค Database หลังทำรายการ)
# ------------------------------------------
if res_dict.get('CODE') == "100":
    returned_tx_id = res_dict.get('TX_ID')
    
    # ถ้ามี TX_ID กลับมา ให้นำไป Query ตาราง WS_ONLINE_TX ต่อทันที
    if returned_tx_id:
        tx_data_df = db_manager.get_transaction_by_tx_id(tx_id=returned_tx_id[:8])
        display(tx_data_df) # แสดงผลข้อมูลที่บันทึกลง Oracle สำเร็จ
# Out:
# 🔍 [Pre-Check] กำลังตรวจสอบ Config ของ Vendor: 0994000160127...
# C:\Users\nakarinsue\AppData\Local\Temp\ipykernel_3944\4122365882.py:311: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, con=conn, params=params)
# C:\Users\nakarinsue\AppData\Local\Temp\ipykernel_3944\4122365882.py:311: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, con=conn, params=params)
# C:\Users\nakarinsue\AppData\Local\Temp\ipykernel_3944\4122365882.py:311: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, con=conn, params=params)
# ❌ Database Query Error: DPY-4008: no bind placeholder named ":service_id" was found in the SQL text
# ✅ [Export Mode] สร้างและบันทึกไฟล์ Excel สำเร็จ: VendorConfig_0994000160127_20260311_214349.xlsx
#
# ▶️ กำลังส่ง DataExchange API...
#   SUCCESS CODE DESCRIPTOR      VENDOR_ID SERV_ID     TX_ID BILL_AMT FEE  \
# 0    true  100    success  0994000160127      00  14678512       50   0
#
#   FEE_VAT      DATA_1         DATA_2
# 0       0  0232506956  5916867125880
# 🔍 [Post-Check] กำลังค้นหา Transaction: 14678512 ในระบบ...
# ❌ Database Query Error: ORA-00904: "PAY": invalid identifier
# Help: https://docs.oracle.com/error-help/db/ora-00904/
# ⚠️ ค้นหาสำเร็จ แต่ยังไม่พบข้อมูล Transaction นี้บันทึกลงใน Database
# C:\Users\nakarinsue\AppData\Local\Temp\ipykernel_3944\4122365882.py:311: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, con=conn, params=params)
# Empty DataFrame
# Columns: []
# Index: []

# %%
from fastapi import FastAPI, HTTPException
from fastapi.responses import FileResponse
from pydantic import BaseModel
from typing import Optional, Dict, Any
import os
import json

# นำเข้าคลาสต่างๆ ที่เราสร้างไว้จากไฟล์หลัก (สมมติว่าชื่อ core_logic.py)
# from core_logic import TransactionContext, SoapPayloadBuilder, SoapApiClient, ResponseParser, OracleManager

app = FastAPI(title="Enterprise POS Integration API", version="1.0.0")

# ==========================================
# 1. Pydantic Models (กำหนดรูปแบบ JSON Input)
# ==========================================

class ActionRequest(BaseModel):
    """JSON สำหรับยิง Action API"""
    url: str = "http://localhost:80/Test/WSCDSService"
    vendor_id: str
    service_id: str
    store_id: str = "09892"
    bill_amt: str = "0"
    data_1: Optional[str] = ""
    data_3: Optional[str] = ""
    # ใช้สำหรับกรณี Cancel, Confirm ที่ต้องอ้างอิงข้อมูลเดิม
    ref_data: Optional[Dict[str, Any]] = {} 

class ConfigRequest(BaseModel):
    """JSON สำหรับเช็ค Config (Show/Export)"""
    vendor_id: str
    service_id: str

class TxIdRequest(BaseModel):
    """JSON สำหรับค้นหา Transaction"""
    tx_id: str

# สร้าง Instance พื้นฐาน
db_manager = OracleManager(ip='10.182.236.52', service_name='ONLPRD')

# ==========================================
# เส้นที่ 1: API สำหรับ Action ต่างๆ (1 เส้นต่อ 1 Action)
# ==========================================

def prepare_tx_from_request(req: ActionRequest) -> TransactionContext:
    """Helper สำหรับแปลง JSON Request เป็น TransactionContext"""
    tx = TransactionContext(data_1=req.data_1, data_3=req.data_3)
    tx.store.vendor_id = req.vendor_id
    tx.store.service_id = req.service_id
    tx.store.store_id = req.store_id
    tx.bill.bill_amt = req.bill_amt
    
    if req.ref_data:
        # ถ้ามีการส่ง ref_data มาด้วย (เช่น Cancel) ให้นำไปโหลดใส่ tx
        tx.load_reference_from_response(req.ref_data)
        
    tx.prepare_data()
    return tx

def process_soap_action(action_type: str, req: ActionRequest) -> Dict[str, Any]:
    tx = prepare_tx_from_request(req)
    api_client = SoapApiClient(endpoint_url=req.url)
    
    # เลือก Builder ตาม Action
    builders = {
        "data_exchange": SoapPayloadBuilder.build_data_exchange,
        "cancel": SoapPayloadBuilder.build_cancel,
        "exchange_confirm": SoapPayloadBuilder.build_data_exchange_confirm,
        "print": SoapPayloadBuilder.build_print,
        "or": SoapPayloadBuilder.build_or,
        "or_cancel": SoapPayloadBuilder.build_or_cancel,
        "or_confirm": SoapPayloadBuilder.build_or_confirm,
        "amt_confirm": SoapPayloadBuilder.build_amt_confirm,
        "std_tk_inquiry": SoapPayloadBuilder.build_std_tk_inquiry,
        "inquiry": SoapPayloadBuilder.build_inquiry,
    }
    
    if action_type not in builders:
        raise HTTPException(status_code=400, detail="Action ไม่ถูกต้อง")
        
    xml_payload = builders[action_type](tx)
    response_xml = api_client.send_request(xml_payload)
    
    if not response_xml:
        raise HTTPException(status_code=500, detail="ไม่สามารถเชื่อมต่อ SOAP Service ได้ หรือไม่มี Response")
        
    return ResponseParser.parse_to_dict(response_xml)

# สร้าง Endpoint แยกร่าย Action
@app.post("/api/action/data_exchange", summary="ยิง Action: DataExchange")
def action_data_exchange(req: ActionRequest):
    return process_soap_action("data_exchange", req)

@app.post("/api/action/cancel", summary="ยิง Action: Cancel")
def action_cancel(req: ActionRequest):
    return process_soap_action("cancel", req)

@app.post("/api/action/exchange_confirm", summary="ยิง Action: DataExchangeConfirm")
def action_exchange_confirm(req: ActionRequest):
    return process_soap_action("exchange_confirm", req)

# (สามารถเพิ่ม @app.post สำหรับ Print, OR, Inquiry ฯลฯ ได้ในรูปแบบเดียวกัน)

# ==========================================
# เส้นที่ 2: Export File (ส่งคืนเป็นไฟล์ Excel)
# ==========================================
@app.post("/api/db/export", summary="ตรวจสอบ Config และ Export เป็น Excel")
def export_config(req: ConfigRequest):
    file_path = db_manager.check_vendor_config(
        vendor_id=req.vendor_id, 
        service_id=req.service_id, 
        action='export'
    )
    
    if not file_path or not os.path.exists(file_path):
        raise HTTPException(status_code=500, detail="ไม่สามารถสร้างไฟล์ Excel ได้")
        
    # คืนค่าเป็นไฟล์ให้ผู้ใช้ Download
    return FileResponse(path=file_path, filename=file_path, media_type='application/vnd.openxmlformats-officedocument.spreadsheetml.sheet')

# ==========================================
# เส้นที่ 3: Show Data (ส่งคืนเป็น JSON)
# ==========================================
@app.post("/api/db/show", summary="ตรวจสอบ Config และแสดงผลเป็น JSON")
def show_config(req: ConfigRequest):
    data = db_manager.check_vendor_config(
        vendor_id=req.vendor_id, 
        service_id=req.service_id, 
        action='show'
    )
    if not data:
        raise HTTPException(status_code=404, detail="ไม่พบข้อมูล Config")
    return {"status": "success", "data": data}

# ==========================================
# เส้นที่ 4: Get Transaction by TX_ID
# ==========================================
@app.post("/api/db/transaction", summary="ค้นหา Transaction จาก Database ด้วย TX_ID")
def get_transaction(req: TxIdRequest):
    df = db_manager.get_transaction_by_tx_id(tx_id=req.tx_id)
    
    if df.empty:
        raise HTTPException(status_code=404, detail=f"ไม่พบข้อมูล TX_ID: {req.tx_id} ในระบบ")
        
    # แปลง DataFrame เป็น JSON Dictionary
    # แทนที่ NaN ด้วย None เพื่อให้เข้ากันได้กับมาตรฐาน JSON
    result_json = df.where(pd.notnull(df), None).to_dict(orient='records')
    
    return {"status": "success", "tx_id": req.tx_id, "data": result_json}

# %%
<?xml version="1.0" encoding="UTF-8"?>
<HQ_REQUEST>
	<SERVICE_BOX>
		<ADDRESS>
			<VENDOR_ID>0994000164904</VENDOR_ID>
			<SERVICE_ID>00</SERVICE_ID>
			<METHOD>DataExchange</METHOD>
		</ADDRESS>
		<DATA>
			<PAYMENT_CHANNEL>C05</PAYMENT_CHANNEL>
			<VENDOR_ID>0994000164904</VENDOR_ID>
			<SERV_ID>00</SERV_ID>
			<SERVICE_ID>00</SERVICE_ID>
			<STORE_ID>09892</STORE_ID>
			<STATION_ID>1</STATION_ID>
			<BUS_DATE>2026/03/12</BUS_DATE>
			<BUS_TIME>09:37:26</BUS_TIME>
			<SYS_DATE>2026/03/12</SYS_DATE>
			<SYS_TIME>09:37:26</SYS_TIME>
			<COMMON_TRN_ID>87</COMMON_TRN_ID>
			<SEQ_NO></SEQ_NO>
			<CLIENT_SERV_SEQ></CLIENT_SERV_SEQ>
			<SHIFT_ID>9</SHIFT_ID>
			<TRANS_TYPE>N</TRANS_TYPE>
			<ACCT_NO></ACCT_NO>
			<BILL_AMT>50</BILL_AMT>
			<ROUND_BILL_AMT>50</ROUND_BILL_AMT>
			<VAT_AMT>0</VAT_AMT>
			<REPT_TYPE>H</REPT_TYPE>
			<REPT_NO></REPT_NO>
			<PREV_REF_SEQ></PREV_REF_SEQ>
			<PREV_REF_DATE></PREV_REF_DATE>
			<SERV_CHARGE_NO></SERV_CHARGE_NO>
			<ITEM_NAME>พิมพ์ใบอนุ</ITEM_NAME>
			<ITEM_SELECTION>N</ITEM_SELECTION>
			<EMPLOYEE_ID> >0555505</EMPLOYEE_ID>
			<POS_TAX_ID>1537264827382</POS_TAX_ID>
			<DATA_1>0123456789</DATA_1>
			<DATA_2>1234567890123</DATA_2>
			<DATA_3></DATA_3>
			<DATA_4></DATA_4>
			<DATA_5></DATA_5>
			<DATA_6></DATA_6>
			<DATA_7></DATA_7>
			<DATA_9></DATA_9>
			<ZONE>1</ZONE>
			<PAYMENT_TYPE>001</PAYMENT_TYPE>
			<CANCEL_ID></CANCEL_ID>
			<CUST_NAME></CUST_NAME>
			<CUST_ADDR_1></CUST_ADDR_1>
			<CUST_ADDR_2></CUST_ADDR_2>
			<CUST_ADDR_3></CUST_ADDR_3>
			<CUST_PHONE_NO></CUST_PHONE_NO>
		</DATA>
	</SERVICE_BOX>
</HQ_REQUEST>

# %%
<?xml version="1.0" encoding="UTF-8"?>
<HQ_REQUEST>
	<SERVICE_BOX>
		<ADDRESS>
			<VENDOR_ID>0994000160127</VENDOR_ID>
			<SERVICE_ID>00</SERVICE_ID>
			<METHOD>DataExchange</METHOD>
		</ADDRESS>
		<DATA>
			<PAYMENT_CHANNEL>C05</PAYMENT_CHANNEL>
			<VENDOR_ID>0994000160127</VENDOR_ID>
			<SERV_ID>00</SERV_ID>
			<SERVICE_ID>00</SERVICE_ID>
			<STORE_ID>09884</STORE_ID>
			<STATION_ID>1</STATION_ID>
			<BUS_DATE>2026/03/12</BUS_DATE>
			<BUS_TIME>09:43:50</BUS_TIME>
			<SYS_DATE>2026/03/12</SYS_DATE>
			<SYS_TIME>09:43:50</SYS_TIME>
			<COMMON_TRN_ID>69</COMMON_TRN_ID>
			<SEQ_NO></SEQ_NO>
			<CLIENT_SERV_SEQ></CLIENT_SERV_SEQ>
			<SHIFT_ID>9</SHIFT_ID>
			<TRANS_TYPE>N</TRANS_TYPE>
			<ACCT_NO></ACCT_NO>
			<BILL_AMT>80</BILL_AMT>
			<ROUND_BILL_AMT>80</ROUND_BILL_AMT>
			<VAT_AMT>0</VAT_AMT>
			<REPT_TYPE>H</REPT_TYPE>
			<REPT_NO></REPT_NO>
			<PREV_REF_SEQ></PREV_REF_SEQ>
			<PREV_REF_DATE></PREV_REF_DATE>
			<SERV_CHARGE_NO></SERV_CHARGE_NO>
			<ITEM_NAME>Test</ITEM_NAME>
			<ITEM_SELECTION>N</ITEM_SELECTION>
			<EMPLOYEE_ID>0555505</EMPLOYEE_ID>
			<POS_TAX_ID>1537264827382</POS_TAX_ID>
			<DATA_1>5327075055</DATA_1>
			<DATA_2>7374296968974</DATA_2>
			<DATA_3></DATA_3>
			<DATA_4></DATA_4>
			<DATA_5></DATA_5>
			<DATA_6></DATA_6>
			<DATA_7></DATA_7>
			<DATA_9></DATA_9>
			<ZONE>1</ZONE>
			<PAYMENT_TYPE>001</PAYMENT_TYPE>
			<CANCEL_ID></CANCEL_ID>
			<CUST_NAME></CUST_NAME>
			<CUST_ADDR_1></CUST_ADDR_1>
			<CUST_ADDR_2></CUST_ADDR_2>
			<CUST_ADDR_3></CUST_ADDR_3>
			<CUST_PHONE_NO></CUST_PHONE_NO>
		</DATA>
	</SERVICE_BOX>
</HQ_REQUEST>'
